# %%
import pandas as pd
import numpy as np
import eventstudy as es
import matplotlib
import os
​
os.chdir('C:/Users/aryan-intern23/OneDrive - Manipal Academy of Higher Education/Desktop/Event Based Returns')

# %%
director= pd.read_csv('Master Stata CAR.csv')
director= director[['ISIN','Appointment Date']]
director['Appointment Date']= pd.to_datetime(director['Appointment Date'], format='%d/%m/%Y').dt.date


## director
## C:\Users\aryan-intern23\AppData\Local\Temp\2\ipykernel_12660\3281648718.py:1: DtypeWarning: Columns (28,32,42,53,54,55,56,57,58,115,116,117,118) have mixed types. Specify dtype option on import or set low_memory=False.

director= pd.read_csv('Master Stata CAR.csv')

# %%
day=21
def window (day):
    x= -(day-1)/2
    y= (day-1)/2
    return(x,y)
window(day)

# %%
form =250
es.Single.import_returns('data_17_05.csv')
es.Single.import_FamaFrench('Fama French 3Factors.csv', date_format ='%m/%d/%Y')
​
for i in range(10,len(director)):
    
    try:
        security= director['ISIN'][i]
        event= director['Appointment Date'][i]
​
        event= es.Single.FamaFrench_3factor(security_ticker=security ,event_date=np.datetime64(event),estimation_size= form , event_window= (-10,+10))
        result= pd.DataFrame(event.results())
        cumulative=(result['CAR']).astype(float).mean()         
    except:
        continue
    else:
        director.loc[i, 'CARFF_250_21' ]= cumulative
        
form =210
es.Single.import_returns('data_17_05.csv')
es.Single.import_FamaFrench('Fama French 3Factors.csv', date_format ='%m/%d/%Y')
​
for i in range(10,len(director)):
    
    try:
        security= director['ISIN'][i]
        event= director['Appointment Date'][i]
​
        event= es.Single.FamaFrench_3factor(security_ticker=security ,event_date=np.datetime64(event),estimation_size= form , event_window= (-10,+10))
        result= pd.DataFrame(event.results())
        cumulative=(result['CAR']).astype(float).mean()         
    except:
        continue
    else:
        director.loc[i, 'CARFF_210_21' ]= cumulative
​
form =180
es.Single.import_returns('data_17_05.csv')
es.Single.import_FamaFrench('Fama French 3Factors.csv', date_format ='%m/%d/%Y')
​
for i in range(10,len(director)):
    
    try:
        security= director['ISIN'][i]
        event= director['Appointment Date'][i]
​
        event= es.Single.FamaFrench_3factor(security_ticker=security ,event_date=np.datetime64(event),estimation_size= form , event_window= (-10,+10))
        result= pd.DataFrame(event.results())
        cumulative=(result['CAR']).astype(float).mean()         
    except:
        continue
    else:
        director.loc[i, 'CARFF_180_21' ]= cumulative
        
form =150
es.Single.import_returns('data_17_05.csv')
es.Single.import_FamaFrench('Fama French 3Factors.csv', date_format ='%m/%d/%Y')
​
for i in range(10,len(director)):
    
    try:
        security= director['ISIN'][i]
        event= director['Appointment Date'][i]
​
        event= es.Single.FamaFrench_3factor(security_ticker=security ,event_date=np.datetime64(event),estimation_size= form , event_window= (-10,+10))
        result= pd.DataFrame(event.results())
        cumulative=(result['CAR']).astype(float).mean()         
    except:
        continue
    else:
        director.loc[i, 'CARFF_150_21' ]= cumulative

# %%
director.to_excel('FF-21D.xlsx', sheet_name='21_CAR')

# %%
director.to_excel('FF-21D.xlsx', sheet_name='21_CAR')
In [298]:
 
​
form =250
es.Single.import_returns('data_17_05.csv')
es.Single.import_FamaFrench('Fama French 3Factors.csv', date_format ='%m/%d/%Y')
​
for i in range(0,len(director)):
    try:
​
        security= director['ISIN'][i]
        event= director['Appointment Date'][i]
​
        event= es.Single.market_model(security_ticker=security ,market_ticker='MF',event_date=np.datetime64(event),estimation_size= form , event_window= (-5,+5))
        result= pd.DataFrame(event.results())
        cumulative=(result['CAR']).astype(float).mean()         
    except:
         continue
​
    else:
        director.loc[i, 'CAR_250_21' ]= cumulative
form =210
es.Single.import_returns('data_17_05.csv')
es.Single.import_FamaFrench('Fama French 3Factors.csv', date_format ='%m/%d/%Y')
​
for i in range(0,len(director)):
    try:
​
        security= director['ISIN'][i]
        event= director['Appointment Date'][i]
​
        event= es.Single.market_model(security_ticker=security ,market_ticker='MF',event_date=np.datetime64(event),estimation_size= form , event_window= (-10,+10))
        result= pd.DataFrame(event.results())
        cumulative=(result['CAR']).astype(float).mean()         
    except:
         continue
​
    else:
        director.loc[i, 'CAR_210_21' ]= cumulative
form =180
es.Single.import_returns('data_17_05.csv')
es.Single.import_FamaFrench('Fama French 3Factors.csv', date_format ='%m/%d/%Y')
​
for i in range(0,len(director)):
    try:
​
        security= director['ISIN'][i]
        event= director['Appointment Date'][i]
​
        event= es.Single.market_model(security_ticker=security ,market_ticker='MF',event_date=np.datetime64(event),estimation_size= form , event_window= (-10,+10))
        result= pd.DataFrame(event.results())
        cumulative=(result['CAR']).astype(float).mean()         
    except:
         continue
​
    else:
        director.loc[i, 'CAR_180_21' ]= cumulative
form =150
es.Single.import_returns('data_17_05.csv')
es.Single.import_FamaFrench('Fama French 3Factors.csv', date_format ='%m/%d/%Y')
​
for i in range(0,len(director)):
    try:
​
        security= director['ISIN'][i]
        event= director['Appointment Date'][i]
​
        event= es.Single.market_model(security_ticker=security ,market_ticker='MF',event_date=np.datetime64(event),estimation_size= form , event_window= (-10,+))
        result= pd.DataFrame(event.results())
        cumulative=(result['CAR']).astype(float).mean()         
    except:
         continue
​
    else:
        director.loc[i, 'CAR_150_21' ]= cumulative

# %%
director

# %%
x

# %%
cumulative
