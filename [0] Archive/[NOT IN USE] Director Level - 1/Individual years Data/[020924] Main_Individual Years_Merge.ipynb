# %%
import pandas as pd
import numpy as np
import scipy as sp
from tqdm import tqdm
tqdm.pandas()
from dateutil.relativedelta import relativedelta
pd.set_option("display.max_columns", None)

# %% [markdown]
# ## Individual Director Data Only

# %%
# Reading Individual Years Data files and skipping 1 row. Table starts from row = 1, with header at row = 1

df1 = pd.read_excel("Indian Boards Data as on 31-Mar-2006.xlsx", sheet_name = "Master Profile", skiprows = 1)
df2 = pd.read_excel("Indian Boards Data as on 31-Mar-2007.xlsx", sheet_name = "Master Profile", skiprows = 1)
df3 = pd.read_excel("Indian Boards Data as on 31-Mar-2008.xlsx", sheet_name = "Master Profile", skiprows = 1)
df4 = pd.read_excel("Indian Boards Data as on 31-Mar-2009.xlsx", sheet_name = "Master Profile", skiprows = 1)
df5 = pd.read_excel("Indian Boards Data as on 31-Mar-2010.xlsx", sheet_name = "Master Profile", skiprows = 1)
df6 = pd.read_excel("Indian Boards Data as on 31-Mar-2011.xlsx", sheet_name = "Master Profile", skiprows = 1)
df7 = pd.read_excel("Indian Boards Data as on 31-Mar-2012.xlsx", sheet_name = "Master Profile", skiprows = 1)
df8 = pd.read_excel("Indian Boards Data as on 31-Mar-2013.xlsx", sheet_name = "Master Profile", skiprows = 1)
df9 = pd.read_excel("Indian Boards Data as on 31-Mar-2014.xlsx", sheet_name = "Master Profile", skiprows = 1)

df10 = pd.read_excel("Indian Boards Data as on 31-Mar-2015.xlsx", sheet_name = "Master Profile", skiprows = 1)
df11 = pd.read_excel("Indian Boards Data as on 31-Mar-2016.xlsx", sheet_name = "Master Profile", skiprows = 1)
df12 = pd.read_excel("Indian Boards Data as on 31-Mar-2017.xlsx", sheet_name = "Master Profile", skiprows = 1)
df13 = pd.read_excel("Indian Boards Data as on 31-Mar-2018.xlsx", sheet_name = "Master Profile", skiprows = 1)
df14 = pd.read_excel("Indian Boards Data as on 31-Mar-2019.xlsx", sheet_name = "Master Profile", skiprows = 1)
df15 = pd.read_excel("Indian Boards Data as on 31-Mar-2020.xlsx", sheet_name = "Master Profile", skiprows = 1)
df16 = pd.read_excel("Indian Boards Data as on 31-Mar-2021.xlsx", sheet_name = "Master Profile", skiprows = 1)
df17 = pd.read_excel("Indian Boards Data as on 31-Mar-2022.xlsx", sheet_name = "Master Profile", skiprows = 1)
df18 = pd.read_excel("Indian Boards Data as on 31-Mar-2023.xlsx", sheet_name = "Master Profile", skiprows = 1)
df19 = pd.read_excel("Indian Boards Data as on 31-Mar-2024.xlsx", sheet_name = "Master Profile", skiprows = 1)

# %%
# This inserts AsOnDate column and fills with NaT value
[df.insert(2, column = "AsOnDate", value = pd.NaT) for df in [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17, df18, df19]]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
# Populating dates
df1["AsOnDate"] = pd.to_datetime( "2006-03-31", format = "%Y-%m-%d" )
df2["AsOnDate"] = pd.to_datetime( "2007-03-31", format = "%Y-%m-%d" )
df3["AsOnDate"] = pd.to_datetime( "2008-03-31", format = "%Y-%m-%d" )
df4["AsOnDate"] = pd.to_datetime( "2009-03-31", format = "%Y-%m-%d" )

df5["AsOnDate"] = pd.to_datetime( "2010-03-31", format = "%Y-%m-%d" )
df6["AsOnDate"] = pd.to_datetime( "2011-03-31", format = "%Y-%m-%d" )
df7["AsOnDate"] = pd.to_datetime( "2012-03-31", format = "%Y-%m-%d" )
df8["AsOnDate"] = pd.to_datetime( "2013-03-31", format = "%Y-%m-%d" )
df9["AsOnDate"] = pd.to_datetime( "2014-03-31", format = "%Y-%m-%d" )

df10["AsOnDate"] = pd.to_datetime( "2015-03-31", format = "%Y-%m-%d" )
df11["AsOnDate"] = pd.to_datetime( "2016-03-31", format = "%Y-%m-%d" )
df12["AsOnDate"] = pd.to_datetime( "2017-03-31", format = "%Y-%m-%d" )
df13["AsOnDate"] = pd.to_datetime( "2018-03-31", format = "%Y-%m-%d" )
df14["AsOnDate"] = pd.to_datetime( "2019-03-31", format = "%Y-%m-%d" )

df15["AsOnDate"] = pd.to_datetime( "2020-03-31", format = "%Y-%m-%d" )
df16["AsOnDate"] = pd.to_datetime( "2021-03-31", format = "%Y-%m-%d" )
df17["AsOnDate"] = pd.to_datetime( "2022-03-31", format = "%Y-%m-%d" )
df18["AsOnDate"] = pd.to_datetime( "2023-03-31", format = "%Y-%m-%d" )
df19["AsOnDate"] = pd.to_datetime( "2024-03-31", format = "%Y-%m-%d" )

# %%
# Merging

dfs = [df.set_index(["Symbol", "Company", "AsOnDate"]) for df in [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17, df18, df19]]
mainDirect = pd.concat(dfs, axis=0).reset_index()
mainDirect.sort_values(["Company", "AsOnDate"]).reset_index(drop = True)
# Out:
#            Symbol             Company   AsOnDate Person Code  \
# 0       20MICRONS     20 MICRONS LTD. 2009-03-31   P00027662
# 1       20MICRONS     20 MICRONS LTD. 2009-03-31   P00027633
# 2       20MICRONS     20 MICRONS LTD. 2009-03-31   P00027664
# 3       20MICRONS     20 MICRONS LTD. 2009-03-31   P00029006
# 4       20MICRONS     20 MICRONS LTD. 2009-03-31   P00027661
# ...           ...                 ...        ...         ...
# 446429      ZYLOG  ZYLOG SYSTEMS LTD. 2018-03-31   P00001781
# 446430      ZYLOG  ZYLOG SYSTEMS LTD. 2018-03-31   P00062851
# 446431      ZYLOG  ZYLOG SYSTEMS LTD. 2018-03-31   P00042325
# 446432      ZYLOG  ZYLOG SYSTEMS LTD. 2018-03-31   P00027523
# 446433      ZYLOG  ZYLOG SYSTEMS LTD. 2018-03-31   P00075398
#
#        Director Salutation Director First Name Director Middle Name  \
# 0                      MR.            DIPTIMOY        DINESHCHANDRA
# 1                      MR.           RAMKISHAN            AMIRCHAND
# 2                      MR.               MIHIR               ARVIND
# 3                      MR.                ATIL            CHANDRESH
# 4                 LATE MR.           CHANDRESH            SHANTILAL
# ...                    ...                 ...                  ...
# 446429                 MR.           RAJAGOPAL                  NaN
# 446430                 MR.                  K.                   S.
# 446431                 MR.              AYYAVU          PALANICHAMY
# 446432                 MR.          SUDHARSHAN                  NaN
# 446433                 MR.                  S.                  NaN
#
#        Director Surname Date of Birth Gender Nationality Appointment Date  \
# 0         BHATTACHARJEE   09-DEC-1955      M         NaN      29-APR-2005
# 1             DEVIDAYAL   08-DEC-1950      M       INDIA      13-OCT-2007
# 2                 JOSHI   12-JUN-1977      M         NaN      23-AUG-2007
# 3                PARIKH   04-SEP-1977      M       INDIA      29-JAN-2001
# 4                PARIKH   06-MAR-1946      M       INDIA      29-MAR-1988
# ...                 ...           ...    ...         ...              ...
# 446429   SRINIVASACHARI   10-MAR-1940      M       INDIA      28-JAN-2007
# 446430      SUBRAMANIAN   17-SEP-1943      M         NaN      14-FEB-2014
# 446431    VASANTHAKUMAR   12-MAY-1977      M         NaN      29-JAN-2010
# 446432      VENKATRAMAN   28-JUL-1963      M         NaN      01-JUN-1995
# 446433    VIMALESHKUMAR   29-SEP-1970      M         NaN      25-NOV-2015
#
#        Member of Civil Services  \
# 0                           NaN
# 1                          NONE
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 446429                     NONE
# 446430                      NaN
# 446431                      NaN
# 446432                      NaN
# 446433                      NaN
#
#                                                Education1  \
# 0                                         GRADUATE: B.SC.
# 1                                   POST GRADUATE: M.B.A.
# 2       GRADUATE: ASSOCIATE MEMBER,INSTITUTE OF COMPAN...
# 3       GRADUATE: B.E.-CHEMICAL,GUJARAT UNIVERSITY,AHM...
# 4                          POST GRADUATE: M.SC.-CHEMISTRY
# ...                                                   ...
# 446429      GRADUATE: B.COM.,GUJARAT UNIVERSITY,AHMEDABAD
# 446430  POST GRADUATE: F.C.M.A.(FELLOW COST & MANAGEME...
# 446431    GRADUATE: B.E.,BHARATHIAR UNIVERSITY,COIMBATORE
# 446432                                    GRADUATE: B.SC.
# 446433                                   GRADUATE: B.COM.
#
#                                                Education2  \
# 0                                                     NaN
# 1       POST GRADUATE: M.COM.,MAHARAJA SAYAJIRAO UNIVE...
# 2                                                     NaN
# 3                POST GRADUATE: M.B.A.-FINANCE,CALIFORNIA
# 4                                                     NaN
# ...                                                   ...
# 446429  GRADUATE: DIPLOMA-INDUSTRIAL FINANCE,INDIAN IN...
# 446430                                                NaN
# 446431  POST GRADUATE: M.B.A.,BHARATHIDASAN UNIVERSITY...
# 446432                                                NaN
# 446433                                                NaN
#
#                                           Education3  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 446429  GRADUATE: LL.B.,GUJARAT UNIVERSITY,AHMEDABAD
# 446430                                           NaN
# 446431                                           NaN
# 446432                                           NaN
# 446433                                           NaN
#
#                                                Education4  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 446429  POST GRADUATE: C.A.I.I.B.(CERTIFIED ASSOCIATE ...
# 446430                                                NaN
# 446431                                                NaN
# 446432                                                NaN
# 446433                                                NaN
#
#                                                Education5 Education6  \
# 0                                                     NaN        NaN
# 1                                                     NaN        NaN
# 2                                                     NaN        NaN
# 3                                                     NaN        NaN
# 4                                                     NaN        NaN
# ...                                                   ...        ...
# 446429  POST GRADUATE: M.A.-ECONOMICS,GUJARAT UNIVERSI...        NaN
# 446430                                                NaN        NaN
# 446431                                                NaN        NaN
# 446432                                                NaN        NaN
# 446433                                                NaN        NaN
#
#        Education7 Education8 Education9 Education10  \
# 0             NaN        NaN        NaN         NaN
# 1             NaN        NaN        NaN         NaN
# 2             NaN        NaN        NaN         NaN
# 3             NaN        NaN        NaN         NaN
# 4             NaN        NaN        NaN         NaN
# ...           ...        ...        ...         ...
# 446429        NaN        NaN        NaN         NaN
# 446430        NaN        NaN        NaN         NaN
# 446431        NaN        NaN        NaN         NaN
# 446432        NaN        NaN        NaN         NaN
# 446433        NaN        NaN        NaN         NaN
#
#                                       Skills/Competencies Cessation Date  \
# 0                                                     NaN    02-MAR-2009
# 1       ACCOUNTS/AUDIT/TAXATION,CONSUMER DISCRETIONARY...            NaN
# 2                                                     NaN            NaN
# 3       ACCOUNTS/AUDIT/TAXATION,CORPORATE GOVERNANCE,F...            NaN
# 4       ACCOUNTS/AUDIT/TAXATION,CORPORATE GOVERNANCE,F...            NaN
# ...                                                   ...            ...
# 446429  CORPORATE GOVERNANCE,CORPORATE SOCIAL RESPONSI...    07-DEC-2012
# 446430                                                NaN    30-JUN-2016
# 446431  ACCOUNTS/AUDIT/TAXATION,CORPORATE GOVERNANCE,F...    20-NOV-2012
# 446432                                                NaN    19-NOV-2014
# 446433                                                NaN    30-JUN-2016
#
#                        Cessation Reason  \
# 0                      NOMINATION ENDED
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 446429      RESIGNED (NO REASON STATED)
# 446430      RESIGNED (NO REASON STATED)
# 446431      RESIGNED (NO REASON STATED)
# 446432  Suspended/Terminated/Superceded
# 446433      RESIGNED (NO REASON STATED)
#
#                                             Brief Profile  \
# 0       MR.D.D.BHATTACHARJEE, IDBI-NOMINEE DIRECTOR HO...
# 1       MR.RAM DEVIDAYAL HAS A MASTER'S DEGREE IN COMM...
# 2       MR.MIHIR JOSHI, GVFL- NOMINEE DIRECTOR HOLDS D...
# 3       MR. ATIL C. PARIKH, HOLDS A BACHELOR'S DEGREE ...
# 4       MR.CHANDRESH S. PARIKH, OUR CHAIRMAN AND MANAG...
# ...                                                   ...
# 446429  MR.S RAJAGOPAL, FORMER CHAIRMAN & MANAGING DIR...
# 446430                  ACCOUNTING & FINANCIAL FUNCTIONS.
# 446431                                                NaN
# 446432  MR.SUDARSHAN VENKATRAMAN, IS OUR PROMOTER. MR....
# 446433  MR. S. VIMALESH KUMAR IS A COMMERCE GRADUATE. ...
#
#        Promoter Director (Yes/No)  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# 446429                         NO
# 446430                         NO
# 446431                         NO
# 446432                         NO
# 446433                         NO
#
#                                         Position on Board  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 446429                             NON-EXECUTIVE DIRECTOR
# 446430                             NON-EXECUTIVE DIRECTOR
# 446431  NOMINEE DIRECTOR OF UTI VENTURE FUNDS MANAGEME...
# 446432                    CHAIRPERSON, EXECUTIVE DIRECTOR
# 446433                             NON-EXECUTIVE DIRECTOR
#
#        Independent (Yes/No) Occupation              Other Directorship 1  \
# 0                       NaN        NaN                               NaN
# 1                       NaN        NaN                               NaN
# 2                       NaN        NaN                               NaN
# 3                       NaN        NaN                               NaN
# 4                       NaN        NaN                               NaN
# ...                     ...        ...                               ...
# 446429                  YES    RETIRED  GMR AIRPORTS INFRASTRUCTURE LTD.
# 446430                  YES        NaN                               NaN
# 446431                   NO        NaN                               NaN
# 446432                   NO        NaN                               NaN
# 446433                  YES        NaN                               NaN
#
#                     Other Directorship 2 Other Directorship 3  \
# 0                                    NaN                  NaN
# 1                                    NaN                  NaN
# 2                                    NaN                  NaN
# 3                                    NaN                  NaN
# 4                                    NaN                  NaN
# ...                                  ...                  ...
# 446429  SREI INFRASTRUCTURE FINANCE LTD.                  NaN
# 446430                               NaN                  NaN
# 446431                               NaN                  NaN
# 446432                               NaN                  NaN
# 446433                               NaN                  NaN
#
#        Other Directorship 4 Other Directorship 5 Other Directorship 6  \
# 0                       NaN                  NaN                  NaN
# 1                       NaN                  NaN                  NaN
# 2                       NaN                  NaN                  NaN
# 3                       NaN                  NaN                  NaN
# 4                       NaN                  NaN                  NaN
# ...                     ...                  ...                  ...
# 446429                  NaN                  NaN                  NaN
# 446430                  NaN                  NaN                  NaN
# 446431                  NaN                  NaN                  NaN
# 446432                  NaN                  NaN                  NaN
# 446433                  NaN                  NaN                  NaN
#
#        Other Directorship 7 Other Directorship 8 Other Directorship 9  \
# 0                       NaN                  NaN                  NaN
# 1                       NaN                  NaN                  NaN
# 2                       NaN                  NaN                  NaN
# 3                       NaN                  NaN                  NaN
# 4                       NaN                  NaN                  NaN
# ...                     ...                  ...                  ...
# 446429                  NaN                  NaN                  NaN
# 446430                  NaN                  NaN                  NaN
# 446431                  NaN                  NaN                  NaN
# 446432                  NaN                  NaN                  NaN
# 446433                  NaN                  NaN                  NaN
#
#        Other Directorship 10 Other Directorship 11 Other Directorship 12  \
# 0                        NaN                   NaN                   NaN
# 1                        NaN                   NaN                   NaN
# 2                        NaN                   NaN                   NaN
# 3                        NaN                   NaN                   NaN
# 4                        NaN                   NaN                   NaN
# ...                      ...                   ...                   ...
# 446429                   NaN                   NaN                   NaN
# 446430                   NaN                   NaN                   NaN
# 446431                   NaN                   NaN                   NaN
# 446432                   NaN                   NaN                   NaN
# 446433                   NaN                   NaN                   NaN
#
#        Other Directorship 13 Other Directorship 14 Other Directorship 15  \
# 0                        NaN                   NaN                   NaN
# 1                        NaN                   NaN                   NaN
# 2                        NaN                   NaN                   NaN
# 3                        NaN                   NaN                   NaN
# 4                        NaN                   NaN                   NaN
# ...                      ...                   ...                   ...
# 446429                   NaN                   NaN                   NaN
# 446430                   NaN                   NaN                   NaN
# 446431                   NaN                   NaN                   NaN
# 446432                   NaN                   NaN                   NaN
# 446433                   NaN                   NaN                   NaN
#
#        Tenure Valid till
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 446429               NaN
# 446430               NaN
# 446431               NaN
# 446432               NaN
# 446433               NaN
#
# [446434 rows x 47 columns]

# %%
mainDirect.to_csv("Main_Director v020924.csv")

# %% [markdown]
# ## Committees Data Only

# %%
# Reading Individual Years Data files for Committees and skipping 1 row. Table starts from row = 1, with header at row = 1

dfC11 = pd.read_excel("Indian Boards Data as on 31-Mar-2016.xlsx", sheet_name = "Committee Details", skiprows = 1)
dfC12 = pd.read_excel("Indian Boards Data as on 31-Mar-2017.xlsx", sheet_name = "Committee Details", skiprows = 1)
dfC13 = pd.read_excel("Indian Boards Data as on 31-Mar-2018.xlsx", sheet_name = "Committee Details", skiprows = 1)
dfC14 = pd.read_excel("Indian Boards Data as on 31-Mar-2019.xlsx", sheet_name = "Committee Details", skiprows = 1)
dfC15 = pd.read_excel("Indian Boards Data as on 31-Mar-2020.xlsx", sheet_name = "Committee Details", skiprows = 1)
dfC16 = pd.read_excel("Indian Boards Data as on 31-Mar-2021.xlsx", sheet_name = "Committee Details", skiprows = 1)
dfC17 = pd.read_excel("Indian Boards Data as on 31-Mar-2022.xlsx", sheet_name = "Committee Details", skiprows = 1)
dfC18 = pd.read_excel("Indian Boards Data as on 31-Mar-2023.xlsx", sheet_name = "Committee Details", skiprows = 1)
dfC19 = pd.read_excel("Indian Boards Data as on 31-Mar-2024.xlsx", sheet_name = "Committee Details", skiprows = 1)

# %%
# This inserts AsOnDate column and fills with NaT value
[df.insert(2, column = "AsOnDate", value = pd.NaT) for df in [dfC11, dfC12, dfC13, dfC14, dfC15, dfC16, dfC17, dfC18, dfC19]]
# Out:
# [None, None, None, None, None, None, None, None, None]

# %%
# Populating dates
dfC11["AsOnDate"] = pd.to_datetime( "2016-03-31", format = "%Y-%m-%d" )
dfC12["AsOnDate"] = pd.to_datetime( "2017-03-31", format = "%Y-%m-%d" )
dfC13["AsOnDate"] = pd.to_datetime( "2018-03-31", format = "%Y-%m-%d" )
dfC14["AsOnDate"] = pd.to_datetime( "2019-03-31", format = "%Y-%m-%d" )

dfC15["AsOnDate"] = pd.to_datetime( "2020-03-31", format = "%Y-%m-%d" )
dfC16["AsOnDate"] = pd.to_datetime( "2021-03-31", format = "%Y-%m-%d" )
dfC17["AsOnDate"] = pd.to_datetime( "2022-03-31", format = "%Y-%m-%d" )
dfC18["AsOnDate"] = pd.to_datetime( "2023-03-31", format = "%Y-%m-%d" )
dfC19["AsOnDate"] = pd.to_datetime( "2024-03-31", format = "%Y-%m-%d" )

# %%
dfCs = [df.set_index(['Person Code']) for df in [dfC11, dfC12, dfC13, dfC14, dfC15, dfC16, dfC17, dfC18, dfC19]]
mainComm = pd.concat(dfCs, axis=0).reset_index()
mainComm.sort_values(['Company', 'AsOnDate']).reset_index(drop = True)
# Out:
#        Person Code     Symbol             Company   AsOnDate  \
# 0        P00027633  20MICRONS     20 MICRONS LTD. 2016-03-31
# 1        P00027633  20MICRONS     20 MICRONS LTD. 2016-03-31
# 2        P00027633  20MICRONS     20 MICRONS LTD. 2016-03-31
# 3        P00029006  20MICRONS     20 MICRONS LTD. 2016-03-31
# 4        P00027661  20MICRONS     20 MICRONS LTD. 2016-03-31
# ...            ...        ...                 ...        ...
# 270877   P00075400      ZYLOG  ZYLOG SYSTEMS LTD. 2018-03-31
# 270878   P00075400      ZYLOG  ZYLOG SYSTEMS LTD. 2018-03-31
# 270879   P00075399      ZYLOG  ZYLOG SYSTEMS LTD. 2018-03-31
# 270880   P00075399      ZYLOG  ZYLOG SYSTEMS LTD. 2018-03-31
# 270881   P00075399      ZYLOG  ZYLOG SYSTEMS LTD. 2018-03-31
#
#        Director Salutation Director First Name Director Middle Name  \
# 0                      MR.           RAMKISHAN            AMIRCHAND
# 1                      MR.           RAMKISHAN            AMIRCHAND
# 2                      MR.           RAMKISHAN            AMIRCHAND
# 3                      MR.                ATIL            CHANDRESH
# 4                 LATE MR.           CHANDRESH            SHANTILAL
# ...                    ...                 ...                  ...
# 270877                 MR.             KRISHNA                  NaN
# 270878                 MR.             KRISHNA                  NaN
# 270879                 MR.                  S.                   P.
# 270880                 MR.                  S.                   P.
# 270881                 MR.                  S.                   P.
#
#        Director Surname                                     Committee Name  \
# 0             DEVIDAYAL  STAKEHOLDERS RELATIONSHIP & SHARE TRANSFER COM...
# 1             DEVIDAYAL                NOMINATION & REMUNERATION COMMITTEE
# 2             DEVIDAYAL                                    AUDIT COMMITTEE
# 3                PARIKH                          RISK MANAGEMENT COMMITTEE
# 4                PARIKH          CORPORATE SOCIAL RESPONSIBILITY COMMITTEE
# ...                 ...                                                ...
# 270877          KISHORE                NOMINATION & REMUNERATION COMMITTEE
# 270878          KISHORE                STAKEHOLDERS RELATIONSHIP COMMITTEE
# 270879          SRIHARI                                    AUDIT COMMITTEE
# 270880          SRIHARI                NOMINATION & REMUNERATION COMMITTEE
# 270881          SRIHARI                STAKEHOLDERS RELATIONSHIP COMMITTEE
#
#            Position Date of Joining
# 0            MEMBER             NaN
# 1            MEMBER             NaN
# 2       CHAIRPERSON             NaN
# 3            MEMBER             NaN
# 4       CHAIRPERSON             NaN
# ...             ...             ...
# 270877       MEMBER     30-SEP-2016
# 270878       MEMBER     30-SEP-2016
# 270879       MEMBER             NaN
# 270880       MEMBER             NaN
# 270881       MEMBER             NaN
#
# [270882 rows x 11 columns]

# %%
mainComm.to_csv("Main_Committees v020924.csv")
