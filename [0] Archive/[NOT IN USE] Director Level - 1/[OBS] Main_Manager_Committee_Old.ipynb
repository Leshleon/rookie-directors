# %%
import pandas as pd

# %%
df1 = pd.read_excel("Indian Boards Data as on 31-Mar-2006.xlsx", sheet_name = 'Master Profile', skiprows = 1)
df2 = pd.read_excel("Indian Boards Data as on 31-Mar-2007.xlsx", sheet_name = 'Master Profile', skiprows = 1)
df3 = pd.read_excel("Indian Boards Data as on 31-Mar-2008.xlsx", sheet_name = 'Master Profile', skiprows = 1)
df4 = pd.read_excel("Indian Boards Data as on 31-Mar-2009.xlsx", sheet_name = 'Master Profile', skiprows = 1)
df5 = pd.read_excel("Indian Boards Data as on 31-Mar-2010.xlsx", sheet_name = 'Master Profile', skiprows = 1)
df6 = pd.read_excel("Indian Boards Data as on 31-Mar-2011.xlsx", sheet_name = 'Master Profile', skiprows = 1)
df7 = pd.read_excel("Indian Boards Data as on 31-Mar-2012.xlsx", sheet_name = 'Master Profile', skiprows = 1)
df8 = pd.read_excel("Indian Boards Data as on 31-Mar-2013.xlsx", sheet_name = 'Master Profile', skiprows = 1)
df9 = pd.read_excel("Indian Boards Data as on 31-Mar-2014.xlsx", sheet_name = 'Master Profile', skiprows = 1)

df10 = pd.read_excel("Indian Boards Data as on 31-Mar-2015.xlsx", sheet_name = 'Master Profile', skiprows = 1)
df11 = pd.read_excel("Indian Boards Data as on 31-Mar-2016.xlsx", sheet_name = 'Master Profile', skiprows = 1)
df12 = pd.read_excel("Indian Boards Data as on 31-Mar-2017.xlsx", sheet_name = 'Master Profile', skiprows = 1)
df13 = pd.read_excel("Indian Boards Data as on 31-Mar-2018.xlsx", sheet_name = 'Master Profile', skiprows = 1)
df14 = pd.read_excel("Indian Boards Data as on 31-Mar-2019.xlsx", sheet_name = 'Master Profile', skiprows = 1)
df15 = pd.read_excel("Indian Boards Data as on 31-Mar-2020.xlsx", sheet_name = 'Master Profile', skiprows = 1)
df16 = pd.read_excel("Indian Boards Data as on 31-Mar-2021.xlsx", sheet_name = 'Master Profile', skiprows = 1)
df17 = pd.read_excel("Indian Boards Data as on 31-Mar-2022.xlsx", sheet_name = 'Master Profile', skiprows = 1)
df18 = pd.read_excel("Indian Boards Data as on 31-Mar-2023.xlsx", sheet_name = 'Master Profile', skiprows = 1)
df19 = pd.read_excel("Indian Boards Data as on 31-Mar-2024.xlsx", sheet_name = 'Master Profile', skiprows = 1)

# %%
df1.insert(2, 'AsOnDate', '31-03-2006')
df2.insert(2, 'AsOnDate', '31-03-2007')
df3.insert(2, 'AsOnDate', '31-03-2008')
df4.insert(2, 'AsOnDate', '31-03-2009')
df5.insert(2, 'AsOnDate', '31-03-2010')
df6.insert(2, 'AsOnDate', '31-03-2011')
df7.insert(2, 'AsOnDate', '31-03-2012')
df8.insert(2, 'AsOnDate', '31-03-2013')
df9.insert(2, 'AsOnDate', '31-03-2014')

df10.insert(2, 'AsOnDate', '31-03-2015')
df11.insert(2, 'AsOnDate', '31-03-2016')
df12.insert(2, 'AsOnDate', '31-03-2017')
df13.insert(2, 'AsOnDate', '31-03-2018')
df14.insert(2, 'AsOnDate', '31-03-2019')
df15.insert(2, 'AsOnDate', '31-03-2020')
df16.insert(2, 'AsOnDate', '31-03-2021')
df17.insert(2, 'AsOnDate', '31-03-2022')
df18.insert(2, 'AsOnDate', '31-03-2023')
df19.insert(2, 'AsOnDate', '31-03-2024')

# %%
dfs = [df.set_index(['Symbol', 'Company', 'AsOnDate']) for df in [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17, df18, df19]]
dff = pd.concat(dfs, axis=0).reset_index()
dff.sort_values(['Company', 'AsOnDate']).reset_index(drop = True)
# Out:
#            Symbol             Company    AsOnDate Person Code  \
# 0       20MICRONS     20 MICRONS LTD.  31-03-2009   P00027662
# 1       20MICRONS     20 MICRONS LTD.  31-03-2009   P00027633
# 2       20MICRONS     20 MICRONS LTD.  31-03-2009   P00027664
# 3       20MICRONS     20 MICRONS LTD.  31-03-2009   P00029006
# 4       20MICRONS     20 MICRONS LTD.  31-03-2009   P00027661
# ...           ...                 ...         ...         ...
# 446429      ZYLOG  ZYLOG SYSTEMS LTD.  31-03-2018   P00001781
# 446430      ZYLOG  ZYLOG SYSTEMS LTD.  31-03-2018   P00062851
# 446431      ZYLOG  ZYLOG SYSTEMS LTD.  31-03-2018   P00042325
# 446432      ZYLOG  ZYLOG SYSTEMS LTD.  31-03-2018   P00027523
# 446433      ZYLOG  ZYLOG SYSTEMS LTD.  31-03-2018   P00075398
#
#        Director Salutation Director First Name Director Middle Name  \
# 0                      MR.            DIPTIMOY        DINESHCHANDRA
# 1                      MR.           RAMKISHAN            AMIRCHAND
# ...

# %%
df11_1 = pd.read_excel("Indian Boards Data as on 31-Mar-2016.xlsx", sheet_name = 'Committee Details', skiprows = 1)
df12_1 = pd.read_excel("Indian Boards Data as on 31-Mar-2017.xlsx", sheet_name = 'Committee Details', skiprows = 1)
df13_1 = pd.read_excel("Indian Boards Data as on 31-Mar-2018.xlsx", sheet_name = 'Committee Details', skiprows = 1)
df14_1 = pd.read_excel("Indian Boards Data as on 31-Mar-2019.xlsx", sheet_name = 'Committee Details', skiprows = 1)
df15_1 = pd.read_excel("Indian Boards Data as on 31-Mar-2020.xlsx", sheet_name = 'Committee Details', skiprows = 1)
df16_1 = pd.read_excel("Indian Boards Data as on 31-Mar-2021.xlsx", sheet_name = 'Committee Details', skiprows = 1)
df17_1 = pd.read_excel("Indian Boards Data as on 31-Mar-2022.xlsx", sheet_name = 'Committee Details', skiprows = 1)
df18_1 = pd.read_excel("Indian Boards Data as on 31-Mar-2023.xlsx", sheet_name = 'Committee Details', skiprows = 1)
df19_1 = pd.read_excel("Indian Boards Data as on 31-Mar-2024.xlsx", sheet_name = 'Committee Details', skiprows = 1)

# %%
df11_1.insert(2, 'AsOnDate', '31-03-2016')
df12_1.insert(2, 'AsOnDate', '31-03-2017')
df13_1.insert(2, 'AsOnDate', '31-03-2018')
df14_1.insert(2, 'AsOnDate', '31-03-2019')
df15_1.insert(2, 'AsOnDate', '31-03-2020')
df16_1.insert(2, 'AsOnDate', '31-03-2021')
df17_1.insert(2, 'AsOnDate', '31-03-2022')
df18_1.insert(2, 'AsOnDate', '31-03-2023')
df19_1.insert(2, 'AsOnDate', '31-03-2024')

# %%
dfs_1 = [df.set_index(['Person Code']) for df in [df11_1, df12_1, df13_1, df14_1, df15_1, df16_1, df17_1, df18_1, df19_1]]
dfg = pd.concat(dfs_1, axis=0).reset_index()
dfg.sort_values(['Company', 'AsOnDate']).reset_index(drop = True)
# Out:
#        Person Code     Symbol             Company    AsOnDate  \
# 0        P00027633  20MICRONS     20 MICRONS LTD.  31-03-2016
# 1        P00027633  20MICRONS     20 MICRONS LTD.  31-03-2016
# 2        P00027633  20MICRONS     20 MICRONS LTD.  31-03-2016
# 3        P00029006  20MICRONS     20 MICRONS LTD.  31-03-2016
# 4        P00027661  20MICRONS     20 MICRONS LTD.  31-03-2016
# ...            ...        ...                 ...         ...
# 270877   P00075400      ZYLOG  ZYLOG SYSTEMS LTD.  31-03-2018
# 270878   P00075400      ZYLOG  ZYLOG SYSTEMS LTD.  31-03-2018
# 270879   P00075399      ZYLOG  ZYLOG SYSTEMS LTD.  31-03-2018
# 270880   P00075399      ZYLOG  ZYLOG SYSTEMS LTD.  31-03-2018
# 270881   P00075399      ZYLOG  ZYLOG SYSTEMS LTD.  31-03-2018
#
#        Director Salutation Director First Name Director Middle Name  \
# 0                      MR.           RAMKISHAN            AMIRCHAND
# 1                      MR.           RAMKISHAN            AMIRCHAND
# ...

# %%
dfd = pd.read_excel('Dirlevel_with CAR and briefs_from 2013_81917.xlsx')
dfd
# Out:
#        ResultId  mRowId      YearRowId             SourceSheet   AsOnDate  \
# 0         44508  135668  2020000000000  MasterProfile_20150331 2015-03-31
# 1         44522  114189  2010000000000  MasterProfile_20140331 2014-03-31
# 2         44523  135917  2020000000000  MasterProfile_20150331 2015-03-31
# 3         44533  107344  2010000000000  MasterProfile_20130331 2013-03-31
# 4         44572  138076  2020000000000  MasterProfile_20150331 2015-03-31
# ...         ...     ...            ...                     ...        ...
# 81911     44395  282275  2020000000000  MasterProfile_20200331 2020-03-31
# 81912     44410  269628  2020000000000  MasterProfile_20200331 2020-03-31
# 81913     44415  272330  2020000000000  MasterProfile_20200331 2020-03-31
# 81914     44420  269092  2020000000000  MasterProfile_20200331 2020-03-31
# 81915     44446  265879  2020000000000  MasterProfile_20200331 2020-03-31
#
#        ProfileRowId      Symbol          ISIN  FirmDirectorMatch  \
# ...

# %%
dff['AsOnDate'] = pd.to_datetime(dff['AsOnDate'], dayfirst = True)
dfg['AsOnDate'] = pd.to_datetime(dfg['AsOnDate'], dayfirst = True)
dfd['AsOnDate'] = pd.to_datetime(dfd['AsOnDate'], dayfirst = True)

dff['Date of Birth'] = pd.to_datetime(dff['Date of Birth'], yearfirst = True)
dfd['Date of Birth'] = pd.to_datetime(dfd['Date of Birth'], yearfirst = True)

dff['Appointment Date'] = pd.to_datetime(dff['Appointment Date'], yearfirst = True)
dfd['Appointment Date'] = pd.to_datetime(dfd['Appointment Date'], yearfirst = True)

# %%
dfd['Cessation Reason'] = dfd['Cessation Reason'].astype(str)
dff['Cessation Reason'] = dff['Cessation Reason'].astype(str)

dfd['Other Directorship 14'] = dfd['Other Directorship 14'].astype(str)
dff['Other Directorship 14'] = dff['Other Directorship 14'].astype(str)

dfd['Other Directorship 15'] = dfd['Other Directorship 15'].astype(str)
dff['Other Directorship 15'] = dff['Other Directorship 15'].astype(str)

# %%
dfd.drop('Person Code', axis = 1)
dfd
# Out:
#        ResultId  mRowId      YearRowId             SourceSheet   AsOnDate  \
# 0         44508  135668  2020000000000  MasterProfile_20150331 2015-03-31
# 1         44522  114189  2010000000000  MasterProfile_20140331 2014-03-31
# 2         44523  135917  2020000000000  MasterProfile_20150331 2015-03-31
# 3         44533  107344  2010000000000  MasterProfile_20130331 2013-03-31
# 4         44572  138076  2020000000000  MasterProfile_20150331 2015-03-31
# ...         ...     ...            ...                     ...        ...
# 81911     44395  282275  2020000000000  MasterProfile_20200331 2020-03-31
# 81912     44410  269628  2020000000000  MasterProfile_20200331 2020-03-31
# 81913     44415  272330  2020000000000  MasterProfile_20200331 2020-03-31
# 81914     44420  269092  2020000000000  MasterProfile_20200331 2020-03-31
# 81915     44446  265879  2020000000000  MasterProfile_20200331 2020-03-31
#
#        ProfileRowId      Symbol          ISIN  FirmDirectorMatch  \
# ...

# %%
dff2 = dff.merge( dfd, on = ['AsOnDate', 'Director First Name', 'Director Middle Name', 'Director Surname', 'Symbol'], how = 'outer' )
dff2
# Out:
#            Symbol              Company_x   AsOnDate Person Code_x  \
# 0         3MINDIA          3M INDIA LTD. 2006-03-31     P00033272
# 1         3MINDIA          3M INDIA LTD. 2006-03-31     P00000249
# 2         3MINDIA          3M INDIA LTD. 2006-03-31     P00033331
# 3          3PLAND  3P LAND HOLDINGS LTD. 2006-03-31     P00022755
# 4          3PLAND  3P LAND HOLDINGS LTD. 2006-03-31     P00012704
# ...           ...                    ...        ...           ...
# 453887      SIKKO                    NaN 2020-03-31           NaN
# 453888  VISAKAIND                    NaN 2020-03-31           NaN
# 453889     DAAWAT                    NaN 2020-03-31           NaN
# 453890       GATI                    NaN 2020-03-31           NaN
# 453891     SELMCL                    NaN 2020-03-31           NaN
#
#        Director Salutation_x Director First Name Director Middle Name  \
# 0                        MR.    SHANKARANARAYANA      VISHWANATHA RAO
# ...

# %%
dff2.set_index(keys = ['Person Code_x', 'Symbol', 'AsOnDate'])
# Out:
#                                                 Company_x  \
# Person Code_x Symbol    AsOnDate
# P00033272     3MINDIA   2006-03-31          3M INDIA LTD.
# P00000249     3MINDIA   2006-03-31          3M INDIA LTD.
# P00033331     3MINDIA   2006-03-31          3M INDIA LTD.
# P00022755     3PLAND    2006-03-31  3P LAND HOLDINGS LTD.
# P00012704     3PLAND    2006-03-31  3P LAND HOLDINGS LTD.
# ...                                                   ...
# NaN           SIKKO     2020-03-31                    NaN
#               VISAKAIND 2020-03-31                    NaN
#               DAAWAT    2020-03-31                    NaN
#               GATI      2020-03-31                    NaN
#               SELMCL    2020-03-31                    NaN
#
#                                    Director Salutation_x Director First Name  \
# Person Code_x Symbol    AsOnDate
# P00033272     3MINDIA   2006-03-31                   MR.    SHANKARANARAYANA
# ...

# %%
dfg
# Out:
#        Person Code     Symbol              Company   AsOnDate  \
# 0        P00027633  20MICRONS      20 MICRONS LTD. 2016-03-31
# 1        P00027633  20MICRONS      20 MICRONS LTD. 2016-03-31
# 2        P00027633  20MICRONS      20 MICRONS LTD. 2016-03-31
# 3        P00029006  20MICRONS      20 MICRONS LTD. 2016-03-31
# 4        P00027661  20MICRONS      20 MICRONS LTD. 2016-03-31
# ...            ...        ...                  ...        ...
# 270877   P00013240  ZYDUSWELL  ZYDUS WELLNESS LTD. 2024-03-31
# 270878   P00013240  ZYDUSWELL  ZYDUS WELLNESS LTD. 2024-03-31
# 270879   P00013240  ZYDUSWELL  ZYDUS WELLNESS LTD. 2024-03-31
# 270880   P00053258  ZYDUSWELL  ZYDUS WELLNESS LTD. 2024-03-31
# 270881   P00053258  ZYDUSWELL  ZYDUS WELLNESS LTD. 2024-03-31
#
#        Director Salutation Director First Name Director Middle Name  \
# 0                      MR.           RAMKISHAN            AMIRCHAND
# 1                      MR.           RAMKISHAN            AMIRCHAND
# ...

# %%
dfg.drop( columns = ['Company', 'Director Salutation', 'Director First Name', 'Director Middle Name', 'Director Surname'], axis = 1, inplace = True)

# %%
dfg.set_index(keys = ['Person Code', 'Symbol', 'AsOnDate'])
# Out:
#                                                                      Committee Name  \
# Person Code Symbol    AsOnDate
# P00027633   20MICRONS 2016-03-31  STAKEHOLDERS RELATIONSHIP & SHARE TRANSFER COM...
#                       2016-03-31                NOMINATION & REMUNERATION COMMITTEE
#                       2016-03-31                                    AUDIT COMMITTEE
# P00029006   20MICRONS 2016-03-31                          RISK MANAGEMENT COMMITTEE
# P00027661   20MICRONS 2016-03-31          CORPORATE SOCIAL RESPONSIBILITY COMMITTEE
# ...                                                                             ...
# P00013240   ZYDUSWELL 2024-03-31                           SHARE TRANSFER COMMITTEE
#                       2024-03-31                          RISK MANAGEMENT COMMITTEE
#                       2024-03-31                 FINANCE & ADMINISTRATIVE COMMITTEE
# P00053258   ZYDUSWELL 2024-03-31                NOMINATION & REMUNERATION COMMITTEE
# ...

# %%
dff3 = dff2.merge(dfg, left_on = ['Person Code_x', 'Symbol', 'AsOnDate'], right_on = ['Person Code', 'Symbol', 'AsOnDate'], how = 'outer')

# %%
dff3
# Out:
#             Symbol              Company_x   AsOnDate Person Code_x  \
# 0          3MINDIA          3M INDIA LTD. 2006-03-31     P00033272
# 1          3MINDIA          3M INDIA LTD. 2006-03-31     P00000249
# 2          3MINDIA          3M INDIA LTD. 2006-03-31     P00033331
# 3           3PLAND  3P LAND HOLDINGS LTD. 2006-03-31     P00022755
# 4           3PLAND  3P LAND HOLDINGS LTD. 2006-03-31     P00012704
# ...            ...                    ...        ...           ...
# 627914  KANORICHEM                    NaN 2020-03-31           NaN
# 627915   NITINSPIN                    NaN 2020-03-31           NaN
# 627916  ANDHRSUGAR                    NaN 2020-03-31           NaN
# 627917   ENDURANCE                    NaN 2020-03-31           NaN
# 627918   VISAKAIND                    NaN 2020-03-31           NaN
#
#        Director Salutation_x Director First Name Director Middle Name  \
# 0                        MR.    SHANKARANARAYANA      VISHWANATHA RAO
# ...

# %%
dff3.to_csv("Main.csv")
