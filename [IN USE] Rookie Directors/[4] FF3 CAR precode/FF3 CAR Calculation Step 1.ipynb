# %%
import pandas_datareader.data as web #to collect data
import datetime as dt #to specify start and end dates

# import yfinance as yf

import eventstudy as es
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns


import pandas as pd

import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.regression.rolling import RollingOLS

from patsy import dmatrices
from tqdm.notebook import tqdm
tqdm.pandas()

# %% [markdown]
# ## Data reading and melting

# %%
import_folder_path = r"..\..\[IN USE] Rookie Directors\[1] Director Level\director_wrangle_output"
output_folder_path = "car_output1"
supporting_folder_path = "supporting_datafiles"

# %%
data = pd.read_csv(rf"{supporting_folder_path}\Adjusted Clos_collated.csv").drop("Unnamed: 0", axis = 1)

# %%
data
# Out:
#         AsOnDate  20 Microns Ltd.  20Th Century Finance Corpn. Ltd. [Merged]  \
# 0     2004-01-01              NaN                                        NaN
# 1     2004-01-02              NaN                                        NaN
# 2     2004-01-05              NaN                                        NaN
# 3     2004-01-06              NaN                                        NaN
# 4     2004-01-07              NaN                                        NaN
# ...          ...              ...                                        ...
# 5025  2024-03-21           144.70                                       12.5
# 5026  2024-03-22           145.05                                       12.5
# 5027  2024-03-26           143.00                                       12.5
# 5028  2024-03-27           143.00                                       12.5
# 5029  2024-03-28           143.70                                       12.5
#
#       360 One Wam Ltd.  3I Infotech Ltd.  3M India Ltd.  \
# 0                  NaN               NaN         515.00
# 1                  NaN               NaN         530.50
# 2                  NaN               NaN         511.75
# 3                  NaN               NaN         495.00
# 4                  NaN               NaN         490.40
# ...                ...               ...            ...
# 5025            673.40             41.60       30049.25
# 5026            665.85             41.85       30728.40
# 5027            650.30             39.20       30487.15
# 5028            667.95             39.40       31475.10
# 5029            675.60             39.50       31193.35
#
#       3P Land Holdings Ltd.  3Rd Rock Multimedia Ltd.  5Paisa Capital Ltd.  \
# 0                       NaN                       NaN                  NaN
# 1                      3.20                       NaN                  NaN
# 2                      3.42                       NaN                  NaN
# 3                       NaN                       NaN                  NaN
# 4                      2.76                       NaN                  NaN
# ...                     ...                       ...                  ...
# 5025                  30.80                      64.6               487.45
# 5026                  30.40                      64.6               487.85
# 5027                  28.90                      64.6               476.05
# 5028                  28.40                      64.6               490.30
# 5029                  27.00                      64.6               505.05
#
#       63 Moons Technologies Ltd.  ...   3898  3899   3900  3901  3902  3903  \
# 0                            NaN  ...  66.83   NaN  15.25   NaN   NaN   NaN
# 1                            NaN  ...  65.88   NaN  17.35   NaN   NaN   NaN
# 2                            NaN  ...  61.76   NaN  16.30   NaN   NaN   NaN
# 3                            NaN  ...  61.94   NaN  15.70   NaN   NaN   NaN
# 4                            NaN  ...  60.33   NaN  16.00   NaN   NaN   NaN
# ...                          ...  ...    ...   ...    ...   ...   ...   ...
# 5025                      407.15  ...    NaN   NaN    NaN   NaN   NaN   NaN
# 5026                      402.95  ...    NaN   NaN    NaN   NaN   NaN   NaN
# 5027                      393.75  ...    NaN   NaN    NaN   NaN   NaN   NaN
# 5028                      381.60  ...    NaN   NaN    NaN   NaN   NaN   NaN
# 5029                      381.60  ...    NaN   NaN    NaN   NaN   NaN   NaN
#
#        3904   3905  3906  3907
# 0     59.85  25.79   NaN   NaN
# 1     66.50  26.74   NaN   NaN
# 2     62.70  25.95   NaN   NaN
# 3     59.50  25.74   NaN   NaN
# 4     57.75  25.15   NaN   NaN
# ...     ...    ...   ...   ...
# 5025    NaN    NaN   NaN   NaN
# 5026    NaN    NaN   NaN   NaN
# 5027    NaN    NaN   NaN   NaN
# 5028    NaN    NaN   NaN   NaN
# 5029    NaN    NaN   NaN   NaN
#
# [5030 rows x 3908 columns]

# %%
dataLong = data.melt( id_vars = "AsOnDate", value_vars = data.columns[1:3908]).rename({"value":"ACP", "variable":"CompanyName"}, axis = 1).drop_duplicates().reset_index(drop = True)
dataLong = dataLong.loc[~( (dataLong.duplicated(subset = ["CompanyName", "AsOnDate"], keep = False)) & (dataLong["ACP"].isnull())) ]
dataLong = dataLong.loc[~ dataLong.duplicated(subset = ["CompanyName", "AsOnDate"], keep = False)].drop_duplicates().reset_index(drop = True)

# %%
dataLong
# Out:
#             AsOnDate      CompanyName  ACP
# 0         2004-01-01  20 Microns Ltd.  NaN
# 1         2004-01-02  20 Microns Ltd.  NaN
# 2         2004-01-05  20 Microns Ltd.  NaN
# 3         2004-01-06  20 Microns Ltd.  NaN
# 4         2004-01-07  20 Microns Ltd.  NaN
# ...              ...              ...  ...
# 19640110  2024-03-21             3907  NaN
# 19640111  2024-03-22             3907  NaN
# 19640112  2024-03-26             3907  NaN
# 19640113  2024-03-27             3907  NaN
# 19640114  2024-03-28             3907  NaN
#
# [19640115 rows x 3 columns]

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Data Snipping from either ends

# %%
def dataSnip(frame):
    
    first_valid_idx = frame["ACP"].first_valid_index()
    
    if first_valid_idx is not None:
        frame = frame.loc[first_valid_idx:]
        
    else:
        frame = frame.iloc[0:0]

    last_valid_idx = frame["ACP"].last_valid_index()
    
    if last_valid_idx is not None:
        frame = frame.loc[:last_valid_idx]
        
    else:
        frame = frame
        
    return frame

# %%
dataLong2 = dataLong.groupby(by="CompanyName").progress_apply(dataSnip).reset_index(drop=True)
dataLong2
# Out:
#   0%|          | 0/3907 [00:00<?, ?it/s]
#             AsOnDate         CompanyName    ACP
# 0         2008-10-06     20 Microns Ltd.  16.82
# 1         2008-10-07     20 Microns Ltd.  15.05
# 2         2008-10-08     20 Microns Ltd.  13.25
# 3         2008-10-10     20 Microns Ltd.  11.60
# 4         2008-10-13     20 Microns Ltd.  12.32
# ...              ...                 ...    ...
# 13465088  2024-03-21  Zylog Systems Ltd.   0.35
# 13465089  2024-03-22  Zylog Systems Ltd.   0.35
# 13465090  2024-03-26  Zylog Systems Ltd.   0.35
# 13465091  2024-03-27  Zylog Systems Ltd.   0.35
# 13465092  2024-03-28  Zylog Systems Ltd.   0.35
#
# [13465093 rows x 3 columns]

# %% [markdown]
# ### Inter series NaN values filled as the previous value

# %%
def dataForwardFill(frame):

    frame["ACP"] = frame["ACP"].ffill()
        
    return frame

# %%
dataLong3 = dataLong2.groupby(by="CompanyName").apply(dataForwardFill).reset_index(drop=True)
dataLong3
# Out:
#             AsOnDate         CompanyName    ACP
# 0         2008-10-06     20 Microns Ltd.  16.82
# 1         2008-10-07     20 Microns Ltd.  15.05
# 2         2008-10-08     20 Microns Ltd.  13.25
# 3         2008-10-10     20 Microns Ltd.  11.60
# 4         2008-10-13     20 Microns Ltd.  12.32
# ...              ...                 ...    ...
# 13465088  2024-03-21  Zylog Systems Ltd.   0.35
# 13465089  2024-03-22  Zylog Systems Ltd.   0.35
# 13465090  2024-03-26  Zylog Systems Ltd.   0.35
# 13465091  2024-03-27  Zylog Systems Ltd.   0.35
# 13465092  2024-03-28  Zylog Systems Ltd.   0.35
#
# [13465093 rows x 3 columns]

# %% [markdown]
# ### Result

# %%
dataLong3.ACP.isnull().value_counts()
# Out:
# ACP
# False    13465093
# Name: count, dtype: int64

# %%
closingPrice = dataLong3.copy()

# %% [markdown]
# ## Simple Returns

# %%
def pct_change(frame):
    frame = frame.sort_values(by = ["AsOnDate"])
    frame["pct"] = frame["ACP"].pct_change(fill_method = None)
    return frame

# %%
simpleReturn = closingPrice.groupby("CompanyName").apply(pct_change).reset_index(drop = True)

# %%
simpleReturn["AsOnDate"] = pd.to_datetime(simpleReturn["AsOnDate"], format = "%Y-%m-%d")
simpleReturn = simpleReturn.drop_duplicates().reset_index(drop = True)
simpleReturn
# Out:
#            AsOnDate         CompanyName    ACP       pct
# 0        2008-10-06     20 Microns Ltd.  16.82       NaN
# 1        2008-10-07     20 Microns Ltd.  15.05 -0.105232
# 2        2008-10-08     20 Microns Ltd.  13.25 -0.119601
# 3        2008-10-10     20 Microns Ltd.  11.60 -0.124528
# 4        2008-10-13     20 Microns Ltd.  12.32  0.062069
# ...             ...                 ...    ...       ...
# 13465088 2024-03-21  Zylog Systems Ltd.   0.35  0.000000
# 13465089 2024-03-22  Zylog Systems Ltd.   0.35  0.000000
# 13465090 2024-03-26  Zylog Systems Ltd.   0.35  0.000000
# 13465091 2024-03-27  Zylog Systems Ltd.   0.35  0.000000
# 13465092 2024-03-28  Zylog Systems Ltd.   0.35  0.000000
#
# [13465093 rows x 4 columns]

# %% [markdown]
# ## FF 3 constants

# %%
ff3Const = pd.read_csv(rf"{supporting_folder_path}\2024-03_FourFactors_and_Market_Returns_Daily_SurvivorshipBiasAdjusted.csv")

# %%
ff3Const["date"] = pd.to_datetime(ff3Const["date"], format = "%d-%m-%Y")

# %%
ff3Const = ff3Const.rename({"date":"AsOnDate"}, axis = 1).drop_duplicates().reset_index(drop = True)
ff3Const["RMRF"] = ff3Const["MF"] - ff3Const["RF"]
ff3Const.columns[[0,1,2,3,4,5,6]]
orderedCol = ff3Const.columns[[0, 5, 6, 4, 1, 2]]
ff3ConstOrdered = ff3Const[orderedCol]
ff3ConstOrdered
# Out:
#        AsOnDate        RF      RMRF        MF       SMB       HML
# 0    1993-10-01       NaN       NaN       NaN  1.414154  1.182552
# 1    1993-10-04  0.022014 -0.954330 -0.932316  0.472301  0.371959
# 2    1993-10-05  0.022014 -0.315512 -0.293498  0.046619  0.839734
# 3    1993-10-06  0.022014 -0.352836 -0.330823 -0.085561 -1.492747
# 4    1993-10-07  0.022014  0.360946  0.382959 -0.286668  0.135259
# ...         ...       ...       ...       ...       ...       ...
# 7563 2024-03-21  0.018215  1.441807  1.460021  0.572866  1.270303
# 7564 2024-03-22  0.018215  0.593324  0.611538  0.752002  0.124527
# 7565 2024-03-26  0.072878 -0.044514  0.028364 -1.091597  0.440605
# 7566 2024-03-27  0.018215  0.326702  0.344916 -0.165072 -0.188505
# 7567 2024-03-28  0.018215  0.703054  0.721269 -0.579335 -0.093002
#
# [7568 rows x 6 columns]

# %%
# df = ff3ConstOrdered.copy()
# df["Year"] = float(df["AsOnDate"].year)
# df.groupby(["Year"]).apply(

# %% [markdown]
# ## Merged and Final Data set

# %%
dataMerged1 = simpleReturn.merge(ff3ConstOrdered, on = "AsOnDate", how = "inner").sort_values(["CompanyName", "AsOnDate"]).set_index(["CompanyName", "AsOnDate"]).reset_index().drop_duplicates().reset_index(drop = True)

# %%
dataMerged1
# Out:
#                  CompanyName   AsOnDate    ACP       pct        RF      RMRF  \
# 0            20 Microns Ltd. 2008-10-06  16.82       NaN  0.069713 -6.381449
# 1            20 Microns Ltd. 2008-10-07  15.05 -0.105232  0.023232 -0.669144
# 2            20 Microns Ltd. 2008-10-08  13.25 -0.119601  0.023232 -3.533362
# 3            20 Microns Ltd. 2008-10-10  11.60 -0.124528  0.045520 -7.052324
# 4            20 Microns Ltd. 2008-10-13  12.32  0.062069  0.066863  5.042738
# ...                      ...        ...    ...       ...       ...       ...
# 13465088  Zylog Systems Ltd. 2024-03-21   0.35  0.000000  0.018215  1.441807
# 13465089  Zylog Systems Ltd. 2024-03-22   0.35  0.000000  0.018215  0.593324
# 13465090  Zylog Systems Ltd. 2024-03-26   0.35  0.000000  0.072878 -0.044514
# 13465091  Zylog Systems Ltd. 2024-03-27   0.35  0.000000  0.018215  0.326702
# 13465092  Zylog Systems Ltd. 2024-03-28   0.35  0.000000  0.018215  0.703054
#
#                 MF       SMB       HML
# 0        -6.311735 -0.373052 -0.566450
# 1        -0.645911 -1.502487  0.184699
# 2        -3.510130 -1.780674  0.072932
# 3        -7.006804  0.217126  0.354629
# 4         5.109602 -2.437097  0.145853
# ...            ...       ...       ...
# 13465088  1.460021  0.572866  1.270303
# 13465089  0.611538  0.752002  0.124527
# 13465090  0.028364 -1.091597  0.440605
# 13465091  0.344916 -0.165072 -0.188505
# 13465092  0.721269 -0.579335 -0.093002
#
# [13465093 rows x 9 columns]

# %% [markdown]
# ## Company Keys and Merging with data above

# %%
companyKeys = pd.read_excel(rf"{supporting_folder_path}\Prowess Code_NSE Symbol.xlsx").rename({"Company Name":"CompanyName", "Prowess company code":"ProwessCode", "NSE symbol":"Symbol"}, axis = 1 )

# %%
companyKeys
# Out:
#                                 CompanyName  ProwessCode Symbol
# 0          'K' Steamship Agencies Pvt. Ltd.            3    NaN
# 1      'X'Clusive Business Centre Pvt. Ltd.       307865    NaN
# 2                 1 To 1 Help.Net Pvt. Ltd.       591675    NaN
# 3              10C India Internet Pvt. Ltd.       556976    NaN
# 4           10I Commerce Services Pvt. Ltd.       560502    NaN
# ...                                     ...          ...    ...
# 55307                    Zylog Systems Ltd.       275793  ZYLOG
# 55308       Zyma Laboratories Ltd. [Merged]       275794    NaN
# 55309      Zyphar'S Pharmaceutics Pvt. Ltd.       565342    NaN
# 55310                   Zytel Agencies Ltd.       275795    NaN
# 55311      Zyxel Technology India Pvt. Ltd.       432445    NaN
#
# [55312 rows x 3 columns]

# %%
dataMerged2 = companyKeys.merge(dataMerged1, on = "CompanyName", how = "right").sort_values( by = ["CompanyName", "AsOnDate"])

# %%
# The above are not in the director dataset, so can be ignored
dataMerged2
# Out:
#                  CompanyName  ProwessCode     Symbol   AsOnDate    ACP  \
# 0            20 Microns Ltd.         11.0  20MICRONS 2008-10-06  16.82
# 1            20 Microns Ltd.         11.0  20MICRONS 2008-10-07  15.05
# 2            20 Microns Ltd.         11.0  20MICRONS 2008-10-08  13.25
# 3            20 Microns Ltd.         11.0  20MICRONS 2008-10-10  11.60
# 4            20 Microns Ltd.         11.0  20MICRONS 2008-10-13  12.32
# ...                      ...          ...        ...        ...    ...
# 13465088  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-21   0.35
# 13465089  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-22   0.35
# 13465090  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-26   0.35
# 13465091  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-27   0.35
# 13465092  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-28   0.35
#
#                pct        RF      RMRF        MF       SMB       HML
# 0              NaN  0.069713 -6.381449 -6.311735 -0.373052 -0.566450
# 1        -0.105232  0.023232 -0.669144 -0.645911 -1.502487  0.184699
# 2        -0.119601  0.023232 -3.533362 -3.510130 -1.780674  0.072932
# 3        -0.124528  0.045520 -7.052324 -7.006804  0.217126  0.354629
# 4         0.062069  0.066863  5.042738  5.109602 -2.437097  0.145853
# ...            ...       ...       ...       ...       ...       ...
# 13465088  0.000000  0.018215  1.441807  1.460021  0.572866  1.270303
# 13465089  0.000000  0.018215  0.593324  0.611538  0.752002  0.124527
# 13465090  0.000000  0.072878 -0.044514  0.028364 -1.091597  0.440605
# 13465091  0.000000  0.018215  0.326702  0.344916 -0.165072 -0.188505
# 13465092  0.000000  0.018215  0.703054  0.721269 -0.579335 -0.093002
#
# [13465093 rows x 11 columns]

# %%
dataMerged2["AsOnDate"] = pd.to_datetime(dataMerged2["AsOnDate"], format = "%Y-%m-%d")

# %% [markdown]
# ## Director Appointment Dates

# %%
dir = pd.read_pickle(rf"{import_folder_path}\Main_Director_COMPLETE.pkl")

# %%
dirAppointment = dir.loc[:, ["Symbol", "Appointment Date"]].copy().sort_values( by = ["Symbol", "Appointment Date"]).drop_duplicates().reset_index(drop = True)
dirAppointment
# Out:
#           Symbol Appointment Date
# 0      20MICRONS       1988-03-29
# 1      20MICRONS       1998-07-02
# 2      20MICRONS       2000-04-10
# 3      20MICRONS       2001-01-29
# 4      20MICRONS       2001-02-27
# ...          ...              ...
# 39086      ZYLOG       2014-11-19
# 39087      ZYLOG       2015-08-14
# 39088      ZYLOG       2015-11-25
# 39089      ZYLOG       2016-11-23
# 39090      ZYLOG       2017-02-10
#
# [39091 rows x 2 columns]

# %% [markdown]
# ### Merging Appointment Dates within dataMerged

# %%
dirMerged = dataMerged2.merge(dirAppointment, left_on = ["Symbol", "AsOnDate"], right_on = ["Symbol", "Appointment Date"], how = "left")

# %%
dirMerged
# Out:
#                  CompanyName  ProwessCode     Symbol   AsOnDate    ACP  \
# 0            20 Microns Ltd.         11.0  20MICRONS 2008-10-06  16.82
# 1            20 Microns Ltd.         11.0  20MICRONS 2008-10-07  15.05
# 2            20 Microns Ltd.         11.0  20MICRONS 2008-10-08  13.25
# 3            20 Microns Ltd.         11.0  20MICRONS 2008-10-10  11.60
# 4            20 Microns Ltd.         11.0  20MICRONS 2008-10-13  12.32
# ...                      ...          ...        ...        ...    ...
# 13465088  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-21   0.35
# 13465089  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-22   0.35
# 13465090  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-26   0.35
# 13465091  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-27   0.35
# 13465092  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-28   0.35
#
#                pct        RF      RMRF        MF       SMB       HML  \
# 0              NaN  0.069713 -6.381449 -6.311735 -0.373052 -0.566450
# 1        -0.105232  0.023232 -0.669144 -0.645911 -1.502487  0.184699
# 2        -0.119601  0.023232 -3.533362 -3.510130 -1.780674  0.072932
# 3        -0.124528  0.045520 -7.052324 -7.006804  0.217126  0.354629
# 4         0.062069  0.066863  5.042738  5.109602 -2.437097  0.145853
# ...            ...       ...       ...       ...       ...       ...
# 13465088  0.000000  0.018215  1.441807  1.460021  0.572866  1.270303
# 13465089  0.000000  0.018215  0.593324  0.611538  0.752002  0.124527
# 13465090  0.000000  0.072878 -0.044514  0.028364 -1.091597  0.440605
# 13465091  0.000000  0.018215  0.326702  0.344916 -0.165072 -0.188505
# 13465092  0.000000  0.018215  0.703054  0.721269 -0.579335 -0.093002
#
#          Appointment Date
# 0                     NaT
# 1                     NaT
# 2                     NaT
# 3                     NaT
# 4                     NaT
# ...                   ...
# 13465088              NaT
# 13465089              NaT
# 13465090              NaT
# 13465091              NaT
# 13465092              NaT
#
# [13465093 rows x 12 columns]

# %% [markdown]
# # Organic Functions

# %%
# Just Trying
# FIT OLS, with R style formulas
# res = smf.ols("pct - RF ~ RMRF + SMB + HML", data = dataMerged).fit()

# %%
# res.summary()

# %%
dirMerged.CompanyName.nunique()
# Out:
# 3721

# %% [markdown]
# ## 120 Day Event Study

# %% [markdown]
# ### 120 day window OLS

# %%
# pre-event 120 days
# ignoring companies with <130 data points in full.

def OLS120(frame):
    frame = frame.reset_index(drop = True)
    results = []
    if len(frame) > 151:
        
    #outputFrame = pd.DataFrame( columns = ["Appointment Date", "const", "RMRF", "SMB", "HML", "OLS120_r_squared", "OLS120_adjusted_r_squared", "OLS120_f_p_value"])
        
        for date in range(len(frame["Appointment Date"])) :
            if not pd.isnull(frame.iloc[date]["Appointment Date"]):
                if date >= 151:
                    ols = frame.iloc[ date - 151 : date - 31]
                    exog_vars = ["RMRF", "SMB", "HML"]
                    endog = ols.pct - ols.RF
                    exog = sm.add_constant(ols[exog_vars])
                    rols = sm.OLS(endog, exog)
                    res = rols.fit()
    
                    outputFrame1 = res.params.to_frame().T
                    outputFrame1["OLS120_r_squared"] = res.rsquared
                    outputFrame1["OLS120_adjusted_r_squared"] = res.rsquared_adj
                    outputFrame1["OLS120_f_p_value"] = res.f_pvalue
                    outputFrame1["Appointment Date"] = frame.iloc[date]["Appointment Date"]
    
                    if not outputFrame1.isnull().all().all():  # Ensure it's not all NaNs
                        results.append(outputFrame1)
    
        return pd.concat(results, ignore_index=True) if results else pd.DataFrame()

# %%
ols120Param = dirMerged.groupby(by = ["CompanyName"]).progress_apply(OLS120).reset_index()
ols120Param = ols120Param.rename({"const":"OLS120_intercept", "RMRF":"OLS120_RMRF", "SMB":"OLS120_SMB", "HML":"OLS120_HML"}, axis = 1).drop("level_1", axis = 1)
# Out:
#   0%|          | 0/3721 [00:00<?, ?it/s]

# %%
ols120Param
# Out:
#               CompanyName  OLS120_intercept  OLS120_RMRF  OLS120_SMB  \
# 0         20 Microns Ltd.         -0.013787     0.004889    0.011979
# 1         20 Microns Ltd.         -0.027096     0.010449    0.015732
# 2         20 Microns Ltd.         -0.035800     0.010683    0.006169
# 3         20 Microns Ltd.         -0.024574     0.014913    0.012525
# 4         20 Microns Ltd.         -0.025666     0.014600    0.013163
# ...                   ...               ...          ...         ...
# 20525  Zylog Systems Ltd.         -0.039007     0.014935    0.013479
# 20526  Zylog Systems Ltd.         -0.039050     0.003156    0.011326
# 20527  Zylog Systems Ltd.         -0.034650     0.004784   -0.007787
# 20528  Zylog Systems Ltd.         -0.028118     0.000909   -0.002034
# 20529  Zylog Systems Ltd.         -0.021431     0.005628    0.003575
#
#        OLS120_HML  OLS120_r_squared  OLS120_adjusted_r_squared  \
# 0        0.005721          0.127494                   0.104929
# 1       -0.002440          0.176213                   0.154908
# 2        0.001164          0.121640                   0.098924
# 3        0.005669          0.359471                   0.342905
# 4        0.003634          0.308224                   0.290333
# ...           ...               ...                        ...
# 20525    0.010621          0.124132                   0.101480
# 20526    0.012391          0.156904                   0.135100
# 20527    0.006894          0.045213                   0.020521
# 20528    0.008051          0.057325                   0.032945
# 20529    0.002313          0.020592                  -0.004738
#
#        OLS120_f_p_value Appointment Date
# 0          1.195618e-03       2009-08-27
# 1          4.937782e-05       2011-04-29
# 2          1.725805e-03       2014-08-06
# 3          3.165739e-11       2017-05-04
# 4          2.555217e-09       2019-05-28
# ...                 ...              ...
# 20525      1.476820e-03       2014-02-14
# 20526      1.795678e-04       2014-11-19
# 20527      1.453695e-01       2015-08-14
# 20528      7.591845e-02       2016-11-23
# 20529      4.891967e-01       2017-02-10
#
# [20530 rows x 9 columns]

# %%
ols120 = dirMerged.merge(ols120Param, left_on = ["CompanyName", "AsOnDate"], right_on = ["CompanyName", "Appointment Date"], how = "left").drop(["Appointment Date_x", "Appointment Date_y"], axis = 1)

# %%
ols120.to_pickle(rf"{output_folder_path}\ols120_2.pkl")

# %%
del ols120Param
del ols120

# %% [markdown]
# ## 150 Day Event Study

# %% [markdown]
# ### 150 day window OLS

# %%
# pre-event 150 days
# ignoring companies with <130 data points in full.

def OLS150(frame):
    frame = frame.reset_index(drop = True)
    results = []
    if len(frame) > 181:
    
        #outputFrame = pd.DataFrame( columns = ["Appointment Date", "const", "RMRF", "SMB", "HML", "OLS150_r_squared", "OLS150_adjusted_r_squared", "OLS150_f_p_value"])
        
        for date in range(len(frame["Appointment Date"])) :
            if not pd.isnull(frame.iloc[date]["Appointment Date"]):
                if date >= 181:
                    ols = frame.iloc[ date - 181 : date - 31]
                    exog_vars = ["RMRF", "SMB", "HML"]
                    endog = ols.pct - ols.RF
                    exog = sm.add_constant(ols[exog_vars])
                    rols = sm.OLS(endog, exog)
                    res = rols.fit()
    
                    outputFrame1 = res.params.to_frame().T
                    outputFrame1["OLS150_r_squared"] = res.rsquared
                    outputFrame1["OLS150_adjusted_r_squared"] = res.rsquared_adj
                    outputFrame1["OLS150_f_p_value"] = res.f_pvalue
                    outputFrame1["Appointment Date"] = frame.iloc[date]["Appointment Date"]
    
                    if not outputFrame1.isnull().all().all():  # Ensure it's not all NaNs
                        results.append(outputFrame1)
    
        return pd.concat(results, ignore_index=True) if results else pd.DataFrame()

# %%
ols150Param = dirMerged.groupby(by = ["CompanyName"]).progress_apply(OLS150).reset_index()
ols150Param = ols150Param.rename({"const":"OLS150_intercept", "RMRF":"OLS150_RMRF", "SMB":"OLS150_SMB", "HML":"OLS150_HML"}, axis = 1).drop("level_1", axis = 1)
# Out:
#   0%|          | 0/3721 [00:00<?, ?it/s]

# %%
ols150Param
# Out:
#               CompanyName  OLS150_intercept  OLS150_RMRF  OLS150_SMB  \
# 0         20 Microns Ltd.         -0.017060     0.006434    0.011588
# 1         20 Microns Ltd.         -0.025992     0.008764    0.012305
# 2         20 Microns Ltd.         -0.035619     0.008433    0.006457
# 3         20 Microns Ltd.         -0.023298     0.017193    0.013819
# 4         20 Microns Ltd.         -0.025053     0.015349    0.011943
# ...                   ...               ...          ...         ...
# 20401  Zylog Systems Ltd.         -0.042799     0.017896    0.017156
# 20402  Zylog Systems Ltd.         -0.039048     0.005378    0.008079
# 20403  Zylog Systems Ltd.         -0.034041     0.006057   -0.003198
# 20404  Zylog Systems Ltd.         -0.029026     0.001455   -0.002229
# 20405  Zylog Systems Ltd.         -0.022639     0.005990    0.001212
#
#        OLS150_HML  OLS150_r_squared  OLS150_adjusted_r_squared  \
# 0        0.008780          0.163067                   0.145870
# 1        0.002310          0.158002                   0.140700
# 2        0.001327          0.084912                   0.066109
# 3        0.001278          0.268181                   0.253143
# 4        0.002961          0.361151                   0.348024
# ...           ...               ...                        ...
# 20401    0.007030          0.135180                   0.117410
# 20402    0.012985          0.146228                   0.128685
# 20403    0.008756          0.079905                   0.060999
# 20404    0.005384          0.035742                   0.015929
# 20405    0.004337          0.029050                   0.009099
#
#        OLS150_f_p_value Appointment Date
# 0          9.189620e-06       2009-08-27
# 1          1.406897e-05       2011-04-29
# 2          4.638373e-03       2014-08-06
# 3          6.453930e-10       2017-05-04
# 4          3.667411e-14       2019-05-28
# ...                 ...              ...
# 20401      9.226997e-05       2014-02-14
# 20402      3.741366e-05       2014-11-19
# 20403      6.729009e-03       2015-08-14
# 20404      1.490415e-01       2016-11-23
# 20405      2.290358e-01       2017-02-10
#
# [20406 rows x 9 columns]

# %%
ols150 = dirMerged.merge(ols150Param, left_on = ["CompanyName", "AsOnDate"], right_on = ["CompanyName", "Appointment Date"], how = "left").drop(["Appointment Date_x", "Appointment Date_y"], axis = 1)

# %%
ols150
# Out:
#                  CompanyName  ProwessCode     Symbol   AsOnDate    ACP  \
# 0            20 Microns Ltd.         11.0  20MICRONS 2008-10-06  16.82
# 1            20 Microns Ltd.         11.0  20MICRONS 2008-10-07  15.05
# 2            20 Microns Ltd.         11.0  20MICRONS 2008-10-08  13.25
# 3            20 Microns Ltd.         11.0  20MICRONS 2008-10-10  11.60
# 4            20 Microns Ltd.         11.0  20MICRONS 2008-10-13  12.32
# ...                      ...          ...        ...        ...    ...
# 13465088  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-21   0.35
# 13465089  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-22   0.35
# 13465090  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-26   0.35
# 13465091  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-27   0.35
# 13465092  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-28   0.35
#
#                pct        RF      RMRF        MF       SMB       HML  \
# 0              NaN  0.069713 -6.381449 -6.311735 -0.373052 -0.566450
# 1        -0.105232  0.023232 -0.669144 -0.645911 -1.502487  0.184699
# 2        -0.119601  0.023232 -3.533362 -3.510130 -1.780674  0.072932
# 3        -0.124528  0.045520 -7.052324 -7.006804  0.217126  0.354629
# 4         0.062069  0.066863  5.042738  5.109602 -2.437097  0.145853
# ...            ...       ...       ...       ...       ...       ...
# 13465088  0.000000  0.018215  1.441807  1.460021  0.572866  1.270303
# 13465089  0.000000  0.018215  0.593324  0.611538  0.752002  0.124527
# 13465090  0.000000  0.072878 -0.044514  0.028364 -1.091597  0.440605
# 13465091  0.000000  0.018215  0.326702  0.344916 -0.165072 -0.188505
# 13465092  0.000000  0.018215  0.703054  0.721269 -0.579335 -0.093002
#
#           OLS150_intercept  OLS150_RMRF  OLS150_SMB  OLS150_HML  \
# 0                      NaN          NaN         NaN         NaN
# 1                      NaN          NaN         NaN         NaN
# 2                      NaN          NaN         NaN         NaN
# 3                      NaN          NaN         NaN         NaN
# 4                      NaN          NaN         NaN         NaN
# ...                    ...          ...         ...         ...
# 13465088               NaN          NaN         NaN         NaN
# 13465089               NaN          NaN         NaN         NaN
# 13465090               NaN          NaN         NaN         NaN
# 13465091               NaN          NaN         NaN         NaN
# 13465092               NaN          NaN         NaN         NaN
#
#           OLS150_r_squared  OLS150_adjusted_r_squared  OLS150_f_p_value
# 0                      NaN                        NaN               NaN
# 1                      NaN                        NaN               NaN
# 2                      NaN                        NaN               NaN
# 3                      NaN                        NaN               NaN
# 4                      NaN                        NaN               NaN
# ...                    ...                        ...               ...
# 13465088               NaN                        NaN               NaN
# 13465089               NaN                        NaN               NaN
# 13465090               NaN                        NaN               NaN
# 13465091               NaN                        NaN               NaN
# 13465092               NaN                        NaN               NaN
#
# [13465093 rows x 18 columns]

# %%
ols150.to_pickle(rf"{output_folder_path}\ols150_2.pkl")

# %%
del ols150Param
del ols150

# %% [markdown]
# ## 180 Day Event Study

# %% [markdown]
# ### 180 day window OLS

# %%
# pre-event 180 days
# ignoring companies with <130 data points in full.

def OLS180(frame):
    frame = frame.reset_index(drop = True)
    results = []
    if len(frame) > 211:
    
        #outputFrame = pd.DataFrame( columns = ["Appointment Date", "const", "RMRF", "SMB", "HML", "OLS180_r_squared", "OLS180_adjusted_r_squared", "OLS180_f_p_value"])
        
        for date in range(len(frame["Appointment Date"])) :
            if not pd.isnull(frame.iloc[date]["Appointment Date"]):
                if date >= 211:
                    ols = frame.iloc[ date - 211 : date - 31]
                    exog_vars = ["RMRF", "SMB", "HML"]
                    endog = ols.pct - ols.RF
                    exog = sm.add_constant(ols[exog_vars])
                    rols = sm.OLS(endog, exog)
                    res = rols.fit()
    
                    outputFrame1 = res.params.to_frame().T
                    outputFrame1["OLS180_r_squared"] = res.rsquared
                    outputFrame1["OLS180_adjusted_r_squared"] = res.rsquared_adj
                    outputFrame1["OLS180_f_p_value"] = res.f_pvalue
                    outputFrame1["Appointment Date"] = frame.iloc[date]["Appointment Date"]
    
                    if not outputFrame1.isnull().all().all():  # Ensure it's not all NaNs
                        results.append(outputFrame1)
    
        return pd.concat(results, ignore_index=True) if results else pd.DataFrame()

# %%
ols180Param = dirMerged.groupby(by = ["CompanyName"]).progress_apply(OLS180).reset_index()
ols180Param = ols180Param.rename({"const":"OLS180_intercept", "RMRF":"OLS180_RMRF", "SMB":"OLS180_SMB", "HML":"OLS180_HML"}, axis = 1).drop("level_1", axis = 1)
# Out:
#   0%|          | 0/3721 [00:00<?, ?it/s]

# %%
ols180Param
# Out:
#               CompanyName  OLS180_intercept  OLS180_RMRF  OLS180_SMB  \
# 0         20 Microns Ltd.         -0.019523     0.008528    0.010563
# 1         20 Microns Ltd.         -0.023910     0.008059    0.012570
# 2         20 Microns Ltd.         -0.035592     0.008052    0.006294
# 3         20 Microns Ltd.         -0.023958     0.016109    0.010135
# 4         20 Microns Ltd.         -0.023995     0.016299    0.012980
# ...                   ...               ...          ...         ...
# 20158  Zylog Systems Ltd.         -0.040186     0.018688    0.016930
# 20159  Zylog Systems Ltd.         -0.038065     0.004418    0.009466
# 20160  Zylog Systems Ltd.         -0.033714     0.005668   -0.003566
# 20161  Zylog Systems Ltd.         -0.030886     0.002208   -0.003777
# 20162  Zylog Systems Ltd.         -0.023642     0.003510    0.003016
#
#        OLS180_HML  OLS180_r_squared  OLS180_adjusted_r_squared  \
# 0        0.007012          0.162659                   0.148386
# 1        0.004786          0.128802                   0.113952
# 2        0.002610          0.076637                   0.060898
# 3        0.001335          0.219310                   0.206003
# 4        0.002108          0.329361                   0.317930
# ...           ...               ...                        ...
# 20158    0.006755          0.133560                   0.118791
# 20159    0.014045          0.158676                   0.144335
# 20160    0.012798          0.106314                   0.091081
# 20161    0.004163          0.031962                   0.015461
# 20162    0.005124          0.022382                   0.005718
#
#        OLS180_f_p_value Appointment Date
# 0          7.238692e-07       2009-08-27
# 1          2.125338e-05       2011-04-29
# 2          2.808170e-03       2014-08-06
# 3          1.752317e-09       2017-05-04
# 4          3.320964e-15       2019-05-28
# ...                 ...              ...
# 20158      1.334846e-05       2014-02-14
# 20159      1.086363e-06       2014-11-19
# 20160      1.833697e-04       2015-08-14
# 20161      1.253331e-01       2016-11-23
# 20162      2.619858e-01       2017-02-10
#
# [20163 rows x 9 columns]

# %%
ols180 = dirMerged.merge(ols180Param, left_on = ["CompanyName", "AsOnDate"], right_on = ["CompanyName", "Appointment Date"], how = "left").drop(["Appointment Date_x", "Appointment Date_y"], axis = 1)

# %%
ols180
# Out:
#                  CompanyName  ProwessCode     Symbol   AsOnDate    ACP  \
# 0            20 Microns Ltd.         11.0  20MICRONS 2008-10-06  16.82
# 1            20 Microns Ltd.         11.0  20MICRONS 2008-10-07  15.05
# 2            20 Microns Ltd.         11.0  20MICRONS 2008-10-08  13.25
# 3            20 Microns Ltd.         11.0  20MICRONS 2008-10-10  11.60
# 4            20 Microns Ltd.         11.0  20MICRONS 2008-10-13  12.32
# ...                      ...          ...        ...        ...    ...
# 13465088  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-21   0.35
# 13465089  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-22   0.35
# 13465090  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-26   0.35
# 13465091  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-27   0.35
# 13465092  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-28   0.35
#
#                pct        RF      RMRF        MF       SMB       HML  \
# 0              NaN  0.069713 -6.381449 -6.311735 -0.373052 -0.566450
# 1        -0.105232  0.023232 -0.669144 -0.645911 -1.502487  0.184699
# 2        -0.119601  0.023232 -3.533362 -3.510130 -1.780674  0.072932
# 3        -0.124528  0.045520 -7.052324 -7.006804  0.217126  0.354629
# 4         0.062069  0.066863  5.042738  5.109602 -2.437097  0.145853
# ...            ...       ...       ...       ...       ...       ...
# 13465088  0.000000  0.018215  1.441807  1.460021  0.572866  1.270303
# 13465089  0.000000  0.018215  0.593324  0.611538  0.752002  0.124527
# 13465090  0.000000  0.072878 -0.044514  0.028364 -1.091597  0.440605
# 13465091  0.000000  0.018215  0.326702  0.344916 -0.165072 -0.188505
# 13465092  0.000000  0.018215  0.703054  0.721269 -0.579335 -0.093002
#
#           OLS180_intercept  OLS180_RMRF  OLS180_SMB  OLS180_HML  \
# 0                      NaN          NaN         NaN         NaN
# 1                      NaN          NaN         NaN         NaN
# 2                      NaN          NaN         NaN         NaN
# 3                      NaN          NaN         NaN         NaN
# 4                      NaN          NaN         NaN         NaN
# ...                    ...          ...         ...         ...
# 13465088               NaN          NaN         NaN         NaN
# 13465089               NaN          NaN         NaN         NaN
# 13465090               NaN          NaN         NaN         NaN
# 13465091               NaN          NaN         NaN         NaN
# 13465092               NaN          NaN         NaN         NaN
#
#           OLS180_r_squared  OLS180_adjusted_r_squared  OLS180_f_p_value
# 0                      NaN                        NaN               NaN
# 1                      NaN                        NaN               NaN
# 2                      NaN                        NaN               NaN
# 3                      NaN                        NaN               NaN
# 4                      NaN                        NaN               NaN
# ...                    ...                        ...               ...
# 13465088               NaN                        NaN               NaN
# 13465089               NaN                        NaN               NaN
# 13465090               NaN                        NaN               NaN
# 13465091               NaN                        NaN               NaN
# 13465092               NaN                        NaN               NaN
#
# [13465093 rows x 18 columns]

# %%
ols180.to_pickle(rf"{output_folder_path}\ols180_2.pkl")

# %%
del ols180Param
del ols180

# %% [markdown]
# ## 210 Day Event Study

# %% [markdown]
# ### 210 day window OLS

# %%
# pre-event 210 days
# ignoring companies with <240 data points in full.

def OLS210(frame):
    frame = frame.reset_index(drop = True)
    results = []
    if len(frame) > 241:
    
        #outputFrame = pd.DataFrame( columns = ["Appointment Date", "const", "RMRF", "SMB", "HML", "OLS210_r_squared", "OLS210_adjusted_r_squared", "OLS210_f_p_value"])
        
        for date in range(len(frame["Appointment Date"])) :
            if not pd.isnull(frame.iloc[date]["Appointment Date"]):
                if date >= 241:
                    ols = frame.iloc[ date - 241 : date - 31]
                    exog_vars = ["RMRF", "SMB", "HML"]
                    endog = ols.pct - ols.RF
                    exog = sm.add_constant(ols[exog_vars])
                    rols = sm.OLS(endog, exog)
                    res = rols.fit()
    
                    outputFrame1 = res.params.to_frame().T
                    outputFrame1["OLS210_r_squared"] = res.rsquared
                    outputFrame1["OLS210_adjusted_r_squared"] = res.rsquared_adj
                    outputFrame1["OLS210_f_p_value"] = res.f_pvalue
                    outputFrame1["Appointment Date"] = frame.iloc[date]["Appointment Date"]
    
                    if not outputFrame1.isnull().all().all():  # Ensure it's not all NaNs
                        results.append(outputFrame1)
    
        return pd.concat(results, ignore_index=True) if results else pd.DataFrame()

# %%
ols210Param = dirMerged.groupby(by = ["CompanyName"]).progress_apply(OLS210).reset_index()
ols210Param = ols210Param.rename({"const":"OLS210_intercept", "RMRF":"OLS210_RMRF", "SMB":"OLS210_SMB", "HML":"OLS210_HML"}, axis = 1).drop("level_1", axis = 1)
# Out:
#   0%|          | 0/3721 [00:00<?, ?it/s]

# %%
ols210Param
# Out:
#               CompanyName  OLS210_intercept  OLS210_RMRF  OLS210_SMB  \
# 0         20 Microns Ltd.         -0.022830     0.009052    0.012831
# 1         20 Microns Ltd.         -0.036365     0.006364    0.006151
# 2         20 Microns Ltd.         -0.024819     0.014223    0.010697
# 3         20 Microns Ltd.         -0.024276     0.015716    0.012604
# 4         20 Microns Ltd.         -0.023586     0.014998    0.013664
# ...                   ...               ...          ...         ...
# 20041  Zylog Systems Ltd.         -0.038926     0.017004    0.015859
# 20042  Zylog Systems Ltd.         -0.038244     0.003994    0.009574
# 20043  Zylog Systems Ltd.         -0.034644     0.006125    0.000900
# 20044  Zylog Systems Ltd.         -0.027645     0.001205   -0.002831
# 20045  Zylog Systems Ltd.         -0.025254     0.004525    0.001875
#
#        OLS210_HML  OLS210_r_squared  OLS210_adjusted_r_squared  \
# 0        0.002836          0.131758                   0.119114
# 1        0.003198          0.065439                   0.051829
# 2        0.003037          0.206107                   0.194546
# 3        0.001488          0.334962                   0.325277
# 4        0.007173          0.313242                   0.303240
# ...           ...               ...                        ...
# 20041    0.008312          0.132494                   0.119861
# 20042    0.014231          0.158091                   0.145830
# 20043    0.012578          0.116788                   0.103926
# 20044    0.004653          0.025289                   0.011094
# 20045    0.003494          0.019630                   0.005353
#
#        OLS210_f_p_value Appointment Date
# 0          2.058205e-06       2011-04-29
# 1          2.939000e-03       2014-08-06
# 2          2.516556e-10       2017-05-04
# 3          3.803786e-18       2019-05-28
# 4          1.008558e-16       2023-05-16
# ...                 ...              ...
# 20041      1.890948e-06       2014-02-14
# 20042      9.396380e-08       2014-11-19
# 20043      1.131949e-05       2015-08-14
# 20044      1.518053e-01       2016-11-23
# 20045      2.514974e-01       2017-02-10
#
# [20046 rows x 9 columns]

# %%
ols210 = dirMerged.merge(ols210Param, left_on = ["CompanyName", "AsOnDate"], right_on = ["CompanyName", "Appointment Date"], how = "left").drop(["Appointment Date_x", "Appointment Date_y"], axis = 1)

# %%
ols210
# Out:
#                  CompanyName  ProwessCode     Symbol   AsOnDate    ACP  \
# 0            20 Microns Ltd.         11.0  20MICRONS 2008-10-06  16.82
# 1            20 Microns Ltd.         11.0  20MICRONS 2008-10-07  15.05
# 2            20 Microns Ltd.         11.0  20MICRONS 2008-10-08  13.25
# 3            20 Microns Ltd.         11.0  20MICRONS 2008-10-10  11.60
# 4            20 Microns Ltd.         11.0  20MICRONS 2008-10-13  12.32
# ...                      ...          ...        ...        ...    ...
# 13465088  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-21   0.35
# 13465089  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-22   0.35
# 13465090  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-26   0.35
# 13465091  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-27   0.35
# 13465092  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-28   0.35
#
#                pct        RF      RMRF        MF       SMB       HML  \
# 0              NaN  0.069713 -6.381449 -6.311735 -0.373052 -0.566450
# 1        -0.105232  0.023232 -0.669144 -0.645911 -1.502487  0.184699
# 2        -0.119601  0.023232 -3.533362 -3.510130 -1.780674  0.072932
# 3        -0.124528  0.045520 -7.052324 -7.006804  0.217126  0.354629
# 4         0.062069  0.066863  5.042738  5.109602 -2.437097  0.145853
# ...            ...       ...       ...       ...       ...       ...
# 13465088  0.000000  0.018215  1.441807  1.460021  0.572866  1.270303
# 13465089  0.000000  0.018215  0.593324  0.611538  0.752002  0.124527
# 13465090  0.000000  0.072878 -0.044514  0.028364 -1.091597  0.440605
# 13465091  0.000000  0.018215  0.326702  0.344916 -0.165072 -0.188505
# 13465092  0.000000  0.018215  0.703054  0.721269 -0.579335 -0.093002
#
#           OLS210_intercept  OLS210_RMRF  OLS210_SMB  OLS210_HML  \
# 0                      NaN          NaN         NaN         NaN
# 1                      NaN          NaN         NaN         NaN
# 2                      NaN          NaN         NaN         NaN
# 3                      NaN          NaN         NaN         NaN
# 4                      NaN          NaN         NaN         NaN
# ...                    ...          ...         ...         ...
# 13465088               NaN          NaN         NaN         NaN
# 13465089               NaN          NaN         NaN         NaN
# 13465090               NaN          NaN         NaN         NaN
# 13465091               NaN          NaN         NaN         NaN
# 13465092               NaN          NaN         NaN         NaN
#
#           OLS210_r_squared  OLS210_adjusted_r_squared  OLS210_f_p_value
# 0                      NaN                        NaN               NaN
# 1                      NaN                        NaN               NaN
# 2                      NaN                        NaN               NaN
# 3                      NaN                        NaN               NaN
# 4                      NaN                        NaN               NaN
# ...                    ...                        ...               ...
# 13465088               NaN                        NaN               NaN
# 13465089               NaN                        NaN               NaN
# 13465090               NaN                        NaN               NaN
# 13465091               NaN                        NaN               NaN
# 13465092               NaN                        NaN               NaN
#
# [13465093 rows x 18 columns]

# %%
ols210.to_pickle(rf"{output_folder_path}\ols210_2.pkl")

# %%
ols210
# Out:
#                  CompanyName  ProwessCode     Symbol   AsOnDate    ACP  \
# 0            20 Microns Ltd.         11.0  20MICRONS 2008-10-06  16.82
# 1            20 Microns Ltd.         11.0  20MICRONS 2008-10-07  15.05
# 2            20 Microns Ltd.         11.0  20MICRONS 2008-10-08  13.25
# 3            20 Microns Ltd.         11.0  20MICRONS 2008-10-10  11.60
# 4            20 Microns Ltd.         11.0  20MICRONS 2008-10-13  12.32
# ...                      ...          ...        ...        ...    ...
# 13465088  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-21   0.35
# 13465089  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-22   0.35
# 13465090  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-26   0.35
# 13465091  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-27   0.35
# 13465092  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-28   0.35
#
#                pct        RF      RMRF        MF       SMB       HML  \
# 0              NaN  0.069713 -6.381449 -6.311735 -0.373052 -0.566450
# 1        -0.105232  0.023232 -0.669144 -0.645911 -1.502487  0.184699
# 2        -0.119601  0.023232 -3.533362 -3.510130 -1.780674  0.072932
# 3        -0.124528  0.045520 -7.052324 -7.006804  0.217126  0.354629
# 4         0.062069  0.066863  5.042738  5.109602 -2.437097  0.145853
# ...            ...       ...       ...       ...       ...       ...
# 13465088  0.000000  0.018215  1.441807  1.460021  0.572866  1.270303
# 13465089  0.000000  0.018215  0.593324  0.611538  0.752002  0.124527
# 13465090  0.000000  0.072878 -0.044514  0.028364 -1.091597  0.440605
# 13465091  0.000000  0.018215  0.326702  0.344916 -0.165072 -0.188505
# 13465092  0.000000  0.018215  0.703054  0.721269 -0.579335 -0.093002
#
#           OLS210_intercept  OLS210_RMRF  OLS210_SMB  OLS210_HML  \
# 0                      NaN          NaN         NaN         NaN
# 1                      NaN          NaN         NaN         NaN
# 2                      NaN          NaN         NaN         NaN
# 3                      NaN          NaN         NaN         NaN
# 4                      NaN          NaN         NaN         NaN
# ...                    ...          ...         ...         ...
# 13465088               NaN          NaN         NaN         NaN
# 13465089               NaN          NaN         NaN         NaN
# 13465090               NaN          NaN         NaN         NaN
# 13465091               NaN          NaN         NaN         NaN
# 13465092               NaN          NaN         NaN         NaN
#
#           OLS210_r_squared  OLS210_adjusted_r_squared  OLS210_f_p_value
# 0                      NaN                        NaN               NaN
# 1                      NaN                        NaN               NaN
# 2                      NaN                        NaN               NaN
# 3                      NaN                        NaN               NaN
# 4                      NaN                        NaN               NaN
# ...                    ...                        ...               ...
# 13465088               NaN                        NaN               NaN
# 13465089               NaN                        NaN               NaN
# 13465090               NaN                        NaN               NaN
# 13465091               NaN                        NaN               NaN
# 13465092               NaN                        NaN               NaN
#
# [13465093 rows x 18 columns]
