# %%
# import pandas_datareader.data as web #to collect data
import datetime as dt #to specify start and end dates

# import yfinance as yf

import eventstudy as es
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import scipy.stats as stats
from scipy.spatial.distance import cdist


from sklearn.neighbors import NearestNeighbors

import pandas as pd

import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.regression.rolling import RollingOLS

from patsy import dmatrices
from tqdm.notebook import tqdm
tqdm.pandas()

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
import_folder_path = rf"../[2] Firm Level Wrangling/Firm level Iterative/Firm Lev + Fin/City level/PCA on Firm/firm_pca_output"
output_folder_path = "analysis_outputs"
# pca_input_folder_path = rf"..\..\[IN USE] Rookie Directors\[1.5] Director Skills PCA\director_skills_pca"
supporting_folder_path = "supporting_datafiles"

# %%
firmLev0 = pd.read_pickle(rf"{import_folder_path}/Main_Firm_COMPLETE_Master_FactorScore.pkl")

# %%
# pca = pd.read_pickle(rf"{pca_input_folder_path}\Main_Director_COMPLETE_PCA.pkl")

# firmlev_col = ["PC1_FactorScore_Standardised_mean"]

# def FirmLevelCalc(frame):

#     PC1_FactorScore_Standardised_mean = frame["PC1_FactorScore_Standardised"].mean()

#     # ---------------------------------------------------------------------------------------------------------------------------------------------------

#     output =    PC1_FactorScore_Standardised_mean

#     return output

# firmPCA = pca.groupby(['Symbol', 'AsOnDate']).progress_apply(FirmLevelCalc)

# firmPCA2 = firmPCA.to_frame(name = "PC1_FactorScore_Standardised_mean").reset_index()
# firmLev00 = firmLev0.merge(firmPCA2, on = ["AsOnDate", "Symbol"])

# %%
not_req_cols = ['Academic_mean',
 'Company Business_mean',
 'combined_sustainability_mean',
 'combined_entrepreneurial_mean',
 'combined_compensation_mean',
 'combined_conglomerate_experience_mean',
 'combined_hr_mean',
 'combined_technology_mean',
 'combined_finance_accounting_mean',
 'combined_governance_mean',
 'combined_government_policy_mean',
 'combined_international_mean',
 'combined_leadership_mean',
 'combined_legal_mean',
 'combined_marketing_mean',
 'combined_risk_management_mean',
 'combined_scientific_mean',
 'combined_strategic_planning_mean',
 'combined_manufacturing_supply_chain_mean',
 'combined_leadership_outside_board_mean',
 'skilllist_sustainability_mean',
 'skilllist_entrepreneurial_mean',
 'skilllist_compensation_mean',
 'skilllist_conglomerate_experience_mean',
 'skilllist_hr_mean',
 'skilllist_technology_mean',
 'skilllist_finance_accounting_mean',
 'skilllist_governance_mean',
 'skilllist_government_policy_mean',
 'skilllist_international_mean',
 'skilllist_leadership_mean',
 'skilllist_legal_mean',
 'skilllist_marketing_mean',
 'skilllist_risk_management_mean',
 'skilllist_scientific_mean',
 'skilllist_strategic_planning_mean',
 'skilllist_manufacturing_supply_chain_mean',
 'skill_committee_sustainability_mean',
 'skill_committee_entrepreneurial_mean',
 'skill_committee_compensation_mean',
 'skill_committee_conglomerate_experience_mean',
 'skill_committee_hr_mean',
 'skill_committee_technology_mean',
 'skill_committee_finance_accounting_mean',
 'skill_committee_governance_mean',
 'skill_committee_government_policy_mean',
 'skill_committee_international_mean',
 'skill_committee_leadership_mean',
 'skill_committee_legal_mean',
 'skill_committee_marketing_mean',
 'skill_committee_risk_management_mean',
 'skill_committee_scientific_mean',
 'skill_committee_strategic_planning_mean',
 'skill_committee_manufacturing_supply_chain_mean',
 'skill_committee_leadership_outside_board_mean',
 'board_corporate governance_mean',
 'board_international business_mean',
 'board_industrials_mean',
 'board_utilities_mean',
 'board_finance_mean',
 'board_telecommunication_mean',
 'board_accounts/audit/taxation_mean',
 'board_public policy_mean',
 'board_risk management_mean',
 'board_research & development_mean',
 'board_legal/compliance_mean',
 'board_services_mean',
 'board_marketing_mean',
 'board_healthcare_mean',
 'board_strategy_mean',
 'board_commodities_mean',
 'board_operations_mean',
 'board_diversity_mean',
 'board_diversified_mean',
 'board_corporate social responsibility_mean',
 'board_human resources_mean',
 'board_fast moving consumer goods_mean',
 'board_economics_mean',
 'board_leadership/management_mean',
 'board_energy_mean',
 'board_financial services_mean',
 'board_information technology_mean',
 'board_personal values_mean',
 'board_consumer discretionary_mean',
 'board_supply chain management_mean',
 'CountDirTurnOver_exits_retire_shifted',
 'PercentDirTurnOver_exits_retire_shifted',
 'CountDirTurnOver_real_exits_shifted',
 'PercentDirTurnOver_real_exits_shifted',
 'CountIndepDirTurnOver_exits_retire_shifted',
 'PercentIndepDirTurnOver_exits_retire_shifted',
 'CountIndepDirTurnOver_real_exits_shifted',
 'PercentIndepDirTurnOver_real_exits_shifted',
 'OtherZeroYearIndepPCode',
 'CountOtherZeroYearIndepPCode',
 'OtherFirstYearIndepPCode',
 'CountOtherFirstYearIndepPCode',
 'OtherTwoYearIndepPCode',
 'CountOtherTwoYearIndepPCode',
 'OtherThreeYearIndepPCode',
 'CountOtherThreeYearIndepPCode',
 'TotalIndepPCode',
 'CountTotalIndepPCode',
 'ZeroYearDirCityIndep',
 'FirstYearDirCityIndep',
 'TwoYearDirCityIndep',
 'ThreeYearDirCityIndep',
 'OtherZeroYearPCode',
 'CountOtherZeroYearPCode',
 'OtherFirstYearPCode',
 'CountOtherFirstYearPCode',
 'OtherTwoYearPCode',
 'CountOtherTwoYearPCode',
 'OtherThreeYearPCode',
 'CountOtherThreeYearPCode',
 'TotalPCode',
 'CountTotalPCode',
 'ZeroYearDirCity',
 'FirstYearDirCity',
 'TwoYearDirCity',
 'ThreeYearDirCity',
 'OtherZeroYearPCodeIndepExcl',
 'CountOtherZeroYearPCodeIndepExcl',
 'OtherFirstYearPCodeIndepExcl',
 'CountOtherFirstYearPCodeIndepExcl',
 'OtherTwoYearPCodeIndepExcl',
 'CountOtherTwoYearPCodeIndepExcl',
 'OtherThreeYearPCodeIndepExcl',
 'CountOtherThreeYearPCodeIndepExcl',
 'TotalPCodeIndepExcl',
 'CountTotalPCodeIndepExcl',
 'ZeroYearDirCityIndepExcl',
 'FirstYearDirCityIndepExcl',
 'TwoYearDirCityIndepExcl',
 'ThreeYearDirCityIndepExcl',
 'OtherZeroYearPCodeExcl',
 'CountOtherZeroYearPCodeExcl',
 'OtherFirstYearPCodeExcl',
 'CountOtherFirstYearPCodeExcl',
 'OtherTwoYearPCodeExcl',
 'CountOtherTwoYearPCodeExcl',
 'OtherThreeYearPCodeExcl',
 'CountOtherThreeYearPCodeExcl',
 'TotalPCodeExcl',
 'CountTotalPCodeExcl',
 'ZeroYearDirCityExcl',
 'FirstYearDirCityExcl',
 'TwoYearDirCityExcl',
 'ThreeYearDirCityExcl',
 'ZeroYearDirCityIndepMean',
 'ZeroYearDirCityMean',
 'ZeroYearDirCityIndepExclMean',
 'ZeroYearDirCityExclMean',
 'FirstYearDirCityIndepMean',
 'FirstYearDirCityMean',
 'FirstYearDirCityIndepExclMean',
 'FirstYearDirCityExclMean',
 'TwoYearDirCityIndepMean',
 'TwoYearDirCityMean',
 'TwoYearDirCityIndepExclMean',
 'TwoYearDirCityExclMean',
 'ThreeYearDirCityIndepMean',
 'ThreeYearDirCityMean',
 'ThreeYearDirCityIndepExclMean',
 'ThreeYearDirCityExclMean',
 'CountMBA',
 'PercentMBA',
 'CountIndepMBA',
 'PercentIndepMBA',
 'CountRookieIndepMBA',
 'PercentRookieIndepMBA',
 'CountPhD',
 'PercentPhD',
 'CountIndepPhD',
 'PercentIndepPhD',
 'CountRookieIndepPhD',
 'PercentRookieIndepPhD',
 'CountFinanceXP',
 'PercentFinanceXP',
 'CountIndepFinanceXP',
 'PercentIndepFinanceXP',
 'CountRookieIndepFinanceXP',
 'PercentRookieIndepFinanceXP',
 'CountTechXP',
 'PercentTechXP',
 'CountIndepTechXP',
 'PercentIndepTechXP',
 'CountRookieIndepTechXP',
 'PercentRookieIndepTechXP',
 'CountFinanceSkill',
 'PercentFinanceSkill',
 'CountIndepFinanceSkill',
 'PercentIndepFinanceSkill',
 'CountRookieIndepFinanceSkill',
 'PercentRookieIndepFinanceSkill',
 'CountTechSkill',
 'PercentTechSkill',
 'CountIndepTechSkill',
 'PercentIndepTechSkill',
 'CountRookieIndepTechSkill',
 'PercentRookieIndepTechSkill',
 'CountRelatedIndustryXP',
 'PercentRelatedIndustryXP',
 'CountIndepRelatedIndustryXP',
 'PercentIndepRelatedIndustryXP',
 'CountRookieIndepRelatedIndustryXP',
 'PercentRookieIndepRelatedIndustryXP',
 'CountExecXP',
 'PercentExecXP',
 'CountIndepExecXP',
 'PercentIndepExecXP',
 'CountRookieIndepExecXP',
 'PercentRookieIndepExecXP',
 'CountPublicExecXP',
 'PercentPublicExecXP',
 'CountIndepPublicExecXP',
 'PercentIndepPublicExecXP',
 'CountRookieIndepPublicExecXP',
 'PercentRookieIndepPublicExecXP',
 'CountPrivateExecXP',
 'PercentPrivateExecXP',
 'CountIndepPrivateExecXP',
 'PercentIndepPrivateExecXP',
 'CountRookieIndepPrivateExecXP',
 'PercentRookieIndepPrivateExecXP']

firmLev00 = firmLev0.loc[:, [x for x in firmLev0.columns.to_list() if x not in not_req_cols]].copy()
del firmLev0

# %%
print(firmLev00.info(memory_usage='deep'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28909 entries, 0 to 28908
# Columns: 222 entries, FirmID to Cluster_FactorScore
# dtypes: datetime64[ns](2), float64(121), int32(25), int64(43), object(31)
# memory usage: 140.5 MB
# None

# %%
# FirmLev data wrangling if any:

# %% [markdown]
# # PSM

# %% [markdown]
# ## Verifying and removing those rows with no control data points

# %%
# ln_tobinq_longborrowincl2 = Dependent Variable

 

# Control variables


# percentwomendir
# percentbusydir
# lnboardsize
# percentindep 
# promoters_percent
# nonpromoterinstitutions_percent
# ln_marcap
# debttoequityratio
# ln_firmage
# pb
# hasdualitychairmanmd
# ln_rdtoassets
# pb
# Sample constraints ---> govtdummy==0 & findummy==0 & asonyear>2012

# %% [markdown]
# ## PSM Functions

# %%
def LogitReg(sample, endog_var, exog_var):
    
    # Logit Regression
    endog = sample[[endog_var]]
    exog = sample[exog_var]
    exog = sm.add_constant(exog)
    
    log_reg = sm.Logit(endog, exog).fit()

    propensityScores = log_reg.predict(exog)
    
    return propensityScores

# %%
def MeanDiffTtest(sample, endog_var, exog_var, depVar, firmLev):

    firmLev = firmLev.rename( {depVar:f"{depVar}_2"}, axis = 1)

    colsAdd = []
    for i in range(-1, 4):
        if i != 0:
            colsAdd.append(f"AsOnYear_T+{i}")
            colsAdd.append(f"{depVar}T+{i}")
            if i>0 :
                colsAdd.append(depVar+f"(T+{i}) - (T-1)")

    newFrame= pd.DataFrame(columns = colsAdd, data = 0, index = sample.index, dtype = "float")
    sample = pd.concat([sample, newFrame], axis = 1)
    sample = sample.copy()
    
    for i in range(-1, 4):
        if i != 0:
            sample.loc[:, f"AsOnYear_T+{i}"] = sample["AsOnYear"] + i

    for i in range(-1, 4):
        if i != 0:
            sample.loc[:, f"{depVar}T+{i}"] = sample.merge(firmLev[["Symbol", "AsOnYear", f"{depVar}_2"]].copy(), left_on = ["Symbol", f"AsOnYear_T+{i}"],
                                                          right_on = ["Symbol", "AsOnYear"], how = "left")[f"{depVar}_2"]
    
    for i in range(1, 4):
        if i != 0:
            sample.loc[:, depVar+f"(T+{i}) - (T-1)"] = sample[f"{depVar}T+{i}"] - sample[f"{depVar}T+-1"]

    
    sample = sample.copy()
    
    group1 = sample.loc[ sample[endog_var] == 1].copy()
    group2 = sample.loc[ sample[endog_var] == 0].copy()
    
    t_stat, p_value = stats.ttest_ind(group1[depVar], group2[depVar], equal_var=False)  # Welch’s t-test (default)

    print("\n")
    print(depVar, ":")
    print("\n")
    print("T Statistic:", t_stat, " P Value:",p_value)
    print("Treated Mean:", group1[depVar].mean(), " Control Mean:", group2[depVar].mean(), " Diff:", group1[depVar].mean() - group2[depVar].mean())
    print("Treated N:", len(group1[depVar]), "; Control N:", len(group2[depVar]))
    print("[treated unique = ", len(group1.loc[ :, ["Symbol", "AsOnDate"]].drop_duplicates()), "]",\
          "[control unique = ", len(group2.loc[ :, ["Symbol", "AsOnDate"]].drop_duplicates()), "]"
         )
    print("\n")

    print("━"*120)
    print(f'{"Matching Variable":<40} {"Treatment Firms":<20} {"Control Firms":<20} {"Test of Diff (p value)":<20}')
    print(f'{" ":<40} {"N = " + str(len(group1[depVar])):<20} {"N = " + str(len(group2[depVar])):<20}')
    print("-"*120)

    for var in exog_var:
        treatMean = group1[var].mean()
        controlMean = group2[var].mean()
        p_value = stats.ttest_ind(group1[var], group2[var], equal_var=False)[1]
        print(f'{var:<40} {treatMean:<20.4f} {controlMean:<20.4f} {p_value:<20.4f}')

    print("━"*120, "\n")
    # print(depVar, " across years:\n")

    # for i in range(1,4):
    #     sample = sample.dropna(subset = [depVar+f'(T+{i}) - (T-1)'])
        
    # group1 = sample.loc[ sample[endog_var] == 1].copy()
    # group2 = sample.loc[ sample[endog_var] == 0].copy()

    # print("━"*150, "\n")
    # print(f'{depVar:<40}{" ":<20}{"Treatment Firms":<20}{"Control Firms":<20}{"Difference":<20}{"Test of Diff":<20}{"Test of Diff"}')
    # print(f'{" ":<120}{"(t stat)":<20}{"(p value)":<20}')

    # print("─"*150, "\n")


    # for i in range(1,4):
    #     t_stat2, p_value2 = stats.ttest_ind(group1[depVar+f'(T+{i}) - (T-1)'], group2[depVar+f'(T+{i}) - (T-1)'], equal_var=False)  # Welch’s t-test (default)
        
    #     treatedMean = group1[depVar+f'(T+{i}) - (T-1)'].mean()
    #     controlMean = group2[depVar+f'(T+{i}) - (T-1)'].mean()
    #     diffMean = treatedMean - controlMean

    #     treatedMedian = group1[depVar+f'(T+{i}) - (T-1)'].median()
    #     controlMedian = group2[depVar+f'(T+{i}) - (T-1)'].median()
    #     diffMedian = treatedMedian - controlMedian

    #     print(f'{"Year_T+" + str(i) +" - Year_T-1":<40}{"<MEAN>":<20}{treatedMean:<20.4f}{controlMean:<20.4f}{diffMean:<20.4f}{t_stat2:<20.4f}{p_value2:<20.4f}')

    #     label1 = "Treated N: " + str(len(group1[depVar+f'(T+{i}) - (T-1)']))
    #     label2 = "Control N: " + str(len(group1[depVar+f'(T+{i}) - (T-1)']))
        
    #     print(f'{label1 + " "*5 + label2:<40}{"<MEDIAN>":<20}{treatedMedian:<20.4f}{controlMedian:<20.4f}{diffMedian:<20.4f}')
        
    #     print("-"*150, "\n")
        
    # print("━"*150, "\n")

    # return

# %%
def PsmReplac(sample, endog_var, exog_var, depVar, firmLev):

    # Logit Regression
    sample["propensityScore"] = LogitReg(sample, endog_var, exog_var)

    treated = sample.loc[ sample[endog_var] == 1].copy()
    control = sample.loc[ sample[endog_var] == 0].copy()

    # Nearest Neighbours
    nn = NearestNeighbors(n_neighbors = 1, metric = "euclidean")
    nn.fit(control[["propensityScore"]])

    distances, indices = nn.kneighbors(treated[["propensityScore"]])
    
    matchedControl = control.iloc[indices.flatten()].copy()
    
    matched = pd.concat([treated, matchedControl])
    matched.reset_index(drop=True, inplace=True)

    MeanDiffTtest(matched, endog_var, exog_var, depVar, firmLev)

    return

# %%
# Func PSM non replacement
def PsmNonReplac(sample, endog_var, exog_var, depVar, firmLev):

    # Logit Regression
    sample["propensityScore"] = LogitReg(sample, endog_var, exog_var)

    # Separate treated and control groups
    treated = sample[sample[endog_var] == 1].copy()
    control = sample[sample[endog_var] == 0].copy()
    
    # Compute pairwise distances (absolute difference in propensity scores)
    dist_matrix = cdist(treated[['propensityScore']], control[['propensityScore']], metric='euclidean')
    
    # Match without replacement
    treated_indices = []
    matched_indices = []
    used_control_indices = set()
    
    for i in range(len(treated)):
        if len(used_control_indices) >= len(control):  # Stop if no controls left
            print("Warning: Not enough control units to match all treated units.")
            break
        
        # Get nearest control unit index that hasn't been used
        match_idx = np.argmin(dist_matrix[i])
        
        while match_idx in used_control_indices:  # Ensure it's not already matched
            dist_matrix[i, match_idx] = np.inf  # Temporarily set distance to infinity

            if np.all(dist_matrix[i] == np.inf):  # If all controls are exhausted
                print(f"No available control for treated unit {i}, skipping.")
                match_idx = None
                break
            
            match_idx = np.argmin(dist_matrix[i])
        
        used_control_indices.add(match_idx)
        matched_indices.append(match_idx)
        treated_indices.append(i)
    
    # Retrieve matched units
    matched_control = control.iloc[matched_indices].copy()
    matched_treated = treated.iloc[treated_indices].copy()
    
    # Combine matched treated and control units
    matched_data = pd.concat([matched_treated.reset_index(drop=True), matched_control.reset_index(drop=True)])
    
    # Reset index
    matched_data.reset_index(drop=True, inplace=True)


    # Mean difference and T Test
    MeanDiffTtest(matched_data, endog_var, exog_var, depVar, firmLev)

    return

# %% [markdown]
# # A. Please check the control vars below

# %%
firmLev = firmLev00.copy()

controlVars = [
    "NonpromoterInstitutions_percent", "ln_marcap", "Debt to equity ratio", "ln_CountUniqueSkills",
    
    "Skilllist_FactorScore"
]

dependentVar = "TobinQ_longborrowincl2"

firmLev["HasDualityChairmanMD"] = firmLev["HasDualityChairmanMD"].astype(int)
firmLev.loc[firmLev["RD to Assets"] == 0, "ln_rdtoassets"] = 0


firmLev["NIC_2digit"] = firmLev["NIC code"].dropna().apply(lambda x: x[0:1])
firmLev["NIC_2digit"] = firmLev["NIC_2digit"].astype(float)
firmLev["ln_CountUniqueSkills"] = np.log(1 + firmLev["CountUniqueSkills"])


psmSample = firmLev.loc[ (firmLev["AsOnDate"] >= "2013-03-31")\
& (firmLev["govtdummy"] == 0) & (firmLev["findummy"] == 0) ].dropna(subset = controlVars).dropna(subset = dependentVar).copy()

psmSample["PercentRookieIndep50"] = np.where(psmSample["PercentRookieIndep"]>= 0.5, 1,0)
psmSample["PercentNonRookieIndep50"] = np.where(psmSample["PercentNonRookieIndep"]> 0.5, 1,0)

#psmSample["DummySum"] = psmSample["PercentRookieIndep50"] + psmSample["PercentNonRookieIndep50"]
psmSample["DummySumIndep"] = psmSample["PercentRookieIndep50"] + psmSample["PercentNonRookieIndep50"]

#psmSampleAll = psmSample.loc[ psmSample["DummySum"] == 1 ].reset_index(drop = True)

psmSampleIndep = psmSample.loc[ psmSample["DummySumIndep"] == 1 ].reset_index(drop = True).copy()

# %%
# firmLev2 = firmLev.copy()
# psmSampleIndep2 = psmSampleIndep.copy()

# listCol = [
#     "FirstYearPCodeList", "TwoYearPCodeList", "ThreeYearPCodeList", "PCodeList",
#     "FirstYearIndepPCodeList", "TwoYearIndepPCodeList", "ThreeYearIndepPCodeList", "IndepPCodeList",
#     "OtherFirstYearIndepPCode", "OtherTwoYearIndepPCode", "OtherThreeYearIndepPCode", "TotalIndepPCode",
#     "OtherFirstYearPCode", "OtherTwoYearPCode", "OtherThreeYearPCode", "TotalPCode",
#     "OtherFirstYearPCodeIndepExcl","OtherTwoYearPCodeIndepExcl", "OtherThreeYearPCodeIndepExcl", "TotalPCodeIndepExcl",
#     "OtherFirstYearPCodeExcl", "OtherTwoYearPCodeExcl", "OtherThreeYearPCodeExcl", "TotalPCodeExcl"
# ]

# firmLev2 = firmLev2.drop(listCol, axis = 1)
# psmSampleIndep2 = psmSampleIndep2.drop(listCol, axis = 1)


# firmLev2.to_csv("Main_Firm_PSM Ready_no filter v040425.csv")
# psmSampleIndep2.to_csv("Main_Firm_PSM Ready_filter-Indep_gov_fin v040425.csv")


# # psmSampleAll --> 2101 rows 
# psmSampleIndep --> 1561 rows

# %% [markdown]
# # Version 0: No filtration

# %%
psmSampleIndep0 = psmSampleIndep.copy()

yearDummies0 = pd.get_dummies( psmSampleIndep0["AsOnYear"], prefix = "YearDummy_", drop_first = True, dtype = "int")
psmSampleIndepWithYearDummies0 = pd.concat([psmSampleIndep0, yearDummies0], axis = 1)

industryDummies0 = pd.get_dummies( psmSampleIndep0["NIC_2digit"], prefix = "IndustryDummy_", drop_first = True, dtype = "int")
psmSampleIndepWithYearIndustryDummies0 = pd.concat([psmSampleIndepWithYearDummies0, industryDummies0], axis = 1)

# %% [markdown]
# ## Using Year fixed effects

# %% [markdown]
# ### PSM with replacement

# %%
PsmReplac(psmSampleIndepWithYearDummies0, "PercentRookieIndep50", controlVars + yearDummies0.columns.to_list(), "TobinQ_longborrowincl2", firmLev)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.558511
#          Iterations 6
#
#
# TobinQ_longborrowincl2 :
#
#
# T Statistic: 6.997348217003141  P Value: 3.0306302425831223e-12
# Treated Mean: 1.5836048645433811  Control Mean: 1.0432701124565225  Diff: 0.5403347520868587
# Treated N: 2367 ; Control N: 2367
# [treated unique =  2367 ] [control unique =  1211 ]
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Matching Variable                        Treatment Firms      Control Firms        Test of Diff (p value)
#                                          N = 2367             N = 2367
# ------------------------------------------------------------------------------------------------------------------------
# NonpromoterInstitutions_percent          7.4562               6.9455               0.1172
# ...

# %% [markdown]
# # Version 1: isfamilychairman == 1 OR  isfamilymanaged == 1

# %%
psmSampleIndep1 = psmSampleIndep.loc[ (psmSampleIndep["HasFamilyChairman"]==1) | (psmSampleIndep["IsFamilyManaged"]==1) ].reset_index(drop = True).copy()

yearDummies1 = pd.get_dummies( psmSampleIndep1["AsOnYear"], prefix = "YearDummy_", drop_first = True, dtype = "int")
psmSampleIndepWithYearDummies1 = pd.concat([psmSampleIndep1, yearDummies1], axis = 1)

industryDummies1 = pd.get_dummies( psmSampleIndep1["NIC_2digit"], prefix = "IndustryDummy_", drop_first = True, dtype = "int")
psmSampleIndepWithYearIndustryDummies1 = pd.concat([psmSampleIndepWithYearDummies1, industryDummies1], axis = 1)

# %% [markdown]
# ## Using Year fixed effects

# %% [markdown]
# ### PSM with replacement

# %%
PsmReplac(psmSampleIndepWithYearDummies1, "PercentRookieIndep50", controlVars + yearDummies1.columns.to_list(), "TobinQ_longborrowincl2", firmLev)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.550381
#          Iterations 6
#
#
# TobinQ_longborrowincl2 :
#
#
# T Statistic: 6.937699670055202  P Value: 4.8413174227278366e-12
# Treated Mean: 1.5712705310564092  Control Mean: 1.0331336028588474  Diff: 0.5381369281975619
# Treated N: 1770 ; Control N: 1770
# [treated unique =  1770 ] [control unique =  908 ]
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Matching Variable                        Treatment Firms      Control Firms        Test of Diff (p value)
#                                          N = 1770             N = 1770
# ------------------------------------------------------------------------------------------------------------------------
# NonpromoterInstitutions_percent          6.6664               6.6531               0.9692
# ...

# %% [markdown]
# # Version 2: promoterholding25==1

# %%
psmSampleIndep2 = psmSampleIndep.loc[ (psmSampleIndep["promoterholding25"]==1) ].reset_index(drop = True).copy()

yearDummies2 = pd.get_dummies( psmSampleIndep2["AsOnYear"], prefix = "YearDummy_", drop_first = True, dtype = "int")
psmSampleIndepWithYearDummies2 = pd.concat([psmSampleIndep2, yearDummies2], axis = 1)

industryDummies2 = pd.get_dummies( psmSampleIndep2["NIC_2digit"], prefix = "IndustryDummy_", drop_first = True, dtype = "int")
psmSampleIndepWithYearIndustryDummies2 = pd.concat([psmSampleIndepWithYearDummies2, industryDummies2], axis = 1)

# %% [markdown]
# ## Using Year fixed effects

# %% [markdown]
# ### PSM with replacement

# %%
PsmReplac(psmSampleIndepWithYearDummies2, "PercentRookieIndep50", controlVars + yearDummies2.columns.to_list(), "TobinQ_longborrowincl2", firmLev)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.562838
#          Iterations 6
# TobinQ_longborrowincl2 :
#
#
# T Statistic: 6.946181701177927  P Value: 4.498141092984898e-12
# Treated Mean: 1.6687264849530412  Control Mean: 1.1194484763182502  Diff: 0.549278008634791
# Treated N: 2156 ; Control N: 2156
# [treated unique =  2156 ] [control unique =  1148 ]
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Matching Variable                        Treatment Firms      Control Firms        Test of Diff (p value)
#                                          N = 2156             N = 2156
# ------------------------------------------------------------------------------------------------------------------------
# NonpromoterInstitutions_percent          6.8159               6.5163               0.3166
# ...

# %% [markdown]
# # Version 2: promoterholding == 0 AND HasFamilyChairmanAndCEO ==0

# %%
psmSampleIndep2 = psmSampleIndep.loc[ (psmSampleIndep["promoterholding25"]==0) & (psmSampleIndep["HasFamilyChairmanAndCEO"]==0) ].reset_index(drop = True).copy()

yearDummies2 = pd.get_dummies( psmSampleIndep2["AsOnYear"], prefix = "YearDummy_", drop_first = True, dtype = "int")
psmSampleIndepWithYearDummies2 = pd.concat([psmSampleIndep2, yearDummies2], axis = 1)

industryDummies2 = pd.get_dummies( psmSampleIndep2["NIC_2digit"], prefix = "IndustryDummy_", drop_first = True, dtype = "int")
psmSampleIndepWithYearIndustryDummies2 = pd.concat([psmSampleIndepWithYearDummies2, industryDummies2], axis = 1)

# %% [markdown]
# ## Using Year fixed effects

# %% [markdown]
# ### PSM with replacement

# %%
PsmReplac(psmSampleIndepWithYearDummies2, "PercentRookieIndep50", controlVars + yearDummies2.columns.to_list(), "TobinQ_longborrowincl2", firmLev)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.423670
#          Iterations 7
#
#
# TobinQ_longborrowincl2 :
#
#
# T Statistic: -6.646222282785996  P Value: 1.5269946382714593e-10
# Treated Mean: 0.6743458617902821  Control Mean: 1.4310417882885427  Diff: -0.7566959264982606
# Treated N: 154 ; Control N: 154
# [treated unique =  154 ] [control unique =  43 ]
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Matching Variable                        Treatment Firms      Control Firms        Test of Diff (p value)
#                                          N = 154              N = 154
# ------------------------------------------------------------------------------------------------------------------------
# NonpromoterInstitutions_percent          16.8977              12.9901              0.0983
# ...

# %% [markdown]
# # B. Please check the control vars below

# %%
firmLev = firmLev00.copy()
    
controlVars = ["PercentWomenDir", "PercentBusyDir",
               "LnBoardSize", "PercentIndep",
               "Promoters_percent", "NonpromoterInstitutions_percent",
               "ln_marcap", "ln_rdtoassets", "Debt to equity ratio",
               "ln_CountUniqueSkills"]

dependentVar = "TobinQ_longborrowincl2"

firmLev["HasDualityChairmanMD"] = firmLev["HasDualityChairmanMD"].astype(int)
firmLev.loc[firmLev["RD to Assets"] == 0, "ln_rdtoassets"] = 0


firmLev["NIC_2digit"] = firmLev["NIC code"].dropna().apply(lambda x: x[0:1])
firmLev["NIC_2digit"] = firmLev["NIC_2digit"].astype(float)
firmLev["ln_CountUniqueSkills"] = np.log(1 + firmLev["CountUniqueSkills"])


psmSample = firmLev.loc[ (firmLev["AsOnDate"] >= "2013-03-31")\
& (firmLev["govtdummy"] == 0) & (firmLev["findummy"] == 0) ].dropna(subset = controlVars).dropna(subset = dependentVar).copy()

psmSample["PercentRookieIndep50"] = np.where(psmSample["PercentRookieIndep"]>= 0.5, 1,0)
psmSample["PercentNonRookieIndep50"] = np.where(psmSample["PercentNonRookieIndep"]> 0.5, 1,0)

#psmSample["DummySum"] = psmSample["PercentRookieIndep50"] + psmSample["PercentNonRookieIndep50"]
psmSample["DummySumIndep"] = psmSample["PercentRookieIndep50"] + psmSample["PercentNonRookieIndep50"]

#psmSampleAll = psmSample.loc[ psmSample["DummySum"] == 1 ].reset_index(drop = True)

psmSampleIndep = psmSample.loc[ psmSample["DummySumIndep"] == 1 ].reset_index(drop = True).copy()

# %% [markdown]
# # Version 0: No filtration

# %%
psmSampleIndep0 = psmSampleIndep.copy()

yearDummies0 = pd.get_dummies( psmSampleIndep0["AsOnYear"], prefix = "YearDummy_", drop_first = True, dtype = "int")
psmSampleIndepWithYearDummies0 = pd.concat([psmSampleIndep0, yearDummies0], axis = 1)

industryDummies0 = pd.get_dummies( psmSampleIndep0["NIC_2digit"], prefix = "IndustryDummy_", drop_first = True, dtype = "int")
psmSampleIndepWithYearIndustryDummies0 = pd.concat([psmSampleIndepWithYearDummies0, industryDummies0], axis = 1)

# %% [markdown]
# ## Using Year fixed effects

# %% [markdown]
# ### PSM with replacement

# %%
PsmReplac(psmSampleIndepWithYearDummies0, "PercentRookieIndep50", controlVars + yearDummies0.columns.to_list(), "TobinQ_longborrowincl2", firmLev)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.407605
#          Iterations 7
#
#
# TobinQ_longborrowincl2 :
#
#
# T Statistic: 8.209810108504024  P Value: 2.928538057089527e-16
# Treated Mean: 1.5917223856650842  Control Mean: 0.947326458926687  Diff: 0.6443959267383972
# Treated N: 2345 ; Control N: 2345
# [treated unique =  2345 ] [control unique =  813 ]
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Matching Variable                        Treatment Firms      Control Firms        Test of Diff (p value)
#                                          N = 2345             N = 2345
# ------------------------------------------------------------------------------------------------------------------------
# PercentWomenDir                          0.1904               0.2771               0.0000
# ...

# %% [markdown]
# # Version 1: isfamilychairman == 1 OR  isfamilymanaged == 1

# %%
psmSampleIndep1 = psmSampleIndep.loc[ (psmSampleIndep["HasFamilyChairman"]==1) | (psmSampleIndep["IsFamilyManaged"]==1) ].reset_index(drop = True).copy()

yearDummies1 = pd.get_dummies( psmSampleIndep1["AsOnYear"], prefix = "YearDummy_", drop_first = True, dtype = "int")
psmSampleIndepWithYearDummies1 = pd.concat([psmSampleIndep1, yearDummies1], axis = 1)

industryDummies1 = pd.get_dummies( psmSampleIndep1["NIC_2digit"], prefix = "IndustryDummy_", drop_first = True, dtype = "int")
psmSampleIndepWithYearIndustryDummies1 = pd.concat([psmSampleIndepWithYearDummies1, industryDummies1], axis = 1)

# %% [markdown]
# ## Using Year fixed effects

# %% [markdown]
# ### PSM with replacement

# %%
PsmReplac(psmSampleIndepWithYearDummies1, "PercentRookieIndep50", controlVars + yearDummies1.columns.to_list(), "TobinQ_longborrowincl2", firmLev)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.313261
#          Iterations 8
#
#
# TobinQ_longborrowincl2 :
#
#
# T Statistic: 1.689504347245676  P Value: 0.09179574205996423
# Treated Mean: 2.2331460517384407  Control Mean: 1.8902884127713175  Diff: 0.3428576389671232
# Treated N: 308 ; Control N: 308
# [treated unique =  308 ] [control unique =  132 ]
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Matching Variable                        Treatment Firms      Control Firms        Test of Diff (p value)
#                                          N = 308              N = 308
# ------------------------------------------------------------------------------------------------------------------------
# PercentWomenDir                          0.1637               0.1425               0.0103
# ...

# %% [markdown]
# # Version 2: promoterholding25==1

# %%
psmSampleIndep2 = psmSampleIndep.loc[ (psmSampleIndep["promoterholding25"]==1) ].reset_index(drop = True).copy()

yearDummies2 = pd.get_dummies( psmSampleIndep2["AsOnYear"], prefix = "YearDummy_", drop_first = True, dtype = "int")
psmSampleIndepWithYearDummies2 = pd.concat([psmSampleIndep2, yearDummies2], axis = 1)

industryDummies2 = pd.get_dummies( psmSampleIndep2["NIC_2digit"], prefix = "IndustryDummy_", drop_first = True, dtype = "int")
psmSampleIndepWithYearIndustryDummies2 = pd.concat([psmSampleIndepWithYearDummies2, industryDummies2], axis = 1)

# %% [markdown]
# ## Using Year fixed effects

# %% [markdown]
# ### PSM with replacement

# %%
PsmReplac(psmSampleIndepWithYearDummies2, "PercentRookieIndep50", controlVars + yearDummies2.columns.to_list(), "TobinQ_longborrowincl2", firmLev)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.304894
#          Iterations 8
#
#
# TobinQ_longborrowincl2 :
#
#
# T Statistic: 7.170165614322594  P Value: 2.846366338671039e-12
# Treated Mean: 2.3295582245307176  Control Mean: 1.0742307997527738  Diff: 1.2553274247779438
# Treated N: 366 ; Control N: 366
# [treated unique =  366 ] [control unique =  157 ]
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Matching Variable                        Treatment Firms      Control Firms        Test of Diff (p value)
#                                          N = 366              N = 366
# ------------------------------------------------------------------------------------------------------------------------
# PercentWomenDir                          0.1729               0.2250               0.0000
# ...

# %% [markdown]
# # Version 2: promoterholding == 0 AND HasFamilyChairmanAndCEO ==0

# %%
psmSampleIndep2 = psmSampleIndep.loc[ (psmSampleIndep["promoterholding25"]==0) & (psmSampleIndep["HasFamilyChairmanAndCEO"]==0) ].reset_index(drop = True).copy()

yearDummies2 = pd.get_dummies( psmSampleIndep2["AsOnYear"], prefix = "YearDummy_", drop_first = True, dtype = "int")
psmSampleIndepWithYearDummies2 = pd.concat([psmSampleIndep2, yearDummies2], axis = 1)

industryDummies2 = pd.get_dummies( psmSampleIndep2["NIC_2digit"], prefix = "IndustryDummy_", drop_first = True, dtype = "int")
psmSampleIndepWithYearIndustryDummies2 = pd.concat([psmSampleIndepWithYearDummies2, industryDummies2], axis = 1)

# %% [markdown]
# ## Using Year fixed effects

# %% [markdown]
# ### PSM with replacement

# %%
PsmReplac(psmSampleIndepWithYearDummies2, "PercentRookieIndep50", controlVars + yearDummies2.columns.to_list(), "TobinQ_longborrowincl2", firmLev)
# Out:
# /home/leshleon/projects/Rookie Directors Project/.venv/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:2385: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /home/leshleon/projects/Rookie Directors Project/.venv/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:2443: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q * linpred)))
# ...
#          Current function value: inf
#          Iterations: 35
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 PsmReplac(psmSampleIndepWithYearDummies2, "PercentRookieIndep50", controlVars + yearDummies2.columns.to_list(), "TobinQ_longborrowincl2", firmLev)
#
# Cell In[16], line 4, in PsmReplac(sample, endog_var, exog_var, depVar, firmLev)
#       1 def PsmReplac(sample, endog_var, exog_var, depVar, firmLev):
#       2
# ...
