# %%
import pandas_datareader.data as web #to collect data
import datetime as dt #to specify start and end dates

# import yfinance as yf

import eventstudy as es
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns


import pandas as pd

import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.regression.rolling import RollingOLS

from patsy import dmatrices
from tqdm.notebook import tqdm
tqdm.pandas()

pd.set_option('display.max_columns', 500)

# %%
import_folder_path = "car_output1"
output_folder_path = "car_output2"
supporting_folder_path = "supporting_datafiles"

# %% [markdown]
# ## 120 CAR Data Reading

# %%
ols120 = pd.read_pickle(rf"{import_folder_path}\ols120_2.pkl")

# %% [markdown]
# ## 120 CAR Calc

# %%
ols120CAR = ols120.sort_values(by = ["CompanyName", "AsOnDate"])
ols120CAR
# Out:
#                  CompanyName  ProwessCode     Symbol   AsOnDate    ACP  \
# 0            20 Microns Ltd.         11.0  20MICRONS 2008-10-06  16.82
# 1            20 Microns Ltd.         11.0  20MICRONS 2008-10-07  15.05
# 2            20 Microns Ltd.         11.0  20MICRONS 2008-10-08  13.25
# 3            20 Microns Ltd.         11.0  20MICRONS 2008-10-10  11.60
# 4            20 Microns Ltd.         11.0  20MICRONS 2008-10-13  12.32
# ...                      ...          ...        ...        ...    ...
# 13465088  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-21   0.35
# 13465089  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-22   0.35
# 13465090  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-26   0.35
# 13465091  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-27   0.35
# 13465092  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-28   0.35
#
#                pct        RF      RMRF        MF       SMB       HML  \
# 0              NaN  0.069713 -6.381449 -6.311735 -0.373052 -0.566450
# 1        -0.105232  0.023232 -0.669144 -0.645911 -1.502487  0.184699
# 2        -0.119601  0.023232 -3.533362 -3.510130 -1.780674  0.072932
# 3        -0.124528  0.045520 -7.052324 -7.006804  0.217126  0.354629
# 4         0.062069  0.066863  5.042738  5.109602 -2.437097  0.145853
# ...            ...       ...       ...       ...       ...       ...
# 13465088  0.000000  0.018215  1.441807  1.460021  0.572866  1.270303
# 13465089  0.000000  0.018215  0.593324  0.611538  0.752002  0.124527
# 13465090  0.000000  0.072878 -0.044514  0.028364 -1.091597  0.440605
# 13465091  0.000000  0.018215  0.326702  0.344916 -0.165072 -0.188505
# 13465092  0.000000  0.018215  0.703054  0.721269 -0.579335 -0.093002
#
#           OLS120_intercept  OLS120_RMRF  OLS120_r_squared  \
# 0                      NaN          NaN               NaN
# 1                      NaN          NaN               NaN
# 2                      NaN          NaN               NaN
# 3                      NaN          NaN               NaN
# 4                      NaN          NaN               NaN
# ...                    ...          ...               ...
# 13465088               NaN          NaN               NaN
# 13465089               NaN          NaN               NaN
# 13465090               NaN          NaN               NaN
# 13465091               NaN          NaN               NaN
# 13465092               NaN          NaN               NaN
#
#           OLS120_adjusted_r_squared  OLS120_f_p_value
# 0                               NaN               NaN
# 1                               NaN               NaN
# 2                               NaN               NaN
# 3                               NaN               NaN
# 4                               NaN               NaN
# ...                             ...               ...
# 13465088                        NaN               NaN
# 13465089                        NaN               NaN
# 13465090                        NaN               NaN
# 13465091                        NaN               NaN
# 13465092                        NaN               NaN
#
# [13465093 rows x 16 columns]

# %%
# FUNCTION

# def CAR120(frame):
#     if ((~frame.OLS120_intercept.isnull().any()) == True):
#         ER = frame.RF + (frame.RMRF * frame.OLS120_RMRF) + (frame.SMB * frame.OLS120_SMB) + (frame.HML * frame.OLS120_HML) + frame.OLS120_intercept
#         AR = frame.pct - ER
#         return AR.sum()
#     else: 
#         return np.NaN

    # for i in range(len(frame)):
    #     if (i>0) & ( i< len(frame)-1) :
    #         coeff120CAR = np.array([frame.iloc[i]["OLS120_RMRF"], frame.iloc[i]["OLS120_SMB"],
    #                                 frame.iloc[i]["OLS120_HML"], 1, frame.iloc[i]["OLS120_intercept"]])

    #         event120CAR3 = np.array(frame.loc[ [i-1, i, i+1], ["RMRF", "SMB", "HML", "RF"]],)
    #         event120CAR3 = [np.append(item, 1) for item in event120CAR3]

    #         ER = np.matmul(event120CAR3, coeff120CAR)

    #         actualReturns = np.array([frame.iloc[i-1]["pct"], frame.iloc[i]["pct"], frame.iloc[i+1]["pct"]])

    #         AR = np.subtract( actualReturns, ER )

    #         output120CAR3.loc[i, ["120CAR3"]] = AR.sum()


    
        # if i>=2:
        #     frame["120CAR5"].iloc[i] = CAR120(frame.iloc[ i-2 : i+2 ])
        # if i>=3:
        #     frame["120CAR7"].iloc[i] = CAR120(frame.iloc[ i-3 : i+3 ])
        # if i>=5:
        #     frame["120CAR11"].iloc[i] = CAR120(frame.iloc[ i-5 : i+5 ])

        

def CAR(frame):

    outputFrame = pd.DataFrame( index = frame.index)

        
    # 3 Days
    
    outputFrame["pct_cen3sum"] = frame["pct"].rolling(window = 3, min_periods = 3, center = True).sum()
    
    outputFrame["RF_cen3sum"] = frame["RF"].rolling(window = 3, min_periods = 3, center = True).sum()
    
    outputFrame["RMRF_cen3sum"] = frame["RMRF"].rolling(window = 3, min_periods = 3, center = True).sum()
    
    # 5 Days
    
    outputFrame["pct_cen5sum"] = frame["pct"].rolling(window = 5, min_periods = 5, center = True).sum()
    
    outputFrame["RF_cen5sum"] = frame["RF"].rolling(window = 5, min_periods = 5, center = True).sum()
    
    outputFrame["RMRF_cen5sum"] = frame["RMRF"].rolling(window = 5, min_periods = 5, center = True).sum()
    
    
    # 7 Days
    
    outputFrame["pct_cen7sum"] = frame["pct"].rolling(window = 7, min_periods = 7, center = True).sum()
    
    outputFrame["RF_cen7sum"] = frame["RF"].rolling(window = 7, min_periods = 7, center = True).sum()
    
    outputFrame["RMRF_cen7sum"] = frame["RMRF"].rolling(window = 7, min_periods = 7, center = True).sum()
    
    
    # 11 Days
    
    outputFrame["pct_cen11sum"] = frame["pct"].rolling(window = 11, min_periods = 11, center = True).sum()
    
    outputFrame["RF_cen11sum"] = frame["RF"].rolling(window = 11, min_periods = 11, center = True).sum()
    
    outputFrame["RMRF_cen11sum"] = frame["RMRF"].rolling(window = 11, min_periods = 11, center = True).sum()
    
    
    return outputFrame

# %%
result120CAR = ols120CAR.sort_values(by = ["CompanyName", "AsOnDate"]).groupby(by = "CompanyName").progress_apply(CAR)
# Out:
#   0%|          | 0/3721 [00:00<?, ?it/s]
# C:\Users\SHIVAM\anaconda3\Lib\site-packages\tqdm\std.py:805: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return getattr(df, df_function)(wrapper, **kwargs)

# %%
result120CAR
# Out:
#                              pct_cen3sum  RF_cen3sum  RMRF_cen3sum  \
# CompanyName
# 20 Microns Ltd.    0                 NaN         NaN           NaN
#                    1                 NaN    0.116178    -10.583954
#                    2           -0.349361    0.091985    -11.254830
#                    3           -0.182061    0.135616     -5.542948
#                    4           -0.163920    0.134667     -0.834193
# ...                                  ...         ...           ...
# Zylog Systems Ltd. 13465088     0.000000    0.054643      2.222872
#                    13465089     0.000000    0.109307      1.990617
#                    13465090     0.000000    0.109307      0.875511
#                    13465091     0.000000    0.109307      0.985242
#                    13465092          NaN         NaN           NaN
#
#                              pct_cen5sum  RF_cen5sum  RMRF_cen5sum  \
# CompanyName
# 20 Microns Ltd.    0                 NaN         NaN           NaN
#                    1                 NaN         NaN           NaN
#                    2                 NaN    0.228562    -12.593540
#                    3           -0.388754    0.181132     -5.036699
#                    4           -0.183251    0.180182     -9.543586
# ...                                  ...         ...           ...
# Zylog Systems Ltd. 13465088     0.000000    0.145734      0.669402
#                    13465089     0.000000    0.145735      2.505059
#                    13465090     0.000000    0.145736      3.020372
#                    13465091          NaN         NaN           NaN
#                    13465092          NaN         NaN           NaN
#
#                              pct_cen7sum  RF_cen7sum  RMRF_cen7sum  \
# CompanyName
# 20 Microns Ltd.    0                 NaN         NaN           NaN
#                    1                 NaN         NaN           NaN
#                    2                 NaN         NaN           NaN
#                    3                 NaN    0.273128    -16.594178
#                    4           -0.163688    0.225697    -12.320480
# ...                                  ...         ...           ...
# Zylog Systems Ltd. 13465088     0.000000    0.218599      1.086124
#                    13465089     0.000000    0.182163      1.699158
#                    13465090          NaN         NaN           NaN
#                    13465091          NaN         NaN           NaN
#                    13465092          NaN         NaN           NaN
#
#                              pct_cen11sum  RF_cen11sum  RMRF_cen11sum
# CompanyName
# 20 Microns Ltd.    0                  NaN          NaN            NaN
#                    1                  NaN          NaN            NaN
#                    2                  NaN          NaN            NaN
#                    3                  NaN          NaN            NaN
#                    4                  NaN          NaN            NaN
# ...                                   ...          ...            ...
# Zylog Systems Ltd. 13465088           NaN          NaN            NaN
#                    13465089           NaN          NaN            NaN
#                    13465090           NaN          NaN            NaN
#                    13465091           NaN          NaN            NaN
#                    13465092           NaN          NaN            NaN
#
# [13465093 rows x 12 columns]

# %%
result120CAR2 = result120CAR.reset_index(level = 0).drop("CompanyName", axis = 1)
result120CAR2
# Out:
#           pct_cen3sum  RF_cen3sum  RMRF_cen3sum  pct_cen5sum  RF_cen5sum  \
# 0                 NaN         NaN           NaN          NaN         NaN
# 1                 NaN    0.116178    -10.583954          NaN         NaN
# 2           -0.349361    0.091985    -11.254830          NaN    0.228562
# 3           -0.182061    0.135616     -5.542948    -0.388754    0.181132
# 4           -0.163920    0.134667     -0.834193    -0.183251    0.180182
# ...               ...         ...           ...          ...         ...
# 13465088     0.000000    0.054643      2.222872     0.000000    0.145734
# 13465089     0.000000    0.109307      1.990617     0.000000    0.145735
# 13465090     0.000000    0.109307      0.875511     0.000000    0.145736
# 13465091     0.000000    0.109307      0.985242          NaN         NaN
# 13465092          NaN         NaN           NaN          NaN         NaN
#
#           RMRF_cen5sum  pct_cen7sum  RF_cen7sum  RMRF_cen7sum  pct_cen11sum  \
# 0                  NaN          NaN         NaN           NaN           NaN
# 1                  NaN          NaN         NaN           NaN           NaN
# 2           -12.593540          NaN         NaN           NaN           NaN
# 3            -5.036699          NaN    0.273128    -16.594178           NaN
# 4            -9.543586    -0.163688    0.225697    -12.320480           NaN
# ...                ...          ...         ...           ...           ...
# 13465088      0.669402     0.000000    0.218599      1.086124           NaN
# 13465089      2.505059     0.000000    0.182163      1.699158           NaN
# 13465090      3.020372          NaN         NaN           NaN           NaN
# 13465091           NaN          NaN         NaN           NaN           NaN
# 13465092           NaN          NaN         NaN           NaN           NaN
#
#           RF_cen11sum  RMRF_cen11sum
# 0                 NaN            NaN
# 1                 NaN            NaN
# 2                 NaN            NaN
# 3                 NaN            NaN
# 4                 NaN            NaN
# ...               ...            ...
# 13465088          NaN            NaN
# 13465089          NaN            NaN
# 13465090          NaN            NaN
# 13465091          NaN            NaN
# 13465092          NaN            NaN
#
# [13465093 rows x 12 columns]

# %%
output120CAR = pd.concat([ols120CAR, result120CAR2], axis = 1)

# %%
output120CAR.columns
# Out:
# Index(['CompanyName', 'ProwessCode', 'Symbol', 'AsOnDate', 'ACP', 'pct', 'RF',
#        'RMRF', 'MF', 'SMB', 'HML', 'OLS120_intercept', 'OLS120_RMRF',
#        'OLS120_r_squared', 'OLS120_adjusted_r_squared', 'OLS120_f_p_value',
#        'pct_cen3sum', 'RF_cen3sum', 'RMRF_cen3sum', 'pct_cen5sum',
#        'RF_cen5sum', 'RMRF_cen5sum', 'pct_cen7sum', 'RF_cen7sum',
#        'RMRF_cen7sum', 'pct_cen11sum', 'RF_cen11sum', 'RMRF_cen11sum'],
#       dtype='object')

# %%
output120CAR["120CAR3"] = output120CAR["pct_cen3sum"] - (output120CAR["RF_cen3sum"] + 
                          
                          output120CAR["OLS120_RMRF"]*output120CAR["RMRF_cen3sum"] +  
                          output120CAR["OLS120_intercept"]*3 )

# %%
output120CAR["120CAR5"] = output120CAR["pct_cen5sum"] - (output120CAR["RF_cen5sum"] + 
                          
                          output120CAR["OLS120_RMRF"]*output120CAR["RMRF_cen5sum"] + 
                          output120CAR["OLS120_intercept"]*3 )

# %%
output120CAR["120CAR7"] = output120CAR["pct_cen7sum"] - (output120CAR["RF_cen7sum"] + 
                          
                          output120CAR["OLS120_RMRF"]*output120CAR["RMRF_cen7sum"] + 
                          output120CAR["OLS120_intercept"]*3 )

# %%
output120CAR["120CAR11"] = output120CAR["pct_cen11sum"] - (output120CAR["RF_cen11sum"] + 
                          
                          output120CAR["OLS120_RMRF"]*output120CAR["RMRF_cen11sum"] + 
                          output120CAR["OLS120_intercept"]*3 )

# %%
output120CAR
# Out:
#                  CompanyName  ProwessCode     Symbol   AsOnDate    ACP  \
# 0            20 Microns Ltd.         11.0  20MICRONS 2008-10-06  16.82
# 1            20 Microns Ltd.         11.0  20MICRONS 2008-10-07  15.05
# 2            20 Microns Ltd.         11.0  20MICRONS 2008-10-08  13.25
# 3            20 Microns Ltd.         11.0  20MICRONS 2008-10-10  11.60
# 4            20 Microns Ltd.         11.0  20MICRONS 2008-10-13  12.32
# ...                      ...          ...        ...        ...    ...
# 13465088  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-21   0.35
# 13465089  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-22   0.35
# 13465090  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-26   0.35
# 13465091  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-27   0.35
# 13465092  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-28   0.35
#
#                pct        RF      RMRF        MF       SMB       HML  \
# 0              NaN  0.069713 -6.381449 -6.311735 -0.373052 -0.566450
# 1        -0.105232  0.023232 -0.669144 -0.645911 -1.502487  0.184699
# 2        -0.119601  0.023232 -3.533362 -3.510130 -1.780674  0.072932
# 3        -0.124528  0.045520 -7.052324 -7.006804  0.217126  0.354629
# 4         0.062069  0.066863  5.042738  5.109602 -2.437097  0.145853
# ...            ...       ...       ...       ...       ...       ...
# 13465088  0.000000  0.018215  1.441807  1.460021  0.572866  1.270303
# 13465089  0.000000  0.018215  0.593324  0.611538  0.752002  0.124527
# 13465090  0.000000  0.072878 -0.044514  0.028364 -1.091597  0.440605
# 13465091  0.000000  0.018215  0.326702  0.344916 -0.165072 -0.188505
# 13465092  0.000000  0.018215  0.703054  0.721269 -0.579335 -0.093002
#
#           OLS120_intercept  OLS120_RMRF  OLS120_r_squared  \
# 0                      NaN          NaN               NaN
# 1                      NaN          NaN               NaN
# 2                      NaN          NaN               NaN
# 3                      NaN          NaN               NaN
# 4                      NaN          NaN               NaN
# ...                    ...          ...               ...
# 13465088               NaN          NaN               NaN
# 13465089               NaN          NaN               NaN
# 13465090               NaN          NaN               NaN
# 13465091               NaN          NaN               NaN
# 13465092               NaN          NaN               NaN
#
#           OLS120_adjusted_r_squared  OLS120_f_p_value  pct_cen3sum  \
# 0                               NaN               NaN          NaN
# 1                               NaN               NaN          NaN
# 2                               NaN               NaN    -0.349361
# 3                               NaN               NaN    -0.182061
# 4                               NaN               NaN    -0.163920
# ...                             ...               ...          ...
# 13465088                        NaN               NaN     0.000000
# 13465089                        NaN               NaN     0.000000
# 13465090                        NaN               NaN     0.000000
# 13465091                        NaN               NaN     0.000000
# 13465092                        NaN               NaN          NaN
#
#           RF_cen3sum  RMRF_cen3sum  pct_cen5sum  RF_cen5sum  RMRF_cen5sum  \
# 0                NaN           NaN          NaN         NaN           NaN
# 1           0.116178    -10.583954          NaN         NaN           NaN
# 2           0.091985    -11.254830          NaN    0.228562    -12.593540
# 3           0.135616     -5.542948    -0.388754    0.181132     -5.036699
# 4           0.134667     -0.834193    -0.183251    0.180182     -9.543586
# ...              ...           ...          ...         ...           ...
# 13465088    0.054643      2.222872     0.000000    0.145734      0.669402
# 13465089    0.109307      1.990617     0.000000    0.145735      2.505059
# 13465090    0.109307      0.875511     0.000000    0.145736      3.020372
# 13465091    0.109307      0.985242          NaN         NaN           NaN
# 13465092         NaN           NaN          NaN         NaN           NaN
#
#           pct_cen7sum  RF_cen7sum  RMRF_cen7sum  pct_cen11sum  RF_cen11sum  \
# 0                 NaN         NaN           NaN           NaN          NaN
# 1                 NaN         NaN           NaN           NaN          NaN
# 2                 NaN         NaN           NaN           NaN          NaN
# 3                 NaN    0.273128    -16.594178           NaN          NaN
# 4           -0.163688    0.225697    -12.320480           NaN          NaN
# ...               ...         ...           ...           ...          ...
# 13465088     0.000000    0.218599      1.086124           NaN          NaN
# 13465089     0.000000    0.182163      1.699158           NaN          NaN
# 13465090          NaN         NaN           NaN           NaN          NaN
# 13465091          NaN         NaN           NaN           NaN          NaN
# 13465092          NaN         NaN           NaN           NaN          NaN
#
#           RMRF_cen11sum  120CAR3  120CAR5  120CAR7  120CAR11
# 0                   NaN      NaN      NaN      NaN       NaN
# 1                   NaN      NaN      NaN      NaN       NaN
# 2                   NaN      NaN      NaN      NaN       NaN
# 3                   NaN      NaN      NaN      NaN       NaN
# 4                   NaN      NaN      NaN      NaN       NaN
# ...                 ...      ...      ...      ...       ...
# 13465088            NaN      NaN      NaN      NaN       NaN
# 13465089            NaN      NaN      NaN      NaN       NaN
# 13465090            NaN      NaN      NaN      NaN       NaN
# 13465091            NaN      NaN      NaN      NaN       NaN
# 13465092            NaN      NaN      NaN      NaN       NaN
#
# [13465093 rows x 32 columns]

# %%
output120CAR_2 = output120CAR.dropna(subset = "120CAR3").reset_index(drop = True).sort_values( by = ["CompanyName", "AsOnDate"] ).reset_index(drop = True)

# %%
output120CAR_2
# Out:
#               CompanyName  ProwessCode     Symbol   AsOnDate    ACP       pct  \
# 0         20 Microns Ltd.         11.0  20MICRONS 2009-07-29  12.60 -0.017161
# 1         20 Microns Ltd.         11.0  20MICRONS 2009-07-30  12.50 -0.007937
# 2         20 Microns Ltd.         11.0  20MICRONS 2009-08-27  15.78  0.000000
# 3         20 Microns Ltd.         11.0  20MICRONS 2011-04-29  20.48 -0.016330
# 4         20 Microns Ltd.         11.0  20MICRONS 2014-08-06  31.15 -0.011111
# ...                   ...          ...        ...        ...    ...       ...
# 34561  Zylog Systems Ltd.     275793.0      ZYLOG 2015-08-14   5.40  0.018868
# 34562  Zylog Systems Ltd.     275793.0      ZYLOG 2016-06-30   3.90  0.040000
# 34563  Zylog Systems Ltd.     275793.0      ZYLOG 2016-08-12   3.15 -0.045455
# 34564  Zylog Systems Ltd.     275793.0      ZYLOG 2016-11-23   4.25 -0.022989
# 34565  Zylog Systems Ltd.     275793.0      ZYLOG 2017-02-10   5.05  0.041237
#
#              RF      RMRF        MF       SMB       HML  OLS120_intercept  \
# 0      0.008824 -1.187185 -1.178360  0.280266 -0.219265         -0.016130
# 1      0.008824  0.606603  0.615428 -0.050968  0.076723         -0.015122
# 2      0.009040  0.358959  0.368000  0.741064  0.945923         -0.012672
# 3      0.019851 -0.595940 -0.576089 -0.572908 -0.607305         -0.027709
# 4      0.022705 -0.690542 -0.667837  1.023324 -0.182707         -0.034611
# ...         ...       ...       ...       ...       ...               ...
# 34561  0.019213  1.546309  1.565522 -0.064032  1.416502         -0.034858
# 34562  0.017832  1.065921  1.083753 -0.809196  1.214423         -0.025075
# 34563  0.017406  0.290292  0.307698 -0.979555  0.368906         -0.028892
# 34564  0.015807  1.118596  1.134402  0.640072  1.506896         -0.028364
# 34565  0.016234 -0.042546 -0.026312  0.204566 -0.756680         -0.021262
#
#        OLS120_RMRF  OLS120_r_squared  OLS120_adjusted_r_squared  \
# 0         0.003310          0.028601                   0.020369
# 1         0.003345          0.029881                   0.021660
# 2         0.002374          0.016580                   0.008245
# 3         0.010815          0.109751                   0.102207
# 4         0.011129          0.088050                   0.080322
# ...            ...               ...                        ...
# 34561     0.007051          0.027495                   0.019253
# 34562     0.002161          0.002523                  -0.005930
# 34563     0.001915          0.002487                  -0.005967
# 34564     0.006545          0.020030                   0.011725
# 34565     0.007799          0.018200                   0.009880
#
#        OLS120_f_p_value  pct_cen3sum  RF_cen3sum  RMRF_cen3sum  pct_cen5sum  \
# 0              0.064814    -0.056087    0.026473      0.029619     0.062901
# 1              0.059023     0.000503    0.026365      0.353815    -0.004746
# 2              0.161037    -0.020051    0.027229      2.106517     0.095158
# 3              0.000219     0.135960    0.099051     -2.055273     0.068979
# 4              0.000998    -0.012716    0.068115     -0.250139    -0.004716
# ...                 ...          ...         ...           ...          ...
# 34561          0.070302    -0.113635    0.096076      0.535057    -0.246220
# 34562          0.585868     0.080218    0.053601      2.887396     0.066209
# 34563          0.588591    -0.061816    0.104454      0.121902    -0.076967
# 34564          0.123099     0.000961    0.047206      1.977908    -0.072004
# 34565          0.141807     0.060639    0.081176      0.077238     0.082365
#
#        RF_cen5sum  RMRF_cen5sum  pct_cen7sum  RF_cen7sum  RMRF_cen7sum  \
# 0        0.061664      1.417488     0.109739    0.096639      4.283657
# 1        0.061340      2.473169     0.130467    0.096531      2.484330
# 2        0.063718      2.095520     0.186179    0.099990      3.145210
# 3        0.138538     -4.268887     0.048651    0.178026     -4.607642
# 4        0.158951     -0.558310    -0.002971    0.249787     -1.450041
# ...           ...           ...          ...         ...           ...
# 34561    0.134926     -0.534668    -0.291712    0.173777     -0.844522
# 34562    0.125044      3.865878     0.082876    0.196699      3.920553
# 34563    0.139266     -1.118332    -0.061583    0.174078     -0.982620
# 34564    0.110227      1.658702    -0.103254    0.172820      2.689463
# 34565    0.113856     -0.002369     0.044815    0.146536     -1.621023
#
#        pct_cen11sum  RF_cen11sum  RMRF_cen11sum   120CAR3   120CAR5   120CAR7  \
# 0          0.181963     0.131720       6.025389 -0.034268  0.044935  0.047310
# 1          0.143027     0.131612       4.768098  0.018321 -0.028993  0.070992
# 2          0.367888     0.136368       5.257233 -0.014266  0.064480  0.116737
# 3          0.066696     0.316887      -5.076389  0.142262  0.059733  0.003581
# 4         -0.040029     0.363107      -1.042710  0.025785 -0.053622 -0.132788
# ...             ...          ...            ...       ...       ...       ...
# 34561     -0.274151     0.291613      -3.755096 -0.108911 -0.272803 -0.354960
# 34562      0.017235     0.285435       1.822980  0.095600  0.008034 -0.047072
# 34563     -0.059889     0.313345       0.230677 -0.079827 -0.127416 -0.147103
# 34564      0.087481     0.236579       3.498012  0.025903 -0.107993 -0.208582
# 34565      0.055863     0.245226       0.610712  0.042647  0.032314 -0.025294
#
#        120CAR11
# 0      0.078687
# 1      0.040831
# 2      0.257054
# 3     -0.112165
# 4     -0.287699
# ...         ...
# 34561 -0.434712
# 34562 -0.196916
# 34563 -0.286999
# 34564 -0.086900
# 34565 -0.130340
#
# [34566 rows x 32 columns]

# %%
output120CAR_2.to_pickle(rf"{output_folder_path}\output120CAR_2.pkl")

# %%
del ols120
del ols120CAR

del result120CAR2
del result120CAR

del output120CAR
del output120CAR_2

# %% [markdown]
# ## 150 CAR Data Reading

# %%
ols150 = pd.read_pickle(rf"{import_folder_path}\ols150_2.pkl")

# %% [markdown]
# ## 150 CAR Calc

# %%
ols150CAR = ols150.sort_values(by = ["CompanyName", "AsOnDate"])
ols150CAR
# Out:
#                  CompanyName  ProwessCode     Symbol   AsOnDate    ACP  \
# 0            20 Microns Ltd.         11.0  20MICRONS 2008-10-06  16.82
# 1            20 Microns Ltd.         11.0  20MICRONS 2008-10-07  15.05
# 2            20 Microns Ltd.         11.0  20MICRONS 2008-10-08  13.25
# 3            20 Microns Ltd.         11.0  20MICRONS 2008-10-10  11.60
# 4            20 Microns Ltd.         11.0  20MICRONS 2008-10-13  12.32
# ...                      ...          ...        ...        ...    ...
# 13465088  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-21   0.35
# 13465089  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-22   0.35
# 13465090  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-26   0.35
# 13465091  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-27   0.35
# 13465092  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-28   0.35
#
#                pct        RF      RMRF        MF       SMB       HML  \
# 0              NaN  0.069713 -6.381449 -6.311735 -0.373052 -0.566450
# 1        -0.105232  0.023232 -0.669144 -0.645911 -1.502487  0.184699
# 2        -0.119601  0.023232 -3.533362 -3.510130 -1.780674  0.072932
# 3        -0.124528  0.045520 -7.052324 -7.006804  0.217126  0.354629
# 4         0.062069  0.066863  5.042738  5.109602 -2.437097  0.145853
# ...            ...       ...       ...       ...       ...       ...
# 13465088  0.000000  0.018215  1.441807  1.460021  0.572866  1.270303
# 13465089  0.000000  0.018215  0.593324  0.611538  0.752002  0.124527
# 13465090  0.000000  0.072878 -0.044514  0.028364 -1.091597  0.440605
# 13465091  0.000000  0.018215  0.326702  0.344916 -0.165072 -0.188505
# 13465092  0.000000  0.018215  0.703054  0.721269 -0.579335 -0.093002
#
#           OLS150_intercept  OLS150_RMRF  OLS150_r_squared  \
# 0                      NaN          NaN               NaN
# 1                      NaN          NaN               NaN
# 2                      NaN          NaN               NaN
# 3                      NaN          NaN               NaN
# 4                      NaN          NaN               NaN
# ...                    ...          ...               ...
# 13465088               NaN          NaN               NaN
# 13465089               NaN          NaN               NaN
# 13465090               NaN          NaN               NaN
# 13465091               NaN          NaN               NaN
# 13465092               NaN          NaN               NaN
#
#           OLS150_adjusted_r_squared  OLS150_f_p_value
# 0                               NaN               NaN
# 1                               NaN               NaN
# 2                               NaN               NaN
# 3                               NaN               NaN
# 4                               NaN               NaN
# ...                             ...               ...
# 13465088                        NaN               NaN
# 13465089                        NaN               NaN
# 13465090                        NaN               NaN
# 13465091                        NaN               NaN
# 13465092                        NaN               NaN
#
# [13465093 rows x 16 columns]

# %%
# FUNCTION

# def CAR150(frame):
#     if ((~frame.OLS150_intercept.isnull().any()) == True):
#         ER = frame.RF + (frame.RMRF * frame.OLS150_RMRF) + (frame.SMB * frame.OLS150_SMB) + (frame.HML * frame.OLS150_HML) + frame.OLS150_intercept
#         AR = frame.pct - ER
#         return AR.sum()
#     else: 
#         return np.NaN

    # for i in range(len(frame)):
    #     if (i>0) & ( i< len(frame)-1) :
    #         coeff150CAR = np.array([frame.iloc[i]["OLS150_RMRF"], frame.iloc[i]["OLS150_SMB"],
    #                                 frame.iloc[i]["OLS150_HML"], 1, frame.iloc[i]["OLS150_intercept"]])

    #         event150CAR3 = np.array(frame.loc[ [i-1, i, i+1], ["RMRF", "SMB", "HML", "RF"]],)
    #         event150CAR3 = [np.append(item, 1) for item in event150CAR3]

    #         ER = np.matmul(event150CAR3, coeff150CAR)

    #         actualReturns = np.array([frame.iloc[i-1]["pct"], frame.iloc[i]["pct"], frame.iloc[i+1]["pct"]])

    #         AR = np.subtract( actualReturns, ER )

    #         output150CAR3.loc[i, ["150CAR3"]] = AR.sum()


    
        # if i>=2:
        #     frame["150CAR5"].iloc[i] = CAR150(frame.iloc[ i-2 : i+2 ])
        # if i>=3:
        #     frame["150CAR7"].iloc[i] = CAR150(frame.iloc[ i-3 : i+3 ])
        # if i>=5:
        #     frame["150CAR11"].iloc[i] = CAR150(frame.iloc[ i-5 : i+5 ])

        

def CAR(frame):

    outputFrame = pd.DataFrame( index = frame.index)

        
    # 3 Days
    
    outputFrame["pct_cen3sum"] = frame["pct"].rolling(window = 3, min_periods = 3, center = True).sum()
    
    outputFrame["RF_cen3sum"] = frame["RF"].rolling(window = 3, min_periods = 3, center = True).sum()
    
    outputFrame["RMRF_cen3sum"] = frame["RMRF"].rolling(window = 3, min_periods = 3, center = True).sum()
    
    
    # 5 Days
    
    outputFrame["pct_cen5sum"] = frame["pct"].rolling(window = 5, min_periods = 5, center = True).sum()
    
    outputFrame["RF_cen5sum"] = frame["RF"].rolling(window = 5, min_periods = 5, center = True).sum()
    
    outputFrame["RMRF_cen5sum"] = frame["RMRF"].rolling(window = 5, min_periods = 5, center = True).sum()
        
    
    # 7 Days
    
    outputFrame["pct_cen7sum"] = frame["pct"].rolling(window = 7, min_periods = 7, center = True).sum()
    
    outputFrame["RF_cen7sum"] = frame["RF"].rolling(window = 7, min_periods = 7, center = True).sum()
    
    outputFrame["RMRF_cen7sum"] = frame["RMRF"].rolling(window = 7, min_periods = 7, center = True).sum()
        
    
    # 11 Days
    
    outputFrame["pct_cen11sum"] = frame["pct"].rolling(window = 11, min_periods = 11, center = True).sum()
    
    outputFrame["RF_cen11sum"] = frame["RF"].rolling(window = 11, min_periods = 11, center = True).sum()
    
    outputFrame["RMRF_cen11sum"] = frame["RMRF"].rolling(window = 11, min_periods = 11, center = True).sum()
        
    return outputFrame

# %%
result150CAR = ols150CAR.sort_values(by = ["CompanyName", "AsOnDate"]).groupby(by = "CompanyName").progress_apply(CAR)
# Out:
#   0%|          | 0/3721 [00:00<?, ?it/s]
# C:\Users\SHIVAM\anaconda3\Lib\site-packages\tqdm\std.py:805: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return getattr(df, df_function)(wrapper, **kwargs)

# %%
result150CAR
# Out:
#                              pct_cen3sum  RF_cen3sum  RMRF_cen3sum  \
# CompanyName
# 20 Microns Ltd.    0                 NaN         NaN           NaN
#                    1                 NaN    0.116178    -10.583954
#                    2           -0.349361    0.091985    -11.254830
#                    3           -0.182061    0.135616     -5.542948
#                    4           -0.163920    0.134667     -0.834193
# ...                                  ...         ...           ...
# Zylog Systems Ltd. 13465088     0.000000    0.054643      2.222872
#                    13465089     0.000000    0.109307      1.990617
#                    13465090     0.000000    0.109307      0.875511
#                    13465091     0.000000    0.109307      0.985242
#                    13465092          NaN         NaN           NaN
#
#                              pct_cen5sum  RF_cen5sum  RMRF_cen5sum  \
# CompanyName
# 20 Microns Ltd.    0                 NaN         NaN           NaN
#                    1                 NaN         NaN           NaN
#                    2                 NaN    0.228562    -12.593540
#                    3           -0.388754    0.181132     -5.036699
#                    4           -0.183251    0.180182     -9.543586
# ...                                  ...         ...           ...
# Zylog Systems Ltd. 13465088     0.000000    0.145734      0.669402
#                    13465089     0.000000    0.145735      2.505059
#                    13465090     0.000000    0.145736      3.020372
#                    13465091          NaN         NaN           NaN
#                    13465092          NaN         NaN           NaN
#
#                              pct_cen7sum  RF_cen7sum  RMRF_cen7sum  \
# CompanyName
# 20 Microns Ltd.    0                 NaN         NaN           NaN
#                    1                 NaN         NaN           NaN
#                    2                 NaN         NaN           NaN
#                    3                 NaN    0.273128    -16.594178
#                    4           -0.163688    0.225697    -12.320480
# ...                                  ...         ...           ...
# Zylog Systems Ltd. 13465088     0.000000    0.218599      1.086124
#                    13465089     0.000000    0.182163      1.699158
#                    13465090          NaN         NaN           NaN
#                    13465091          NaN         NaN           NaN
#                    13465092          NaN         NaN           NaN
#
#                              pct_cen11sum  RF_cen11sum  RMRF_cen11sum
# CompanyName
# 20 Microns Ltd.    0                  NaN          NaN            NaN
#                    1                  NaN          NaN            NaN
#                    2                  NaN          NaN            NaN
#                    3                  NaN          NaN            NaN
#                    4                  NaN          NaN            NaN
# ...                                   ...          ...            ...
# Zylog Systems Ltd. 13465088           NaN          NaN            NaN
#                    13465089           NaN          NaN            NaN
#                    13465090           NaN          NaN            NaN
#                    13465091           NaN          NaN            NaN
#                    13465092           NaN          NaN            NaN
#
# [13465093 rows x 12 columns]

# %%
result150CAR2 = result150CAR.reset_index(level = 0).drop("CompanyName", axis = 1)
result150CAR2
# Out:
#           pct_cen3sum  RF_cen3sum  RMRF_cen3sum  pct_cen5sum  RF_cen5sum  \
# 0                 NaN         NaN           NaN          NaN         NaN
# 1                 NaN    0.116178    -10.583954          NaN         NaN
# 2           -0.349361    0.091985    -11.254830          NaN    0.228562
# 3           -0.182061    0.135616     -5.542948    -0.388754    0.181132
# 4           -0.163920    0.134667     -0.834193    -0.183251    0.180182
# ...               ...         ...           ...          ...         ...
# 13465088     0.000000    0.054643      2.222872     0.000000    0.145734
# 13465089     0.000000    0.109307      1.990617     0.000000    0.145735
# 13465090     0.000000    0.109307      0.875511     0.000000    0.145736
# 13465091     0.000000    0.109307      0.985242          NaN         NaN
# 13465092          NaN         NaN           NaN          NaN         NaN
#
#           RMRF_cen5sum  pct_cen7sum  RF_cen7sum  RMRF_cen7sum  pct_cen11sum  \
# 0                  NaN          NaN         NaN           NaN           NaN
# 1                  NaN          NaN         NaN           NaN           NaN
# 2           -12.593540          NaN         NaN           NaN           NaN
# 3            -5.036699          NaN    0.273128    -16.594178           NaN
# 4            -9.543586    -0.163688    0.225697    -12.320480           NaN
# ...                ...          ...         ...           ...           ...
# 13465088      0.669402     0.000000    0.218599      1.086124           NaN
# 13465089      2.505059     0.000000    0.182163      1.699158           NaN
# 13465090      3.020372          NaN         NaN           NaN           NaN
# 13465091           NaN          NaN         NaN           NaN           NaN
# 13465092           NaN          NaN         NaN           NaN           NaN
#
#           RF_cen11sum  RMRF_cen11sum
# 0                 NaN            NaN
# 1                 NaN            NaN
# 2                 NaN            NaN
# 3                 NaN            NaN
# 4                 NaN            NaN
# ...               ...            ...
# 13465088          NaN            NaN
# 13465089          NaN            NaN
# 13465090          NaN            NaN
# 13465091          NaN            NaN
# 13465092          NaN            NaN
#
# [13465093 rows x 12 columns]

# %%
output150CAR = pd.concat([ols150CAR, result150CAR2], axis = 1)
output150CAR
# Out:
#                  CompanyName  ProwessCode     Symbol   AsOnDate    ACP  \
# 0            20 Microns Ltd.         11.0  20MICRONS 2008-10-06  16.82
# 1            20 Microns Ltd.         11.0  20MICRONS 2008-10-07  15.05
# 2            20 Microns Ltd.         11.0  20MICRONS 2008-10-08  13.25
# 3            20 Microns Ltd.         11.0  20MICRONS 2008-10-10  11.60
# 4            20 Microns Ltd.         11.0  20MICRONS 2008-10-13  12.32
# ...                      ...          ...        ...        ...    ...
# 13465088  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-21   0.35
# 13465089  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-22   0.35
# 13465090  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-26   0.35
# 13465091  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-27   0.35
# 13465092  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-28   0.35
#
#                pct        RF      RMRF        MF       SMB       HML  \
# 0              NaN  0.069713 -6.381449 -6.311735 -0.373052 -0.566450
# 1        -0.105232  0.023232 -0.669144 -0.645911 -1.502487  0.184699
# 2        -0.119601  0.023232 -3.533362 -3.510130 -1.780674  0.072932
# 3        -0.124528  0.045520 -7.052324 -7.006804  0.217126  0.354629
# 4         0.062069  0.066863  5.042738  5.109602 -2.437097  0.145853
# ...            ...       ...       ...       ...       ...       ...
# 13465088  0.000000  0.018215  1.441807  1.460021  0.572866  1.270303
# 13465089  0.000000  0.018215  0.593324  0.611538  0.752002  0.124527
# 13465090  0.000000  0.072878 -0.044514  0.028364 -1.091597  0.440605
# 13465091  0.000000  0.018215  0.326702  0.344916 -0.165072 -0.188505
# 13465092  0.000000  0.018215  0.703054  0.721269 -0.579335 -0.093002
#
#           OLS150_intercept  OLS150_RMRF  OLS150_r_squared  \
# 0                      NaN          NaN               NaN
# 1                      NaN          NaN               NaN
# 2                      NaN          NaN               NaN
# 3                      NaN          NaN               NaN
# 4                      NaN          NaN               NaN
# ...                    ...          ...               ...
# 13465088               NaN          NaN               NaN
# 13465089               NaN          NaN               NaN
# 13465090               NaN          NaN               NaN
# 13465091               NaN          NaN               NaN
# 13465092               NaN          NaN               NaN
#
#           OLS150_adjusted_r_squared  OLS150_f_p_value  pct_cen3sum  \
# 0                               NaN               NaN          NaN
# 1                               NaN               NaN          NaN
# 2                               NaN               NaN    -0.349361
# 3                               NaN               NaN    -0.182061
# 4                               NaN               NaN    -0.163920
# ...                             ...               ...          ...
# 13465088                        NaN               NaN     0.000000
# 13465089                        NaN               NaN     0.000000
# 13465090                        NaN               NaN     0.000000
# 13465091                        NaN               NaN     0.000000
# 13465092                        NaN               NaN          NaN
#
#           RF_cen3sum  RMRF_cen3sum  pct_cen5sum  RF_cen5sum  RMRF_cen5sum  \
# 0                NaN           NaN          NaN         NaN           NaN
# 1           0.116178    -10.583954          NaN         NaN           NaN
# 2           0.091985    -11.254830          NaN    0.228562    -12.593540
# 3           0.135616     -5.542948    -0.388754    0.181132     -5.036699
# 4           0.134667     -0.834193    -0.183251    0.180182     -9.543586
# ...              ...           ...          ...         ...           ...
# 13465088    0.054643      2.222872     0.000000    0.145734      0.669402
# 13465089    0.109307      1.990617     0.000000    0.145735      2.505059
# 13465090    0.109307      0.875511     0.000000    0.145736      3.020372
# 13465091    0.109307      0.985242          NaN         NaN           NaN
# 13465092         NaN           NaN          NaN         NaN           NaN
#
#           pct_cen7sum  RF_cen7sum  RMRF_cen7sum  pct_cen11sum  RF_cen11sum  \
# 0                 NaN         NaN           NaN           NaN          NaN
# 1                 NaN         NaN           NaN           NaN          NaN
# 2                 NaN         NaN           NaN           NaN          NaN
# 3                 NaN    0.273128    -16.594178           NaN          NaN
# 4           -0.163688    0.225697    -12.320480           NaN          NaN
# ...               ...         ...           ...           ...          ...
# 13465088     0.000000    0.218599      1.086124           NaN          NaN
# 13465089     0.000000    0.182163      1.699158           NaN          NaN
# 13465090          NaN         NaN           NaN           NaN          NaN
# 13465091          NaN         NaN           NaN           NaN          NaN
# 13465092          NaN         NaN           NaN           NaN          NaN
#
#           RMRF_cen11sum
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 13465088            NaN
# 13465089            NaN
# 13465090            NaN
# 13465091            NaN
# 13465092            NaN
#
# [13465093 rows x 28 columns]

# %%
output150CAR.columns
# Out:
# Index(['CompanyName', 'ProwessCode', 'Symbol', 'AsOnDate', 'ACP', 'pct', 'RF',
#        'RMRF', 'MF', 'SMB', 'HML', 'OLS150_intercept', 'OLS150_RMRF',
#        'OLS150_r_squared', 'OLS150_adjusted_r_squared', 'OLS150_f_p_value',
#        'pct_cen3sum', 'RF_cen3sum', 'RMRF_cen3sum', 'pct_cen5sum',
#        'RF_cen5sum', 'RMRF_cen5sum', 'pct_cen7sum', 'RF_cen7sum',
#        'RMRF_cen7sum', 'pct_cen11sum', 'RF_cen11sum', 'RMRF_cen11sum'],
#       dtype='object')

# %%
output150CAR["150CAR3"] = output150CAR["pct_cen3sum"] - (output150CAR["RF_cen3sum"] + 
                          
                          output150CAR["OLS150_RMRF"]*output150CAR["RMRF_cen3sum"] + 
                          output150CAR["OLS150_intercept"]*3 )

# %%
output150CAR["150CAR5"] = output150CAR["pct_cen5sum"] - (output150CAR["RF_cen5sum"] + 
                          
                          output150CAR["OLS150_RMRF"]*output150CAR["RMRF_cen5sum"] + 
                          output150CAR["OLS150_intercept"]*3 )

# %%
output150CAR["150CAR7"] = output150CAR["pct_cen7sum"] - (output150CAR["RF_cen7sum"] + 
                          
                          output150CAR["OLS150_RMRF"]*output150CAR["RMRF_cen7sum"] + 
                          output150CAR["OLS150_intercept"]*3 )

# %%
output150CAR["150CAR11"] = output150CAR["pct_cen11sum"] - (output150CAR["RF_cen11sum"] + 
                          
                          output150CAR["OLS150_RMRF"]*output150CAR["RMRF_cen11sum"] + 
                          output150CAR["OLS150_intercept"]*3 )

# %%
output150CAR
# Out:
#                  CompanyName  ProwessCode     Symbol   AsOnDate    ACP  \
# 0            20 Microns Ltd.         11.0  20MICRONS 2008-10-06  16.82
# 1            20 Microns Ltd.         11.0  20MICRONS 2008-10-07  15.05
# 2            20 Microns Ltd.         11.0  20MICRONS 2008-10-08  13.25
# 3            20 Microns Ltd.         11.0  20MICRONS 2008-10-10  11.60
# 4            20 Microns Ltd.         11.0  20MICRONS 2008-10-13  12.32
# ...                      ...          ...        ...        ...    ...
# 13465088  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-21   0.35
# 13465089  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-22   0.35
# 13465090  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-26   0.35
# 13465091  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-27   0.35
# 13465092  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-28   0.35
#
#                pct        RF      RMRF        MF       SMB       HML  \
# 0              NaN  0.069713 -6.381449 -6.311735 -0.373052 -0.566450
# 1        -0.105232  0.023232 -0.669144 -0.645911 -1.502487  0.184699
# 2        -0.119601  0.023232 -3.533362 -3.510130 -1.780674  0.072932
# 3        -0.124528  0.045520 -7.052324 -7.006804  0.217126  0.354629
# 4         0.062069  0.066863  5.042738  5.109602 -2.437097  0.145853
# ...            ...       ...       ...       ...       ...       ...
# 13465088  0.000000  0.018215  1.441807  1.460021  0.572866  1.270303
# 13465089  0.000000  0.018215  0.593324  0.611538  0.752002  0.124527
# 13465090  0.000000  0.072878 -0.044514  0.028364 -1.091597  0.440605
# 13465091  0.000000  0.018215  0.326702  0.344916 -0.165072 -0.188505
# 13465092  0.000000  0.018215  0.703054  0.721269 -0.579335 -0.093002
#
#           OLS150_intercept  OLS150_RMRF  OLS150_r_squared  \
# 0                      NaN          NaN               NaN
# 1                      NaN          NaN               NaN
# 2                      NaN          NaN               NaN
# 3                      NaN          NaN               NaN
# 4                      NaN          NaN               NaN
# ...                    ...          ...               ...
# 13465088               NaN          NaN               NaN
# 13465089               NaN          NaN               NaN
# 13465090               NaN          NaN               NaN
# 13465091               NaN          NaN               NaN
# 13465092               NaN          NaN               NaN
#
#           OLS150_adjusted_r_squared  OLS150_f_p_value  pct_cen3sum  \
# 0                               NaN               NaN          NaN
# 1                               NaN               NaN          NaN
# 2                               NaN               NaN    -0.349361
# 3                               NaN               NaN    -0.182061
# 4                               NaN               NaN    -0.163920
# ...                             ...               ...          ...
# 13465088                        NaN               NaN     0.000000
# 13465089                        NaN               NaN     0.000000
# 13465090                        NaN               NaN     0.000000
# 13465091                        NaN               NaN     0.000000
# 13465092                        NaN               NaN          NaN
#
#           RF_cen3sum  RMRF_cen3sum  pct_cen5sum  RF_cen5sum  RMRF_cen5sum  \
# 0                NaN           NaN          NaN         NaN           NaN
# 1           0.116178    -10.583954          NaN         NaN           NaN
# 2           0.091985    -11.254830          NaN    0.228562    -12.593540
# 3           0.135616     -5.542948    -0.388754    0.181132     -5.036699
# 4           0.134667     -0.834193    -0.183251    0.180182     -9.543586
# ...              ...           ...          ...         ...           ...
# 13465088    0.054643      2.222872     0.000000    0.145734      0.669402
# 13465089    0.109307      1.990617     0.000000    0.145735      2.505059
# 13465090    0.109307      0.875511     0.000000    0.145736      3.020372
# 13465091    0.109307      0.985242          NaN         NaN           NaN
# 13465092         NaN           NaN          NaN         NaN           NaN
#
#           pct_cen7sum  RF_cen7sum  RMRF_cen7sum  pct_cen11sum  RF_cen11sum  \
# 0                 NaN         NaN           NaN           NaN          NaN
# 1                 NaN         NaN           NaN           NaN          NaN
# 2                 NaN         NaN           NaN           NaN          NaN
# 3                 NaN    0.273128    -16.594178           NaN          NaN
# 4           -0.163688    0.225697    -12.320480           NaN          NaN
# ...               ...         ...           ...           ...          ...
# 13465088     0.000000    0.218599      1.086124           NaN          NaN
# 13465089     0.000000    0.182163      1.699158           NaN          NaN
# 13465090          NaN         NaN           NaN           NaN          NaN
# 13465091          NaN         NaN           NaN           NaN          NaN
# 13465092          NaN         NaN           NaN           NaN          NaN
#
#           RMRF_cen11sum  150CAR3  150CAR5  150CAR7  150CAR11
# 0                   NaN      NaN      NaN      NaN       NaN
# 1                   NaN      NaN      NaN      NaN       NaN
# 2                   NaN      NaN      NaN      NaN       NaN
# 3                   NaN      NaN      NaN      NaN       NaN
# 4                   NaN      NaN      NaN      NaN       NaN
# ...                 ...      ...      ...      ...       ...
# 13465088            NaN      NaN      NaN      NaN       NaN
# 13465089            NaN      NaN      NaN      NaN       NaN
# 13465090            NaN      NaN      NaN      NaN       NaN
# 13465091            NaN      NaN      NaN      NaN       NaN
# 13465092            NaN      NaN      NaN      NaN       NaN
#
# [13465093 rows x 32 columns]

# %%
output150CAR_2 = output150CAR.dropna(subset = "150CAR3").reset_index(drop = True)
output150CAR_2
# Out:
#               CompanyName  ProwessCode     Symbol   AsOnDate    ACP       pct  \
# 0         20 Microns Ltd.         11.0  20MICRONS 2009-07-29  12.60 -0.017161
# 1         20 Microns Ltd.         11.0  20MICRONS 2009-07-30  12.50 -0.007937
# 2         20 Microns Ltd.         11.0  20MICRONS 2009-08-27  15.78  0.000000
# 3         20 Microns Ltd.         11.0  20MICRONS 2011-04-29  20.48 -0.016330
# 4         20 Microns Ltd.         11.0  20MICRONS 2014-08-06  31.15 -0.011111
# ...                   ...          ...        ...        ...    ...       ...
# 34393  Zylog Systems Ltd.     275793.0      ZYLOG 2015-08-14   5.40  0.018868
# 34394  Zylog Systems Ltd.     275793.0      ZYLOG 2016-06-30   3.90  0.040000
# 34395  Zylog Systems Ltd.     275793.0      ZYLOG 2016-08-12   3.15 -0.045455
# 34396  Zylog Systems Ltd.     275793.0      ZYLOG 2016-11-23   4.25 -0.022989
# 34397  Zylog Systems Ltd.     275793.0      ZYLOG 2017-02-10   5.05  0.041237
#
#              RF      RMRF        MF       SMB       HML  OLS150_intercept  \
# 0      0.008824 -1.187185 -1.178360  0.280266 -0.219265         -0.018705
# 1      0.008824  0.606603  0.615428 -0.050968  0.076723         -0.017426
# 2      0.009040  0.358959  0.368000  0.741064  0.945923         -0.016317
# 3      0.019851 -0.595940 -0.576089 -0.572908 -0.607305         -0.026340
# 4      0.022705 -0.690542 -0.667837  1.023324 -0.182707         -0.034378
# ...         ...       ...       ...       ...       ...               ...
# 34393  0.019213  1.546309  1.565522 -0.064032  1.416502         -0.034571
# 34394  0.017832  1.065921  1.083753 -0.809196  1.214423         -0.027604
# 34395  0.017406  0.290292  0.307698 -0.979555  0.368906         -0.025477
# 34396  0.015807  1.118596  1.134402  0.640072  1.506896         -0.029032
# 34397  0.016234 -0.042546 -0.026312  0.204566 -0.756680         -0.022281
#
#        OLS150_RMRF  OLS150_r_squared  OLS150_adjusted_r_squared  \
# 0         0.005061          0.064182                   0.057859
# 1         0.004621          0.055583                   0.049202
# 2         0.004135          0.048609                   0.042181
# 3         0.010345          0.100758                   0.094682
# 4         0.008381          0.050199                   0.043781
# ...            ...               ...                        ...
# 34393     0.010030          0.061262                   0.054919
# 34394     0.002431          0.002971                  -0.003765
# 34395     0.002946          0.004509                  -0.002217
# 34396     0.004966          0.013618                   0.006953
# 34397     0.008887          0.024759                   0.018170
#
#        OLS150_f_p_value  pct_cen3sum  RF_cen3sum  RMRF_cen3sum  pct_cen5sum  \
# 0              0.001760    -0.056087    0.026473      0.029619     0.062901
# 1              0.003680     0.000503    0.026365      0.353815    -0.004746
# 2              0.006706    -0.020051    0.027229      2.106517     0.095158
# 3              0.000076     0.135960    0.099051     -2.055273     0.068979
# 4              0.005847    -0.012716    0.068115     -0.250139    -0.004716
# ...                 ...          ...         ...           ...          ...
# 34393          0.002261    -0.113635    0.096076      0.535057    -0.246220
# 34394          0.507632     0.080218    0.053601      2.887396     0.066209
# 34395          0.414249    -0.061816    0.104454      0.121902    -0.076967
# 34396          0.154986     0.000961    0.047206      1.977908    -0.072004
# 34397          0.054476     0.060639    0.081176      0.077238     0.082365
#
#        RF_cen5sum  RMRF_cen5sum  pct_cen7sum  RF_cen7sum  RMRF_cen7sum  \
# 0        0.061664      1.417488     0.109739    0.096639      4.283657
# 1        0.061340      2.473169     0.130467    0.096531      2.484330
# 2        0.063718      2.095520     0.186179    0.099990      3.145210
# 3        0.138538     -4.268887     0.048651    0.178026     -4.607642
# 4        0.158951     -0.558310    -0.002971    0.249787     -1.450041
# ...           ...           ...          ...         ...           ...
# 34393    0.134926     -0.534668    -0.291712    0.173777     -0.844522
# 34394    0.125044      3.865878     0.082876    0.196699      3.920553
# 34395    0.139266     -1.118332    -0.061583    0.174078     -0.982620
# 34396    0.110227      1.658702    -0.103254    0.172820      2.689463
# 34397    0.113856     -0.002369     0.044815    0.146536     -1.621023
#
#        pct_cen11sum  RF_cen11sum  RMRF_cen11sum   150CAR3   150CAR5   150CAR7  \
# 0          0.181963     0.131720       6.025389 -0.026594  0.050179  0.047536
# 1          0.143027     0.131612       4.768098  0.024780 -0.025239  0.074731
# 2          0.367888     0.136368       5.257233 -0.007040  0.071726  0.122134
# 3          0.066696     0.316887      -5.076389  0.137190  0.053622 -0.002689
# 4         -0.040029     0.363107      -1.042710  0.024399 -0.055854 -0.137471
# ...             ...          ...            ...       ...       ...       ...
# 34393     -0.274151     0.291613      -3.755096 -0.111364 -0.272070 -0.353304
# 34394      0.017235     0.285435       1.822980  0.102407  0.014577 -0.040544
# 34395     -0.059889     0.313345       0.230677 -0.090198 -0.136508 -0.156335
# 34396      0.087481     0.236579       3.498012  0.031027 -0.103373 -0.202336
# 34397      0.055863     0.245226       0.610712  0.045621  0.035374 -0.020473
#
#        150CAR11
# 0      0.075864
# 1      0.041656
# 2      0.258731
# 3     -0.118655
# 4     -0.291262
# ...         ...
# 34393 -0.424385
# 34394 -0.189821
# 34395 -0.297482
# 34396 -0.079376
# 34397 -0.127947
#
# [34398 rows x 32 columns]

# %%
output150CAR_2.to_pickle(rf"{output_folder_path}\output150CAR_2.pkl")

# %%
del ols150
del ols150CAR

del result150CAR2
del result150CAR

del output150CAR
del output150CAR_2

# %% [markdown]
# ## 180 CAR Data Reading

# %%
ols180 = pd.read_pickle(rf"{import_folder_path}\ols180_2.pkl")

# %% [markdown]
# ## 180 CAR Calc

# %%
ols180CAR = ols180.sort_values(by = ["CompanyName", "AsOnDate"])
ols180CAR
# Out:
#                  CompanyName  ProwessCode     Symbol   AsOnDate    ACP  \
# 0            20 Microns Ltd.         11.0  20MICRONS 2008-10-06  16.82
# 1            20 Microns Ltd.         11.0  20MICRONS 2008-10-07  15.05
# 2            20 Microns Ltd.         11.0  20MICRONS 2008-10-08  13.25
# 3            20 Microns Ltd.         11.0  20MICRONS 2008-10-10  11.60
# 4            20 Microns Ltd.         11.0  20MICRONS 2008-10-13  12.32
# ...                      ...          ...        ...        ...    ...
# 13465088  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-21   0.35
# 13465089  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-22   0.35
# 13465090  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-26   0.35
# 13465091  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-27   0.35
# 13465092  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-28   0.35
#
#                pct        RF      RMRF        MF       SMB       HML  \
# 0              NaN  0.069713 -6.381449 -6.311735 -0.373052 -0.566450
# 1        -0.105232  0.023232 -0.669144 -0.645911 -1.502487  0.184699
# 2        -0.119601  0.023232 -3.533362 -3.510130 -1.780674  0.072932
# 3        -0.124528  0.045520 -7.052324 -7.006804  0.217126  0.354629
# 4         0.062069  0.066863  5.042738  5.109602 -2.437097  0.145853
# ...            ...       ...       ...       ...       ...       ...
# 13465088  0.000000  0.018215  1.441807  1.460021  0.572866  1.270303
# 13465089  0.000000  0.018215  0.593324  0.611538  0.752002  0.124527
# 13465090  0.000000  0.072878 -0.044514  0.028364 -1.091597  0.440605
# 13465091  0.000000  0.018215  0.326702  0.344916 -0.165072 -0.188505
# 13465092  0.000000  0.018215  0.703054  0.721269 -0.579335 -0.093002
#
#           OLS180_intercept  OLS180_RMRF  OLS180_r_squared  \
# 0                      NaN          NaN               NaN
# 1                      NaN          NaN               NaN
# 2                      NaN          NaN               NaN
# 3                      NaN          NaN               NaN
# 4                      NaN          NaN               NaN
# ...                    ...          ...               ...
# 13465088               NaN          NaN               NaN
# 13465089               NaN          NaN               NaN
# 13465090               NaN          NaN               NaN
# 13465091               NaN          NaN               NaN
# 13465092               NaN          NaN               NaN
#
#           OLS180_adjusted_r_squared  OLS180_f_p_value
# 0                               NaN               NaN
# 1                               NaN               NaN
# 2                               NaN               NaN
# 3                               NaN               NaN
# 4                               NaN               NaN
# ...                             ...               ...
# 13465088                        NaN               NaN
# 13465089                        NaN               NaN
# 13465090                        NaN               NaN
# 13465091                        NaN               NaN
# 13465092                        NaN               NaN
#
# [13465093 rows x 16 columns]

# %%
# FUNCTION

# def CAR180(frame):
#     if ((~frame.OLS180_intercept.isnull().any()) == True):
#         ER = frame.RF + (frame.RMRF * frame.OLS180_RMRF) + (frame.SMB * frame.OLS180_SMB) + (frame.HML * frame.OLS180_HML) + frame.OLS180_intercept
#         AR = frame.pct - ER
#         return AR.sum()
#     else: 
#         return np.NaN

    # for i in range(len(frame)):
    #     if (i>0) & ( i< len(frame)-1) :
    #         coeff180CAR = np.array([frame.iloc[i]["OLS180_RMRF"], frame.iloc[i]["OLS180_SMB"],
    #                                 frame.iloc[i]["OLS180_HML"], 1, frame.iloc[i]["OLS180_intercept"]])

    #         event180CAR3 = np.array(frame.loc[ [i-1, i, i+1], ["RMRF", "SMB", "HML", "RF"]],)
    #         event180CAR3 = [np.append(item, 1) for item in event180CAR3]

    #         ER = np.matmul(event180CAR3, coeff180CAR)

    #         actualReturns = np.array([frame.iloc[i-1]["pct"], frame.iloc[i]["pct"], frame.iloc[i+1]["pct"]])

    #         AR = np.subtract( actualReturns, ER )

    #         output180CAR3.loc[i, ["180CAR3"]] = AR.sum()


    
        # if i>=2:
        #     frame["180CAR5"].iloc[i] = CAR180(frame.iloc[ i-2 : i+2 ])
        # if i>=3:
        #     frame["180CAR7"].iloc[i] = CAR180(frame.iloc[ i-3 : i+3 ])
        # if i>=5:
        #     frame["180CAR11"].iloc[i] = CAR180(frame.iloc[ i-5 : i+5 ])

        

def CAR(frame):

    outputFrame = pd.DataFrame( index = frame.index)

        
    # 3 Days
    
    outputFrame["pct_cen3sum"] = frame["pct"].rolling(window = 3, min_periods = 3, center = True).sum()
    
    outputFrame["RF_cen3sum"] = frame["RF"].rolling(window = 3, min_periods = 3, center = True).sum()
    
    outputFrame["RMRF_cen3sum"] = frame["RMRF"].rolling(window = 3, min_periods = 3, center = True).sum()
    
    
    # 5 Days
    
    outputFrame["pct_cen5sum"] = frame["pct"].rolling(window = 5, min_periods = 5, center = True).sum()
    
    outputFrame["RF_cen5sum"] = frame["RF"].rolling(window = 5, min_periods = 5, center = True).sum()
    
    outputFrame["RMRF_cen5sum"] = frame["RMRF"].rolling(window = 5, min_periods = 5, center = True).sum()
    
    
    # 7 Days
    
    outputFrame["pct_cen7sum"] = frame["pct"].rolling(window = 7, min_periods = 7, center = True).sum()
    
    outputFrame["RF_cen7sum"] = frame["RF"].rolling(window = 7, min_periods = 7, center = True).sum()
    
    outputFrame["RMRF_cen7sum"] = frame["RMRF"].rolling(window = 7, min_periods = 7, center = True).sum()
    
    
    # 11 Days
    
    outputFrame["pct_cen11sum"] = frame["pct"].rolling(window = 11, min_periods = 11, center = True).sum()
    
    outputFrame["RF_cen11sum"] = frame["RF"].rolling(window = 11, min_periods = 11, center = True).sum()
    
    outputFrame["RMRF_cen11sum"] = frame["RMRF"].rolling(window = 11, min_periods = 11, center = True).sum()
    
    
    return outputFrame

# %%
result180CAR = ols180CAR.sort_values(by = ["CompanyName", "AsOnDate"]).groupby(by = "CompanyName").progress_apply(CAR)
# Out:
#   0%|          | 0/3721 [00:00<?, ?it/s]
# C:\Users\SHIVAM\anaconda3\Lib\site-packages\tqdm\std.py:805: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return getattr(df, df_function)(wrapper, **kwargs)

# %%
result180CAR
# Out:
#                              pct_cen3sum  RF_cen3sum  RMRF_cen3sum  \
# CompanyName
# 20 Microns Ltd.    0                 NaN         NaN           NaN
#                    1                 NaN    0.116178    -10.583954
#                    2           -0.349361    0.091985    -11.254830
#                    3           -0.182061    0.135616     -5.542948
#                    4           -0.163920    0.134667     -0.834193
# ...                                  ...         ...           ...
# Zylog Systems Ltd. 13465088     0.000000    0.054643      2.222872
#                    13465089     0.000000    0.109307      1.990617
#                    13465090     0.000000    0.109307      0.875511
#                    13465091     0.000000    0.109307      0.985242
#                    13465092          NaN         NaN           NaN
#
#                              pct_cen5sum  RF_cen5sum  RMRF_cen5sum  \
# CompanyName
# 20 Microns Ltd.    0                 NaN         NaN           NaN
#                    1                 NaN         NaN           NaN
#                    2                 NaN    0.228562    -12.593540
#                    3           -0.388754    0.181132     -5.036699
#                    4           -0.183251    0.180182     -9.543586
# ...                                  ...         ...           ...
# Zylog Systems Ltd. 13465088     0.000000    0.145734      0.669402
#                    13465089     0.000000    0.145735      2.505059
#                    13465090     0.000000    0.145736      3.020372
#                    13465091          NaN         NaN           NaN
#                    13465092          NaN         NaN           NaN
#
#                              pct_cen7sum  RF_cen7sum  RMRF_cen7sum  \
# CompanyName
# 20 Microns Ltd.    0                 NaN         NaN           NaN
#                    1                 NaN         NaN           NaN
#                    2                 NaN         NaN           NaN
#                    3                 NaN    0.273128    -16.594178
#                    4           -0.163688    0.225697    -12.320480
# ...                                  ...         ...           ...
# Zylog Systems Ltd. 13465088     0.000000    0.218599      1.086124
#                    13465089     0.000000    0.182163      1.699158
#                    13465090          NaN         NaN           NaN
#                    13465091          NaN         NaN           NaN
#                    13465092          NaN         NaN           NaN
#
#                              pct_cen11sum  RF_cen11sum  RMRF_cen11sum
# CompanyName
# 20 Microns Ltd.    0                  NaN          NaN            NaN
#                    1                  NaN          NaN            NaN
#                    2                  NaN          NaN            NaN
#                    3                  NaN          NaN            NaN
#                    4                  NaN          NaN            NaN
# ...                                   ...          ...            ...
# Zylog Systems Ltd. 13465088           NaN          NaN            NaN
#                    13465089           NaN          NaN            NaN
#                    13465090           NaN          NaN            NaN
#                    13465091           NaN          NaN            NaN
#                    13465092           NaN          NaN            NaN
#
# [13465093 rows x 12 columns]

# %%
result180CAR2 = result180CAR.reset_index(level = 0).drop("CompanyName", axis = 1)
result180CAR2
# Out:
#           pct_cen3sum  RF_cen3sum  RMRF_cen3sum  pct_cen5sum  RF_cen5sum  \
# 0                 NaN         NaN           NaN          NaN         NaN
# 1                 NaN    0.116178    -10.583954          NaN         NaN
# 2           -0.349361    0.091985    -11.254830          NaN    0.228562
# 3           -0.182061    0.135616     -5.542948    -0.388754    0.181132
# 4           -0.163920    0.134667     -0.834193    -0.183251    0.180182
# ...               ...         ...           ...          ...         ...
# 13465088     0.000000    0.054643      2.222872     0.000000    0.145734
# 13465089     0.000000    0.109307      1.990617     0.000000    0.145735
# 13465090     0.000000    0.109307      0.875511     0.000000    0.145736
# 13465091     0.000000    0.109307      0.985242          NaN         NaN
# 13465092          NaN         NaN           NaN          NaN         NaN
#
#           RMRF_cen5sum  pct_cen7sum  RF_cen7sum  RMRF_cen7sum  pct_cen11sum  \
# 0                  NaN          NaN         NaN           NaN           NaN
# 1                  NaN          NaN         NaN           NaN           NaN
# 2           -12.593540          NaN         NaN           NaN           NaN
# 3            -5.036699          NaN    0.273128    -16.594178           NaN
# 4            -9.543586    -0.163688    0.225697    -12.320480           NaN
# ...                ...          ...         ...           ...           ...
# 13465088      0.669402     0.000000    0.218599      1.086124           NaN
# 13465089      2.505059     0.000000    0.182163      1.699158           NaN
# 13465090      3.020372          NaN         NaN           NaN           NaN
# 13465091           NaN          NaN         NaN           NaN           NaN
# 13465092           NaN          NaN         NaN           NaN           NaN
#
#           RF_cen11sum  RMRF_cen11sum
# 0                 NaN            NaN
# 1                 NaN            NaN
# 2                 NaN            NaN
# 3                 NaN            NaN
# 4                 NaN            NaN
# ...               ...            ...
# 13465088          NaN            NaN
# 13465089          NaN            NaN
# 13465090          NaN            NaN
# 13465091          NaN            NaN
# 13465092          NaN            NaN
#
# [13465093 rows x 12 columns]

# %%
output180CAR = pd.concat([ols180CAR, result180CAR2], axis = 1)
output180CAR
# Out:
#                  CompanyName  ProwessCode     Symbol   AsOnDate    ACP  \
# 0            20 Microns Ltd.         11.0  20MICRONS 2008-10-06  16.82
# 1            20 Microns Ltd.         11.0  20MICRONS 2008-10-07  15.05
# 2            20 Microns Ltd.         11.0  20MICRONS 2008-10-08  13.25
# 3            20 Microns Ltd.         11.0  20MICRONS 2008-10-10  11.60
# 4            20 Microns Ltd.         11.0  20MICRONS 2008-10-13  12.32
# ...                      ...          ...        ...        ...    ...
# 13465088  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-21   0.35
# 13465089  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-22   0.35
# 13465090  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-26   0.35
# 13465091  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-27   0.35
# 13465092  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-28   0.35
#
#                pct        RF      RMRF        MF       SMB       HML  \
# 0              NaN  0.069713 -6.381449 -6.311735 -0.373052 -0.566450
# 1        -0.105232  0.023232 -0.669144 -0.645911 -1.502487  0.184699
# 2        -0.119601  0.023232 -3.533362 -3.510130 -1.780674  0.072932
# 3        -0.124528  0.045520 -7.052324 -7.006804  0.217126  0.354629
# 4         0.062069  0.066863  5.042738  5.109602 -2.437097  0.145853
# ...            ...       ...       ...       ...       ...       ...
# 13465088  0.000000  0.018215  1.441807  1.460021  0.572866  1.270303
# 13465089  0.000000  0.018215  0.593324  0.611538  0.752002  0.124527
# 13465090  0.000000  0.072878 -0.044514  0.028364 -1.091597  0.440605
# 13465091  0.000000  0.018215  0.326702  0.344916 -0.165072 -0.188505
# 13465092  0.000000  0.018215  0.703054  0.721269 -0.579335 -0.093002
#
#           OLS180_intercept  OLS180_RMRF  OLS180_r_squared  \
# 0                      NaN          NaN               NaN
# 1                      NaN          NaN               NaN
# 2                      NaN          NaN               NaN
# 3                      NaN          NaN               NaN
# 4                      NaN          NaN               NaN
# ...                    ...          ...               ...
# 13465088               NaN          NaN               NaN
# 13465089               NaN          NaN               NaN
# 13465090               NaN          NaN               NaN
# 13465091               NaN          NaN               NaN
# 13465092               NaN          NaN               NaN
#
#           OLS180_adjusted_r_squared  OLS180_f_p_value  pct_cen3sum  \
# 0                               NaN               NaN          NaN
# 1                               NaN               NaN          NaN
# 2                               NaN               NaN    -0.349361
# 3                               NaN               NaN    -0.182061
# 4                               NaN               NaN    -0.163920
# ...                             ...               ...          ...
# 13465088                        NaN               NaN     0.000000
# 13465089                        NaN               NaN     0.000000
# 13465090                        NaN               NaN     0.000000
# 13465091                        NaN               NaN     0.000000
# 13465092                        NaN               NaN          NaN
#
#           RF_cen3sum  RMRF_cen3sum  pct_cen5sum  RF_cen5sum  RMRF_cen5sum  \
# 0                NaN           NaN          NaN         NaN           NaN
# 1           0.116178    -10.583954          NaN         NaN           NaN
# 2           0.091985    -11.254830          NaN    0.228562    -12.593540
# 3           0.135616     -5.542948    -0.388754    0.181132     -5.036699
# 4           0.134667     -0.834193    -0.183251    0.180182     -9.543586
# ...              ...           ...          ...         ...           ...
# 13465088    0.054643      2.222872     0.000000    0.145734      0.669402
# 13465089    0.109307      1.990617     0.000000    0.145735      2.505059
# 13465090    0.109307      0.875511     0.000000    0.145736      3.020372
# 13465091    0.109307      0.985242          NaN         NaN           NaN
# 13465092         NaN           NaN          NaN         NaN           NaN
#
#           pct_cen7sum  RF_cen7sum  RMRF_cen7sum  pct_cen11sum  RF_cen11sum  \
# 0                 NaN         NaN           NaN           NaN          NaN
# 1                 NaN         NaN           NaN           NaN          NaN
# 2                 NaN         NaN           NaN           NaN          NaN
# 3                 NaN    0.273128    -16.594178           NaN          NaN
# 4           -0.163688    0.225697    -12.320480           NaN          NaN
# ...               ...         ...           ...           ...          ...
# 13465088     0.000000    0.218599      1.086124           NaN          NaN
# 13465089     0.000000    0.182163      1.699158           NaN          NaN
# 13465090          NaN         NaN           NaN           NaN          NaN
# 13465091          NaN         NaN           NaN           NaN          NaN
# 13465092          NaN         NaN           NaN           NaN          NaN
#
#           RMRF_cen11sum
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 13465088            NaN
# 13465089            NaN
# 13465090            NaN
# 13465091            NaN
# 13465092            NaN
#
# [13465093 rows x 28 columns]

# %%
output180CAR.columns
# Out:
# Index(['CompanyName', 'ProwessCode', 'Symbol', 'AsOnDate', 'ACP', 'pct', 'RF',
#        'RMRF', 'MF', 'SMB', 'HML', 'OLS180_intercept', 'OLS180_RMRF',
#        'OLS180_r_squared', 'OLS180_adjusted_r_squared', 'OLS180_f_p_value',
#        'pct_cen3sum', 'RF_cen3sum', 'RMRF_cen3sum', 'pct_cen5sum',
#        'RF_cen5sum', 'RMRF_cen5sum', 'pct_cen7sum', 'RF_cen7sum',
#        'RMRF_cen7sum', 'pct_cen11sum', 'RF_cen11sum', 'RMRF_cen11sum'],
#       dtype='object')

# %%
output180CAR["180CAR3"] = output180CAR["pct_cen3sum"] - (output180CAR["RF_cen3sum"] + 
                          
                          output180CAR["OLS180_RMRF"]*output180CAR["RMRF_cen3sum"] + 
                          output180CAR["OLS180_intercept"]*3 )

# %%
output180CAR["180CAR5"] = output180CAR["pct_cen5sum"] - (output180CAR["RF_cen5sum"] + 
                          
                          output180CAR["OLS180_RMRF"]*output180CAR["RMRF_cen5sum"] + 
                          output180CAR["OLS180_intercept"]*3 )

# %%
output180CAR["180CAR7"] = output180CAR["pct_cen7sum"] - (output180CAR["RF_cen7sum"] + 
                          
                          output180CAR["OLS180_RMRF"]*output180CAR["RMRF_cen7sum"] + 
                          output180CAR["OLS180_intercept"]*3 )

# %%
output180CAR["180CAR11"] = output180CAR["pct_cen11sum"] - (output180CAR["RF_cen11sum"] + 
                          
                          output180CAR["OLS180_RMRF"]*output180CAR["RMRF_cen11sum"] + 
                          output180CAR["OLS180_intercept"]*3 )

# %%
output180CAR
# Out:
#                  CompanyName  ProwessCode     Symbol   AsOnDate    ACP  \
# 0            20 Microns Ltd.         11.0  20MICRONS 2008-10-06  16.82
# 1            20 Microns Ltd.         11.0  20MICRONS 2008-10-07  15.05
# 2            20 Microns Ltd.         11.0  20MICRONS 2008-10-08  13.25
# 3            20 Microns Ltd.         11.0  20MICRONS 2008-10-10  11.60
# 4            20 Microns Ltd.         11.0  20MICRONS 2008-10-13  12.32
# ...                      ...          ...        ...        ...    ...
# 13465088  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-21   0.35
# 13465089  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-22   0.35
# 13465090  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-26   0.35
# 13465091  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-27   0.35
# 13465092  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-28   0.35
#
#                pct        RF      RMRF        MF       SMB       HML  \
# 0              NaN  0.069713 -6.381449 -6.311735 -0.373052 -0.566450
# 1        -0.105232  0.023232 -0.669144 -0.645911 -1.502487  0.184699
# 2        -0.119601  0.023232 -3.533362 -3.510130 -1.780674  0.072932
# 3        -0.124528  0.045520 -7.052324 -7.006804  0.217126  0.354629
# 4         0.062069  0.066863  5.042738  5.109602 -2.437097  0.145853
# ...            ...       ...       ...       ...       ...       ...
# 13465088  0.000000  0.018215  1.441807  1.460021  0.572866  1.270303
# 13465089  0.000000  0.018215  0.593324  0.611538  0.752002  0.124527
# 13465090  0.000000  0.072878 -0.044514  0.028364 -1.091597  0.440605
# 13465091  0.000000  0.018215  0.326702  0.344916 -0.165072 -0.188505
# 13465092  0.000000  0.018215  0.703054  0.721269 -0.579335 -0.093002
#
#           OLS180_intercept  OLS180_RMRF  OLS180_r_squared  \
# 0                      NaN          NaN               NaN
# 1                      NaN          NaN               NaN
# 2                      NaN          NaN               NaN
# 3                      NaN          NaN               NaN
# 4                      NaN          NaN               NaN
# ...                    ...          ...               ...
# 13465088               NaN          NaN               NaN
# 13465089               NaN          NaN               NaN
# 13465090               NaN          NaN               NaN
# 13465091               NaN          NaN               NaN
# 13465092               NaN          NaN               NaN
#
#           OLS180_adjusted_r_squared  OLS180_f_p_value  pct_cen3sum  \
# 0                               NaN               NaN          NaN
# 1                               NaN               NaN          NaN
# 2                               NaN               NaN    -0.349361
# 3                               NaN               NaN    -0.182061
# 4                               NaN               NaN    -0.163920
# ...                             ...               ...          ...
# 13465088                        NaN               NaN     0.000000
# 13465089                        NaN               NaN     0.000000
# 13465090                        NaN               NaN     0.000000
# 13465091                        NaN               NaN     0.000000
# 13465092                        NaN               NaN          NaN
#
#           RF_cen3sum  RMRF_cen3sum  pct_cen5sum  RF_cen5sum  RMRF_cen5sum  \
# 0                NaN           NaN          NaN         NaN           NaN
# 1           0.116178    -10.583954          NaN         NaN           NaN
# 2           0.091985    -11.254830          NaN    0.228562    -12.593540
# 3           0.135616     -5.542948    -0.388754    0.181132     -5.036699
# 4           0.134667     -0.834193    -0.183251    0.180182     -9.543586
# ...              ...           ...          ...         ...           ...
# 13465088    0.054643      2.222872     0.000000    0.145734      0.669402
# 13465089    0.109307      1.990617     0.000000    0.145735      2.505059
# 13465090    0.109307      0.875511     0.000000    0.145736      3.020372
# 13465091    0.109307      0.985242          NaN         NaN           NaN
# 13465092         NaN           NaN          NaN         NaN           NaN
#
#           pct_cen7sum  RF_cen7sum  RMRF_cen7sum  pct_cen11sum  RF_cen11sum  \
# 0                 NaN         NaN           NaN           NaN          NaN
# 1                 NaN         NaN           NaN           NaN          NaN
# 2                 NaN         NaN           NaN           NaN          NaN
# 3                 NaN    0.273128    -16.594178           NaN          NaN
# 4           -0.163688    0.225697    -12.320480           NaN          NaN
# ...               ...         ...           ...           ...          ...
# 13465088     0.000000    0.218599      1.086124           NaN          NaN
# 13465089     0.000000    0.182163      1.699158           NaN          NaN
# 13465090          NaN         NaN           NaN           NaN          NaN
# 13465091          NaN         NaN           NaN           NaN          NaN
# 13465092          NaN         NaN           NaN           NaN          NaN
#
#           RMRF_cen11sum  180CAR3  180CAR5  180CAR7  180CAR11
# 0                   NaN      NaN      NaN      NaN       NaN
# 1                   NaN      NaN      NaN      NaN       NaN
# 2                   NaN      NaN      NaN      NaN       NaN
# 3                   NaN      NaN      NaN      NaN       NaN
# 4                   NaN      NaN      NaN      NaN       NaN
# ...                 ...      ...      ...      ...       ...
# 13465088            NaN      NaN      NaN      NaN       NaN
# 13465089            NaN      NaN      NaN      NaN       NaN
# 13465090            NaN      NaN      NaN      NaN       NaN
# 13465091            NaN      NaN      NaN      NaN       NaN
# 13465092            NaN      NaN      NaN      NaN       NaN
#
# [13465093 rows x 32 columns]

# %%
output180CAR_2 = output180CAR.dropna(subset = "180CAR3").reset_index(drop = True)
output180CAR_2
# Out:
#               CompanyName  ProwessCode     Symbol   AsOnDate    ACP       pct  \
# 0         20 Microns Ltd.         11.0  20MICRONS 2009-08-27  15.78  0.000000
# 1         20 Microns Ltd.         11.0  20MICRONS 2011-04-29  20.48 -0.016330
# 2         20 Microns Ltd.         11.0  20MICRONS 2014-08-06  31.15 -0.011111
# 3         20 Microns Ltd.         11.0  20MICRONS 2015-02-05  38.50 -0.020356
# 4         20 Microns Ltd.         11.0  20MICRONS 2017-05-04  43.70  0.016279
# ...                   ...          ...        ...        ...    ...       ...
# 34082  Zylog Systems Ltd.     275793.0      ZYLOG 2015-08-14   5.40  0.018868
# 34083  Zylog Systems Ltd.     275793.0      ZYLOG 2016-06-30   3.90  0.040000
# 34084  Zylog Systems Ltd.     275793.0      ZYLOG 2016-08-12   3.15 -0.045455
# 34085  Zylog Systems Ltd.     275793.0      ZYLOG 2016-11-23   4.25 -0.022989
# 34086  Zylog Systems Ltd.     275793.0      ZYLOG 2017-02-10   5.05  0.041237
#
#              RF      RMRF        MF       SMB       HML  OLS180_intercept  \
# 0      0.009040  0.358959  0.368000  0.741064  0.945923         -0.019785
# 1      0.019851 -0.595940 -0.576089 -0.572908 -0.607305         -0.024022
# 2      0.022705 -0.690542 -0.667837  1.023324 -0.182707         -0.034278
# 3      0.021755 -0.625772 -0.604017  0.012769 -1.213916         -0.034440
# 4      0.016554  0.046274  0.062828  0.831535 -0.581499         -0.024020
# ...         ...       ...       ...       ...       ...               ...
# 34082  0.019213  1.546309  1.565522 -0.064032  1.416502         -0.034362
# 34083  0.017832  1.065921  1.083753 -0.809196  1.214423         -0.028974
# 34084  0.017406  0.290292  0.307698 -0.979555  0.368906         -0.027501
# 34085  0.015807  1.118596  1.134402  0.640072  1.506896         -0.030786
# 34086  0.016234 -0.042546 -0.026312  0.204566 -0.756680         -0.023243
#
#        OLS180_RMRF  OLS180_r_squared  OLS180_adjusted_r_squared  \
# 0         0.006153          0.095433                   0.090351
# 1         0.010026          0.072412                   0.067200
# 2         0.008417          0.042347                   0.036967
# 3         0.006402          0.034724                   0.029301
# 4         0.018310          0.186137                   0.181564
# ...            ...               ...                        ...
# 34082     0.011860          0.071526                   0.066310
# 34083     0.005380          0.020708                   0.015206
# 34084     0.003164          0.004900                  -0.000691
# 34085     0.004640          0.014079                   0.008541
# 34086     0.006936          0.015210                   0.009678
#
#        OLS180_f_p_value  pct_cen3sum  RF_cen3sum  RMRF_cen3sum  pct_cen5sum  \
# 0          2.449373e-05    -0.020051    0.027229      2.106517     0.095158
# 1          2.594653e-04     0.135960    0.099051     -2.055273     0.068979
# 2          5.581963e-03    -0.012716    0.068115     -0.250139    -0.004716
# 3          1.225873e-02     0.001722    0.065159     -1.736416    -0.022663
# 4          1.480156e-09    -0.023826    0.049554     -0.994942    -0.031524
# ...                 ...          ...         ...           ...          ...
# 34082      2.840090e-04    -0.113635    0.096076      0.535057    -0.246220
# 34083      5.395059e-02     0.080218    0.053601      2.887396     0.066209
# 34084      3.504521e-01    -0.061816    0.104454      0.121902    -0.076967
# 34085      1.126326e-01     0.000961    0.047206      1.977908    -0.072004
# 34086      9.906091e-02     0.060639    0.081176      0.077238     0.082365
#
#        RF_cen5sum  RMRF_cen5sum  pct_cen7sum  RF_cen7sum  RMRF_cen7sum  \
# 0        0.063718      2.095520     0.186179    0.099990      3.145210
# 1        0.138538     -4.268887     0.048651    0.178026     -4.607642
# 2        0.158951     -0.558310    -0.002971    0.249787     -1.450041
# 3        0.152086     -2.821734    -0.020077    0.238803     -2.753260
# 4        0.165027     -0.704433    -0.043378    0.198027     -0.312208
# ...           ...           ...          ...         ...           ...
# 34082    0.134926     -0.534668    -0.291712    0.173777     -0.844522
# 34083    0.125044      3.865878     0.082876    0.196699      3.920553
# 34084    0.139266     -1.118332    -0.061583    0.174078     -0.982620
# 34085    0.110227      1.658702    -0.103254    0.172820      2.689463
# 34086    0.113856     -0.002369     0.044815    0.146536     -1.621023
#
#        pct_cen11sum  RF_cen11sum  RMRF_cen11sum   180CAR3   180CAR5   180CAR7  \
# 0          0.367888     0.136368       5.257233 -0.000888  0.077900  0.126189
# 1          0.066696     0.316887      -5.076389  0.129581  0.045305 -0.011114
# 2         -0.040029     0.363107      -1.042710  0.024108 -0.056134 -0.137719
# 3         -0.086138     0.325611      -0.871457  0.051002 -0.053362 -0.137931
# 4         -0.078551     0.263922       0.266193  0.016897 -0.111592 -0.163628
# ...             ...          ...            ...       ...       ...       ...
# 34082     -0.274151     0.291613      -3.755096 -0.112971 -0.271720 -0.352387
# 34083      0.017235     0.285435       1.822980  0.098004  0.007288 -0.047994
# 34084     -0.059889     0.313345       0.230677 -0.084153 -0.130193 -0.150050
# 34085      0.087481     0.236579       3.498012  0.036935 -0.097569 -0.196195
# 34086      0.055863     0.245226       0.610712  0.048657  0.038255 -0.020749
#
#        180CAR11
# 0      0.258523
# 1     -0.127230
# 2     -0.291525
# 3     -0.302848
# 4     -0.275287
# ...         ...
# 34082 -0.418144
# 34083 -0.191085
# 34084 -0.291461
# 34085 -0.072971
# 34086 -0.123870
#
# [34087 rows x 32 columns]

# %%
output180CAR_2.to_pickle(rf"{output_folder_path}\output180CAR_2.pkl")

# %%
del ols180
del ols180CAR

del result180CAR2
del result180CAR

del output180CAR
del output180CAR_2

# %% [markdown]
# ## 210 CAR Data Reading

# %%
ols210 = pd.read_pickle(rf"{import_folder_path}\ols210_2.pkl")

# %% [markdown]
# ## 210 CAR Calc

# %%
ols210CAR = ols210.sort_values(by = ["CompanyName", "AsOnDate"])
ols210CAR
# Out:
#                  CompanyName  ProwessCode     Symbol   AsOnDate    ACP  \
# 0            20 Microns Ltd.         11.0  20MICRONS 2008-10-06  16.82
# 1            20 Microns Ltd.         11.0  20MICRONS 2008-10-07  15.05
# 2            20 Microns Ltd.         11.0  20MICRONS 2008-10-08  13.25
# 3            20 Microns Ltd.         11.0  20MICRONS 2008-10-10  11.60
# 4            20 Microns Ltd.         11.0  20MICRONS 2008-10-13  12.32
# ...                      ...          ...        ...        ...    ...
# 13465088  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-21   0.35
# 13465089  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-22   0.35
# 13465090  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-26   0.35
# 13465091  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-27   0.35
# 13465092  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-28   0.35
#
#                pct        RF      RMRF        MF       SMB       HML  \
# 0              NaN  0.069713 -6.381449 -6.311735 -0.373052 -0.566450
# 1        -0.105232  0.023232 -0.669144 -0.645911 -1.502487  0.184699
# 2        -0.119601  0.023232 -3.533362 -3.510130 -1.780674  0.072932
# 3        -0.124528  0.045520 -7.052324 -7.006804  0.217126  0.354629
# 4         0.062069  0.066863  5.042738  5.109602 -2.437097  0.145853
# ...            ...       ...       ...       ...       ...       ...
# 13465088  0.000000  0.018215  1.441807  1.460021  0.572866  1.270303
# 13465089  0.000000  0.018215  0.593324  0.611538  0.752002  0.124527
# 13465090  0.000000  0.072878 -0.044514  0.028364 -1.091597  0.440605
# 13465091  0.000000  0.018215  0.326702  0.344916 -0.165072 -0.188505
# 13465092  0.000000  0.018215  0.703054  0.721269 -0.579335 -0.093002
#
#           OLS210_intercept  OLS210_RMRF  OLS210_r_squared  \
# 0                      NaN          NaN               NaN
# 1                      NaN          NaN               NaN
# 2                      NaN          NaN               NaN
# 3                      NaN          NaN               NaN
# 4                      NaN          NaN               NaN
# ...                    ...          ...               ...
# 13465088               NaN          NaN               NaN
# 13465089               NaN          NaN               NaN
# 13465090               NaN          NaN               NaN
# 13465091               NaN          NaN               NaN
# 13465092               NaN          NaN               NaN
#
#           OLS210_adjusted_r_squared  OLS210_f_p_value
# 0                               NaN               NaN
# 1                               NaN               NaN
# 2                               NaN               NaN
# 3                               NaN               NaN
# 4                               NaN               NaN
# ...                             ...               ...
# 13465088                        NaN               NaN
# 13465089                        NaN               NaN
# 13465090                        NaN               NaN
# 13465091                        NaN               NaN
# 13465092                        NaN               NaN
#
# [13465093 rows x 16 columns]

# %%
# FUNCTION

# def CAR210(frame):
#     if ((~frame.OLS210_intercept.isnull().any()) == True):
#         ER = frame.RF + (frame.RMRF * frame.OLS210_RMRF) + (frame.SMB * frame.OLS210_SMB) + (frame.HML * frame.OLS210_HML) + frame.OLS210_intercept
#         AR = frame.pct - ER
#         return AR.sum()
#     else: 
#         return np.NaN

    # for i in range(len(frame)):
    #     if (i>0) & ( i< len(frame)-1) :
    #         coeff210CAR = np.array([frame.iloc[i]["OLS210_RMRF"], frame.iloc[i]["OLS210_SMB"],
    #                                 frame.iloc[i]["OLS210_HML"], 1, frame.iloc[i]["OLS210_intercept"]])

    #         event210CAR3 = np.array(frame.loc[ [i-1, i, i+1], ["RMRF", "SMB", "HML", "RF"]],)
    #         event210CAR3 = [np.append(item, 1) for item in event210CAR3]

    #         ER = np.matmul(event210CAR3, coeff210CAR)

    #         actualReturns = np.array([frame.iloc[i-1]["pct"], frame.iloc[i]["pct"], frame.iloc[i+1]["pct"]])

    #         AR = np.subtract( actualReturns, ER )

    #         output210CAR3.loc[i, ["210CAR3"]] = AR.sum()


    
        # if i>=2:
        #     frame["210CAR5"].iloc[i] = CAR210(frame.iloc[ i-2 : i+2 ])
        # if i>=3:
        #     frame["210CAR7"].iloc[i] = CAR210(frame.iloc[ i-3 : i+3 ])
        # if i>=5:
        #     frame["210CAR11"].iloc[i] = CAR210(frame.iloc[ i-5 : i+5 ])

        

def CAR(frame):

    outputFrame = pd.DataFrame( index = frame.index)

        
    # 3 Days
    
    outputFrame["pct_cen3sum"] = frame["pct"].rolling(window = 3, min_periods = 3, center = True).sum()
    
    outputFrame["RF_cen3sum"] = frame["RF"].rolling(window = 3, min_periods = 3, center = True).sum()
    
    outputFrame["RMRF_cen3sum"] = frame["RMRF"].rolling(window = 3, min_periods = 3, center = True).sum()
    
    
    # 5 Days
    
    outputFrame["pct_cen5sum"] = frame["pct"].rolling(window = 5, min_periods = 5, center = True).sum()
    
    outputFrame["RF_cen5sum"] = frame["RF"].rolling(window = 5, min_periods = 5, center = True).sum()
    
    outputFrame["RMRF_cen5sum"] = frame["RMRF"].rolling(window = 5, min_periods = 5, center = True).sum()
    
    
    # 7 Days
    
    outputFrame["pct_cen7sum"] = frame["pct"].rolling(window = 7, min_periods = 7, center = True).sum()
    
    outputFrame["RF_cen7sum"] = frame["RF"].rolling(window = 7, min_periods = 7, center = True).sum()
    
    outputFrame["RMRF_cen7sum"] = frame["RMRF"].rolling(window = 7, min_periods = 7, center = True).sum()
    
    
    # 11 Days
    
    outputFrame["pct_cen11sum"] = frame["pct"].rolling(window = 11, min_periods = 11, center = True).sum()
    
    outputFrame["RF_cen11sum"] = frame["RF"].rolling(window = 11, min_periods = 11, center = True).sum()
    
    outputFrame["RMRF_cen11sum"] = frame["RMRF"].rolling(window = 11, min_periods = 11, center = True).sum()
    
    
    return outputFrame

# %%
result210CAR = ols210CAR.sort_values(by = ["CompanyName", "AsOnDate"]).groupby(by = "CompanyName").progress_apply(CAR)
# Out:
#   0%|          | 0/3721 [00:00<?, ?it/s]
# C:\Users\SHIVAM\anaconda3\Lib\site-packages\tqdm\std.py:805: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return getattr(df, df_function)(wrapper, **kwargs)

# %%
result210CAR
# Out:
#                              pct_cen3sum  RF_cen3sum  RMRF_cen3sum  \
# CompanyName
# 20 Microns Ltd.    0                 NaN         NaN           NaN
#                    1                 NaN    0.116178    -10.583954
#                    2           -0.349361    0.091985    -11.254830
#                    3           -0.182061    0.135616     -5.542948
#                    4           -0.163920    0.134667     -0.834193
# ...                                  ...         ...           ...
# Zylog Systems Ltd. 13465088     0.000000    0.054643      2.222872
#                    13465089     0.000000    0.109307      1.990617
#                    13465090     0.000000    0.109307      0.875511
#                    13465091     0.000000    0.109307      0.985242
#                    13465092          NaN         NaN           NaN
#
#                              pct_cen5sum  RF_cen5sum  RMRF_cen5sum  \
# CompanyName
# 20 Microns Ltd.    0                 NaN         NaN           NaN
#                    1                 NaN         NaN           NaN
#                    2                 NaN    0.228562    -12.593540
#                    3           -0.388754    0.181132     -5.036699
#                    4           -0.183251    0.180182     -9.543586
# ...                                  ...         ...           ...
# Zylog Systems Ltd. 13465088     0.000000    0.145734      0.669402
#                    13465089     0.000000    0.145735      2.505059
#                    13465090     0.000000    0.145736      3.020372
#                    13465091          NaN         NaN           NaN
#                    13465092          NaN         NaN           NaN
#
#                              pct_cen7sum  RF_cen7sum  RMRF_cen7sum  \
# CompanyName
# 20 Microns Ltd.    0                 NaN         NaN           NaN
#                    1                 NaN         NaN           NaN
#                    2                 NaN         NaN           NaN
#                    3                 NaN    0.273128    -16.594178
#                    4           -0.163688    0.225697    -12.320480
# ...                                  ...         ...           ...
# Zylog Systems Ltd. 13465088     0.000000    0.218599      1.086124
#                    13465089     0.000000    0.182163      1.699158
#                    13465090          NaN         NaN           NaN
#                    13465091          NaN         NaN           NaN
#                    13465092          NaN         NaN           NaN
#
#                              pct_cen11sum  RF_cen11sum  RMRF_cen11sum
# CompanyName
# 20 Microns Ltd.    0                  NaN          NaN            NaN
#                    1                  NaN          NaN            NaN
#                    2                  NaN          NaN            NaN
#                    3                  NaN          NaN            NaN
#                    4                  NaN          NaN            NaN
# ...                                   ...          ...            ...
# Zylog Systems Ltd. 13465088           NaN          NaN            NaN
#                    13465089           NaN          NaN            NaN
#                    13465090           NaN          NaN            NaN
#                    13465091           NaN          NaN            NaN
#                    13465092           NaN          NaN            NaN
#
# [13465093 rows x 12 columns]

# %%
result210CAR2 = result210CAR.reset_index(level = 0).drop("CompanyName", axis = 1)
result210CAR2
# Out:
#           pct_cen3sum  RF_cen3sum  RMRF_cen3sum  pct_cen5sum  RF_cen5sum  \
# 0                 NaN         NaN           NaN          NaN         NaN
# 1                 NaN    0.116178    -10.583954          NaN         NaN
# 2           -0.349361    0.091985    -11.254830          NaN    0.228562
# 3           -0.182061    0.135616     -5.542948    -0.388754    0.181132
# 4           -0.163920    0.134667     -0.834193    -0.183251    0.180182
# ...               ...         ...           ...          ...         ...
# 13465088     0.000000    0.054643      2.222872     0.000000    0.145734
# 13465089     0.000000    0.109307      1.990617     0.000000    0.145735
# 13465090     0.000000    0.109307      0.875511     0.000000    0.145736
# 13465091     0.000000    0.109307      0.985242          NaN         NaN
# 13465092          NaN         NaN           NaN          NaN         NaN
#
#           RMRF_cen5sum  pct_cen7sum  RF_cen7sum  RMRF_cen7sum  pct_cen11sum  \
# 0                  NaN          NaN         NaN           NaN           NaN
# 1                  NaN          NaN         NaN           NaN           NaN
# 2           -12.593540          NaN         NaN           NaN           NaN
# 3            -5.036699          NaN    0.273128    -16.594178           NaN
# 4            -9.543586    -0.163688    0.225697    -12.320480           NaN
# ...                ...          ...         ...           ...           ...
# 13465088      0.669402     0.000000    0.218599      1.086124           NaN
# 13465089      2.505059     0.000000    0.182163      1.699158           NaN
# 13465090      3.020372          NaN         NaN           NaN           NaN
# 13465091           NaN          NaN         NaN           NaN           NaN
# 13465092           NaN          NaN         NaN           NaN           NaN
#
#           RF_cen11sum  RMRF_cen11sum
# 0                 NaN            NaN
# 1                 NaN            NaN
# 2                 NaN            NaN
# 3                 NaN            NaN
# 4                 NaN            NaN
# ...               ...            ...
# 13465088          NaN            NaN
# 13465089          NaN            NaN
# 13465090          NaN            NaN
# 13465091          NaN            NaN
# 13465092          NaN            NaN
#
# [13465093 rows x 12 columns]

# %%
output210CAR = pd.concat([ols210CAR, result210CAR2], axis = 1)
output210CAR
# Out:
#                  CompanyName  ProwessCode     Symbol   AsOnDate    ACP  \
# 0            20 Microns Ltd.         11.0  20MICRONS 2008-10-06  16.82
# 1            20 Microns Ltd.         11.0  20MICRONS 2008-10-07  15.05
# 2            20 Microns Ltd.         11.0  20MICRONS 2008-10-08  13.25
# 3            20 Microns Ltd.         11.0  20MICRONS 2008-10-10  11.60
# 4            20 Microns Ltd.         11.0  20MICRONS 2008-10-13  12.32
# ...                      ...          ...        ...        ...    ...
# 13465088  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-21   0.35
# 13465089  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-22   0.35
# 13465090  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-26   0.35
# 13465091  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-27   0.35
# 13465092  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-28   0.35
#
#                pct        RF      RMRF        MF       SMB       HML  \
# 0              NaN  0.069713 -6.381449 -6.311735 -0.373052 -0.566450
# 1        -0.105232  0.023232 -0.669144 -0.645911 -1.502487  0.184699
# 2        -0.119601  0.023232 -3.533362 -3.510130 -1.780674  0.072932
# 3        -0.124528  0.045520 -7.052324 -7.006804  0.217126  0.354629
# 4         0.062069  0.066863  5.042738  5.109602 -2.437097  0.145853
# ...            ...       ...       ...       ...       ...       ...
# 13465088  0.000000  0.018215  1.441807  1.460021  0.572866  1.270303
# 13465089  0.000000  0.018215  0.593324  0.611538  0.752002  0.124527
# 13465090  0.000000  0.072878 -0.044514  0.028364 -1.091597  0.440605
# 13465091  0.000000  0.018215  0.326702  0.344916 -0.165072 -0.188505
# 13465092  0.000000  0.018215  0.703054  0.721269 -0.579335 -0.093002
#
#           OLS210_intercept  OLS210_RMRF  OLS210_r_squared  \
# 0                      NaN          NaN               NaN
# 1                      NaN          NaN               NaN
# 2                      NaN          NaN               NaN
# 3                      NaN          NaN               NaN
# 4                      NaN          NaN               NaN
# ...                    ...          ...               ...
# 13465088               NaN          NaN               NaN
# 13465089               NaN          NaN               NaN
# 13465090               NaN          NaN               NaN
# 13465091               NaN          NaN               NaN
# 13465092               NaN          NaN               NaN
#
#           OLS210_adjusted_r_squared  OLS210_f_p_value  pct_cen3sum  \
# 0                               NaN               NaN          NaN
# 1                               NaN               NaN          NaN
# 2                               NaN               NaN    -0.349361
# 3                               NaN               NaN    -0.182061
# 4                               NaN               NaN    -0.163920
# ...                             ...               ...          ...
# 13465088                        NaN               NaN     0.000000
# 13465089                        NaN               NaN     0.000000
# 13465090                        NaN               NaN     0.000000
# 13465091                        NaN               NaN     0.000000
# 13465092                        NaN               NaN          NaN
#
#           RF_cen3sum  RMRF_cen3sum  pct_cen5sum  RF_cen5sum  RMRF_cen5sum  \
# 0                NaN           NaN          NaN         NaN           NaN
# 1           0.116178    -10.583954          NaN         NaN           NaN
# 2           0.091985    -11.254830          NaN    0.228562    -12.593540
# 3           0.135616     -5.542948    -0.388754    0.181132     -5.036699
# 4           0.134667     -0.834193    -0.183251    0.180182     -9.543586
# ...              ...           ...          ...         ...           ...
# 13465088    0.054643      2.222872     0.000000    0.145734      0.669402
# 13465089    0.109307      1.990617     0.000000    0.145735      2.505059
# 13465090    0.109307      0.875511     0.000000    0.145736      3.020372
# 13465091    0.109307      0.985242          NaN         NaN           NaN
# 13465092         NaN           NaN          NaN         NaN           NaN
#
#           pct_cen7sum  RF_cen7sum  RMRF_cen7sum  pct_cen11sum  RF_cen11sum  \
# 0                 NaN         NaN           NaN           NaN          NaN
# 1                 NaN         NaN           NaN           NaN          NaN
# 2                 NaN         NaN           NaN           NaN          NaN
# 3                 NaN    0.273128    -16.594178           NaN          NaN
# 4           -0.163688    0.225697    -12.320480           NaN          NaN
# ...               ...         ...           ...           ...          ...
# 13465088     0.000000    0.218599      1.086124           NaN          NaN
# 13465089     0.000000    0.182163      1.699158           NaN          NaN
# 13465090          NaN         NaN           NaN           NaN          NaN
# 13465091          NaN         NaN           NaN           NaN          NaN
# 13465092          NaN         NaN           NaN           NaN          NaN
#
#           RMRF_cen11sum
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 13465088            NaN
# 13465089            NaN
# 13465090            NaN
# 13465091            NaN
# 13465092            NaN
#
# [13465093 rows x 28 columns]

# %%
output210CAR.columns
# Out:
# Index(['CompanyName', 'ProwessCode', 'Symbol', 'AsOnDate', 'ACP', 'pct', 'RF',
#        'RMRF', 'MF', 'SMB', 'HML', 'OLS210_intercept', 'OLS210_RMRF',
#        'OLS210_r_squared', 'OLS210_adjusted_r_squared', 'OLS210_f_p_value',
#        'pct_cen3sum', 'RF_cen3sum', 'RMRF_cen3sum', 'pct_cen5sum',
#        'RF_cen5sum', 'RMRF_cen5sum', 'pct_cen7sum', 'RF_cen7sum',
#        'RMRF_cen7sum', 'pct_cen11sum', 'RF_cen11sum', 'RMRF_cen11sum'],
#       dtype='object')

# %%
output210CAR["210CAR3"] = output210CAR["pct_cen3sum"] - (output210CAR["RF_cen3sum"] + 
                          
                          output210CAR["OLS210_RMRF"]*output210CAR["RMRF_cen3sum"] + 
                          output210CAR["OLS210_intercept"]*3 )

# %%
output210CAR["210CAR5"] = output210CAR["pct_cen5sum"] - (output210CAR["RF_cen5sum"] + 
                          
                          output210CAR["OLS210_RMRF"]*output210CAR["RMRF_cen5sum"] + 
                          output210CAR["OLS210_intercept"]*3 )

# %%
output210CAR["210CAR7"] = output210CAR["pct_cen7sum"] - (output210CAR["RF_cen7sum"] + 
                          
                          output210CAR["OLS210_RMRF"]*output210CAR["RMRF_cen7sum"] + 
                          output210CAR["OLS210_intercept"]*3 )

# %%
output210CAR["210CAR11"] = output210CAR["pct_cen11sum"] - (output210CAR["RF_cen11sum"] + 
                          
                          output210CAR["OLS210_RMRF"]*output210CAR["RMRF_cen11sum"] + 
                          output210CAR["OLS210_intercept"]*3 )

# %%
output210CAR
# Out:
#                  CompanyName  ProwessCode     Symbol   AsOnDate    ACP  \
# 0            20 Microns Ltd.         11.0  20MICRONS 2008-10-06  16.82
# 1            20 Microns Ltd.         11.0  20MICRONS 2008-10-07  15.05
# 2            20 Microns Ltd.         11.0  20MICRONS 2008-10-08  13.25
# 3            20 Microns Ltd.         11.0  20MICRONS 2008-10-10  11.60
# 4            20 Microns Ltd.         11.0  20MICRONS 2008-10-13  12.32
# ...                      ...          ...        ...        ...    ...
# 13465088  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-21   0.35
# 13465089  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-22   0.35
# 13465090  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-26   0.35
# 13465091  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-27   0.35
# 13465092  Zylog Systems Ltd.     275793.0      ZYLOG 2024-03-28   0.35
#
#                pct        RF      RMRF        MF       SMB       HML  \
# 0              NaN  0.069713 -6.381449 -6.311735 -0.373052 -0.566450
# 1        -0.105232  0.023232 -0.669144 -0.645911 -1.502487  0.184699
# 2        -0.119601  0.023232 -3.533362 -3.510130 -1.780674  0.072932
# 3        -0.124528  0.045520 -7.052324 -7.006804  0.217126  0.354629
# 4         0.062069  0.066863  5.042738  5.109602 -2.437097  0.145853
# ...            ...       ...       ...       ...       ...       ...
# 13465088  0.000000  0.018215  1.441807  1.460021  0.572866  1.270303
# 13465089  0.000000  0.018215  0.593324  0.611538  0.752002  0.124527
# 13465090  0.000000  0.072878 -0.044514  0.028364 -1.091597  0.440605
# 13465091  0.000000  0.018215  0.326702  0.344916 -0.165072 -0.188505
# 13465092  0.000000  0.018215  0.703054  0.721269 -0.579335 -0.093002
#
#           OLS210_intercept  OLS210_RMRF  OLS210_r_squared  \
# 0                      NaN          NaN               NaN
# 1                      NaN          NaN               NaN
# 2                      NaN          NaN               NaN
# 3                      NaN          NaN               NaN
# 4                      NaN          NaN               NaN
# ...                    ...          ...               ...
# 13465088               NaN          NaN               NaN
# 13465089               NaN          NaN               NaN
# 13465090               NaN          NaN               NaN
# 13465091               NaN          NaN               NaN
# 13465092               NaN          NaN               NaN
#
#           OLS210_adjusted_r_squared  OLS210_f_p_value  pct_cen3sum  \
# 0                               NaN               NaN          NaN
# 1                               NaN               NaN          NaN
# 2                               NaN               NaN    -0.349361
# 3                               NaN               NaN    -0.182061
# 4                               NaN               NaN    -0.163920
# ...                             ...               ...          ...
# 13465088                        NaN               NaN     0.000000
# 13465089                        NaN               NaN     0.000000
# 13465090                        NaN               NaN     0.000000
# 13465091                        NaN               NaN     0.000000
# 13465092                        NaN               NaN          NaN
#
#           RF_cen3sum  RMRF_cen3sum  pct_cen5sum  RF_cen5sum  RMRF_cen5sum  \
# 0                NaN           NaN          NaN         NaN           NaN
# 1           0.116178    -10.583954          NaN         NaN           NaN
# 2           0.091985    -11.254830          NaN    0.228562    -12.593540
# 3           0.135616     -5.542948    -0.388754    0.181132     -5.036699
# 4           0.134667     -0.834193    -0.183251    0.180182     -9.543586
# ...              ...           ...          ...         ...           ...
# 13465088    0.054643      2.222872     0.000000    0.145734      0.669402
# 13465089    0.109307      1.990617     0.000000    0.145735      2.505059
# 13465090    0.109307      0.875511     0.000000    0.145736      3.020372
# 13465091    0.109307      0.985242          NaN         NaN           NaN
# 13465092         NaN           NaN          NaN         NaN           NaN
#
#           pct_cen7sum  RF_cen7sum  RMRF_cen7sum  pct_cen11sum  RF_cen11sum  \
# 0                 NaN         NaN           NaN           NaN          NaN
# 1                 NaN         NaN           NaN           NaN          NaN
# 2                 NaN         NaN           NaN           NaN          NaN
# 3                 NaN    0.273128    -16.594178           NaN          NaN
# 4           -0.163688    0.225697    -12.320480           NaN          NaN
# ...               ...         ...           ...           ...          ...
# 13465088     0.000000    0.218599      1.086124           NaN          NaN
# 13465089     0.000000    0.182163      1.699158           NaN          NaN
# 13465090          NaN         NaN           NaN           NaN          NaN
# 13465091          NaN         NaN           NaN           NaN          NaN
# 13465092          NaN         NaN           NaN           NaN          NaN
#
#           RMRF_cen11sum  210CAR3  210CAR5  210CAR7  210CAR11
# 0                   NaN      NaN      NaN      NaN       NaN
# 1                   NaN      NaN      NaN      NaN       NaN
# 2                   NaN      NaN      NaN      NaN       NaN
# 3                   NaN      NaN      NaN      NaN       NaN
# 4                   NaN      NaN      NaN      NaN       NaN
# ...                 ...      ...      ...      ...       ...
# 13465088            NaN      NaN      NaN      NaN       NaN
# 13465089            NaN      NaN      NaN      NaN       NaN
# 13465090            NaN      NaN      NaN      NaN       NaN
# 13465091            NaN      NaN      NaN      NaN       NaN
# 13465092            NaN      NaN      NaN      NaN       NaN
#
# [13465093 rows x 32 columns]

# %%
output210CAR_2 = output210CAR.dropna(subset = "210CAR3").reset_index(drop = True)
output210CAR_2
# Out:
#               CompanyName  ProwessCode     Symbol   AsOnDate    ACP       pct  \
# 0         20 Microns Ltd.         11.0  20MICRONS 2011-04-29  20.48 -0.016330
# 1         20 Microns Ltd.         11.0  20MICRONS 2014-08-06  31.15 -0.011111
# 2         20 Microns Ltd.         11.0  20MICRONS 2015-02-05  38.50 -0.020356
# 3         20 Microns Ltd.         11.0  20MICRONS 2017-05-04  43.70  0.016279
# 4         20 Microns Ltd.         11.0  20MICRONS 2019-05-28  41.00 -0.016787
# ...                   ...          ...        ...        ...    ...       ...
# 33898  Zylog Systems Ltd.     275793.0      ZYLOG 2015-08-14   5.40  0.018868
# 33899  Zylog Systems Ltd.     275793.0      ZYLOG 2016-06-30   3.90  0.040000
# 33900  Zylog Systems Ltd.     275793.0      ZYLOG 2016-08-12   3.15 -0.045455
# 33901  Zylog Systems Ltd.     275793.0      ZYLOG 2016-11-23   4.25 -0.022989
# 33902  Zylog Systems Ltd.     275793.0      ZYLOG 2017-02-10   5.05  0.041237
#
#              RF      RMRF        MF       SMB       HML  OLS210_intercept  \
# 0      0.019851 -0.595940 -0.576089 -0.572908 -0.607305         -0.023121
# 1      0.022705 -0.690542 -0.667837  1.023324 -0.182707         -0.035117
# 2      0.021755 -0.625772 -0.604017  0.012769 -1.213916         -0.034893
# 3      0.016554  0.046274  0.062828  0.831535 -0.581499         -0.024740
# 4      0.016873  0.367905  0.384778 -0.177790  0.292518         -0.025401
# ...         ...       ...       ...       ...       ...               ...
# 33898  0.019213  1.546309  1.565522 -0.064032  1.416502         -0.035294
# 33899  0.017832  1.065921  1.083753 -0.809196  1.214423         -0.027771
# 33900  0.017406  0.290292  0.307698 -0.979555  0.368906         -0.028711
# 33901  0.015807  1.118596  1.134402  0.640072  1.506896         -0.027389
# 33902  0.016234 -0.042546 -0.026312  0.204566 -0.756680         -0.024955
#
#        OLS210_RMRF  OLS210_r_squared  OLS210_adjusted_r_squared  \
# 0         0.009385          0.073740                   0.069287
# 1         0.005551          0.026592                   0.021912
# 2         0.006952          0.038823                   0.034202
# 3         0.017188          0.166374                   0.162366
# 4         0.017863          0.233449                   0.229763
# ...            ...               ...                        ...
# 33898     0.013010          0.077200                   0.072764
# 33899     0.008411          0.038518                   0.033895
# 33900     0.005695          0.022120                   0.017419
# 33901     0.004182          0.010090                   0.005331
# 33902     0.006593          0.015668                   0.010935
#
#        OLS210_f_p_value  pct_cen3sum  RF_cen3sum  RMRF_cen3sum  pct_cen5sum  \
# 0          6.696283e-05     0.135960    0.099051     -2.055273     0.068979
# 1          1.803598e-02    -0.012716    0.068115     -0.250139    -0.004716
# 2          4.151230e-03     0.001722    0.065159     -1.736416    -0.022663
# 3          7.998804e-10    -0.023826    0.049554     -0.994942    -0.031524
# 4          1.106707e-13     0.060421    0.084375      0.593600     0.127139
# ...                 ...          ...         ...           ...          ...
# 33898      4.444277e-05    -0.113635    0.096076      0.535057    -0.246220
# 33899      4.304770e-03     0.080218    0.053601      2.887396     0.066209
# 33900      3.120744e-02    -0.061816    0.104454      0.121902    -0.076967
# 33901      1.468822e-01     0.000961    0.047206      1.977908    -0.072004
# 33902      7.026674e-02     0.060639    0.081176      0.077238     0.082365
#
#        RF_cen5sum  RMRF_cen5sum  pct_cen7sum  RF_cen7sum  RMRF_cen7sum  \
# 0        0.138538     -4.268887     0.048651    0.178026     -4.607642
# 1        0.158951     -0.558310    -0.002971    0.249787     -1.450041
# 2        0.152086     -2.821734    -0.020077    0.238803     -2.753260
# 3        0.165027     -0.704433    -0.043378    0.198027     -0.312208
# 4        0.117695      2.441371     0.116773    0.151016      2.141790
# ...           ...           ...          ...         ...           ...
# 33898    0.134926     -0.534668    -0.291712    0.173777     -0.844522
# 33899    0.125044      3.865878     0.082876    0.196699      3.920553
# 33900    0.139266     -1.118332    -0.061583    0.174078     -0.982620
# 33901    0.110227      1.658702    -0.103254    0.172820      2.689463
# 33902    0.113856     -0.002369     0.044815    0.146536     -1.621023
#
#        pct_cen11sum  RF_cen11sum  RMRF_cen11sum   210CAR3   210CAR5   210CAR7  \
# 0          0.066696     0.316887      -5.076389  0.125561  0.039867 -0.016769
# 1         -0.040029     0.363107      -1.042710  0.025908 -0.055217 -0.139358
# 2         -0.086138     0.325611      -0.871457  0.053314 -0.050453 -0.135060
# 3         -0.078551     0.263922       0.266193  0.017940 -0.110223 -0.161819
# 4          0.099791     0.250771       1.525870  0.041646  0.042037  0.003702
# ...             ...          ...            ...       ...       ...       ...
# 33898     -0.274151     0.291613      -3.755096 -0.110791 -0.268309 -0.348619
# 33899      0.017235     0.285435       1.822980  0.085644 -0.008037 -0.063485
# 33900     -0.059889     0.313345       0.230677 -0.080831 -0.123732 -0.143932
# 33901      0.087481     0.236579       3.498012  0.027651 -0.106999 -0.205153
# 33902      0.055863     0.245226       0.610712  0.053818  0.043389 -0.016170
#
#        210CAR11
# 0     -0.133185
# 1     -0.291996
# 2     -0.301011
# 3     -0.272828
# 4     -0.102033
# ...         ...
# 33898 -0.411028
# 33899 -0.200219
# 33900 -0.288414
# 33901 -0.081559
# 33902 -0.118526
#
# [33903 rows x 32 columns]

# %%
output210CAR_2.to_pickle(rf"{output_folder_path}\output210CAR_2.pkl")

# %%
output210CAR_2
# Out:
#               CompanyName  ProwessCode     Symbol   AsOnDate    ACP       pct  \
# 0         20 Microns Ltd.         11.0  20MICRONS 2011-04-29  20.48 -0.016330
# 1         20 Microns Ltd.         11.0  20MICRONS 2014-08-06  31.15 -0.011111
# 2         20 Microns Ltd.         11.0  20MICRONS 2015-02-05  38.50 -0.020356
# 3         20 Microns Ltd.         11.0  20MICRONS 2017-05-04  43.70  0.016279
# 4         20 Microns Ltd.         11.0  20MICRONS 2019-05-28  41.00 -0.016787
# ...                   ...          ...        ...        ...    ...       ...
# 33898  Zylog Systems Ltd.     275793.0      ZYLOG 2015-08-14   5.40  0.018868
# 33899  Zylog Systems Ltd.     275793.0      ZYLOG 2016-06-30   3.90  0.040000
# 33900  Zylog Systems Ltd.     275793.0      ZYLOG 2016-08-12   3.15 -0.045455
# 33901  Zylog Systems Ltd.     275793.0      ZYLOG 2016-11-23   4.25 -0.022989
# 33902  Zylog Systems Ltd.     275793.0      ZYLOG 2017-02-10   5.05  0.041237
#
#              RF      RMRF        MF       SMB       HML  OLS210_intercept  \
# 0      0.019851 -0.595940 -0.576089 -0.572908 -0.607305         -0.023121
# 1      0.022705 -0.690542 -0.667837  1.023324 -0.182707         -0.035117
# 2      0.021755 -0.625772 -0.604017  0.012769 -1.213916         -0.034893
# 3      0.016554  0.046274  0.062828  0.831535 -0.581499         -0.024740
# 4      0.016873  0.367905  0.384778 -0.177790  0.292518         -0.025401
# ...         ...       ...       ...       ...       ...               ...
# 33898  0.019213  1.546309  1.565522 -0.064032  1.416502         -0.035294
# 33899  0.017832  1.065921  1.083753 -0.809196  1.214423         -0.027771
# 33900  0.017406  0.290292  0.307698 -0.979555  0.368906         -0.028711
# 33901  0.015807  1.118596  1.134402  0.640072  1.506896         -0.027389
# 33902  0.016234 -0.042546 -0.026312  0.204566 -0.756680         -0.024955
#
#        OLS210_RMRF  OLS210_r_squared  OLS210_adjusted_r_squared  \
# 0         0.009385          0.073740                   0.069287
# 1         0.005551          0.026592                   0.021912
# 2         0.006952          0.038823                   0.034202
# 3         0.017188          0.166374                   0.162366
# 4         0.017863          0.233449                   0.229763
# ...            ...               ...                        ...
# 33898     0.013010          0.077200                   0.072764
# 33899     0.008411          0.038518                   0.033895
# 33900     0.005695          0.022120                   0.017419
# 33901     0.004182          0.010090                   0.005331
# 33902     0.006593          0.015668                   0.010935
#
#        OLS210_f_p_value  pct_cen3sum  RF_cen3sum  RMRF_cen3sum  pct_cen5sum  \
# 0          6.696283e-05     0.135960    0.099051     -2.055273     0.068979
# 1          1.803598e-02    -0.012716    0.068115     -0.250139    -0.004716
# 2          4.151230e-03     0.001722    0.065159     -1.736416    -0.022663
# 3          7.998804e-10    -0.023826    0.049554     -0.994942    -0.031524
# 4          1.106707e-13     0.060421    0.084375      0.593600     0.127139
# ...                 ...          ...         ...           ...          ...
# 33898      4.444277e-05    -0.113635    0.096076      0.535057    -0.246220
# 33899      4.304770e-03     0.080218    0.053601      2.887396     0.066209
# 33900      3.120744e-02    -0.061816    0.104454      0.121902    -0.076967
# 33901      1.468822e-01     0.000961    0.047206      1.977908    -0.072004
# 33902      7.026674e-02     0.060639    0.081176      0.077238     0.082365
#
#        RF_cen5sum  RMRF_cen5sum  pct_cen7sum  RF_cen7sum  RMRF_cen7sum  \
# 0        0.138538     -4.268887     0.048651    0.178026     -4.607642
# 1        0.158951     -0.558310    -0.002971    0.249787     -1.450041
# 2        0.152086     -2.821734    -0.020077    0.238803     -2.753260
# 3        0.165027     -0.704433    -0.043378    0.198027     -0.312208
# 4        0.117695      2.441371     0.116773    0.151016      2.141790
# ...           ...           ...          ...         ...           ...
# 33898    0.134926     -0.534668    -0.291712    0.173777     -0.844522
# 33899    0.125044      3.865878     0.082876    0.196699      3.920553
# 33900    0.139266     -1.118332    -0.061583    0.174078     -0.982620
# 33901    0.110227      1.658702    -0.103254    0.172820      2.689463
# 33902    0.113856     -0.002369     0.044815    0.146536     -1.621023
#
#        pct_cen11sum  RF_cen11sum  RMRF_cen11sum   210CAR3   210CAR5   210CAR7  \
# 0          0.066696     0.316887      -5.076389  0.125561  0.039867 -0.016769
# 1         -0.040029     0.363107      -1.042710  0.025908 -0.055217 -0.139358
# 2         -0.086138     0.325611      -0.871457  0.053314 -0.050453 -0.135060
# 3         -0.078551     0.263922       0.266193  0.017940 -0.110223 -0.161819
# 4          0.099791     0.250771       1.525870  0.041646  0.042037  0.003702
# ...             ...          ...            ...       ...       ...       ...
# 33898     -0.274151     0.291613      -3.755096 -0.110791 -0.268309 -0.348619
# 33899      0.017235     0.285435       1.822980  0.085644 -0.008037 -0.063485
# 33900     -0.059889     0.313345       0.230677 -0.080831 -0.123732 -0.143932
# 33901      0.087481     0.236579       3.498012  0.027651 -0.106999 -0.205153
# 33902      0.055863     0.245226       0.610712  0.053818  0.043389 -0.016170
#
#        210CAR11
# 0     -0.133185
# 1     -0.291996
# 2     -0.301011
# 3     -0.272828
# 4     -0.102033
# ...         ...
# 33898 -0.411028
# 33899 -0.200219
# 33900 -0.288414
# 33901 -0.081559
# 33902 -0.118526
#
# [33903 rows x 32 columns]
